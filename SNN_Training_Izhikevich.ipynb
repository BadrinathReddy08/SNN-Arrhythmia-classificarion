# %%
import numpy as np
import snntorch as snn
import torch
from snntorch import spikegen
from snntorch import utils
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from torch.utils.data import TensorDataset, DataLoader

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

from snntorch import spikeplot as splt
import torch.nn as nn
import pandas as pd
from sklearn.preprocessing import StandardScaler

import matplotlib.pyplot as plt
import numpy as np
import itertools

from snntorch import surrogate
import seaborn as sns
from sklearn.metrics import confusion_matrix

# %%
class _SpikeTensor(torch.Tensor):
    """Inherits from torch.Tensor with additional attributes.
    ``init_flag`` is set at the time of initialization.
    When called in the forward function of any neuron, they are parsed and
    replaced with a torch.Tensor variable.
    """

    @staticmethod
    def __new__(cls, *args, init_flag=False, **kwargs):
        return super().__new__(cls, *args, **kwargs)

    def __init__(
        self,
        *args,
        init_flag=True,
    ):
        # super().__init__() # optional
        self.init_flag = init_flag


def _SpikeTorchConv(*args, input_):
    """Convert SpikeTensor to torch.Tensor of the same size as ``input_``."""

    states = []
    # if len(input_.size()) == 0:
    #     _batch_size = 1  # assume batch_size=1 if 1D input
    # else:
    #     _batch_size = input_.size(0)
    if (
        len(args) == 1 and type(args) is not tuple
    ):  # if only one hidden state, make it iterable
        args = (args,)
    for arg in args:
        arg = arg.to("cpu")
        arg = torch.Tensor(arg)  # wash away the SpikeTensor class
        arg = torch.zeros_like(input_, requires_grad=True)
        states.append(arg)
    if len(states) == 1:  # otherwise, list isn't unpacked
        return states[0]

    return states

# %%
# file = open("Arthymia_4_para.csv")

# num_steps = 10
# batch_size = 100
# num_epochs = 120
# loss_hist = []
# test_loss_hist = []
# counter = 0
# num_inputs = 1*4
# num_hidden = 50
# num_outputs = 7
# learning_rate = 1.3e-3
# torch.manual_seed(490) 
# dtype = torch.float #          95.07%

file = open("Arthymia_4_para.csv")

num_steps = 10
batch_size = 100
num_epochs = 120
loss_hist = []
test_loss_hist = []
counter = 0
num_inputs = 1*4
num_hidden = 8
num_outputs = 7
learning_rate = 2e-3
torch.manual_seed(490) 
dtype = torch.float #          93.44%

# %%
numpy_array = np.genfromtxt("Arthymia_4_para.csv", delimiter=",", dtype=None, names=True, encoding=None)

# %%
data = pd.read_csv("Arthymia_4_para.csv")
input_features = data.iloc[:, :4].values
scaler = StandardScaler()
scaler.fit(input_features)

normalized_input_features = scaler.transform(input_features)

normalized_data = pd.DataFrame(normalized_input_features, columns=data.columns[:4])

# %%
print(scaler.mean_)
print(scaler.var_)
# Out:
# [961.50978947 141.33       169.03778947 407.14294737]
# [344895.94274627   9096.9211      10135.06772985   1793.71535552]

# %%
in_data = normalized_data.values
in_data
# Out:
# array([[-0.49296855, -0.5591449 ,  0.08902292,  0.30357406],
#        [-0.53383502, -0.42284481,  0.08902292, -0.42838187],
#        [-0.47083254, -0.45429868, -0.09970679,  0.49246591],
#        ...,
#        [ 0.61723741,  0.09090167,  1.30086632,  1.60220554],
#        [ 0.61042633, -0.04539841,  1.72799145,  0.6341348 ],
#        [-0.61556798, -0.64302188, -0.08977365, -0.16865557]])

# %%
# in_data = np.array([(x[0], x[1], x[2], x[3]) for x in numpy_array])
out_data = np.array([(x[4]) for x in numpy_array])

class_enum = {'NORMAL SINUS RHYTHM': 0,
 'SINUS BRADYCARDIA': 1,
 'WIDE BRADYCARDIA': 2,
 'SINUS TACHYCARDIA': 3,
 'WIDE TACHYCARDIA': 4,
 'NARROW BRADYCARDIA': 5,
 'NARROW TACHYCARDIA': 6}

output_data = [class_enum[x] for x in out_data]

inputs_tensor = torch.tensor(in_data, dtype=torch.float32)
outputs_tensor = torch.tensor(output_data, dtype=torch.long)

dataset = TensorDataset(inputs_tensor, outputs_tensor)

data_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# %%
print(inputs_tensor)
print(outputs_tensor)
# Out:
# tensor([[-0.4930, -0.5591,  0.0890,  0.3036],
#         [-0.5338, -0.4228,  0.0890, -0.4284],
#         [-0.4708, -0.4543, -0.0997,  0.4925],
#         ...,
#         [ 0.6172,  0.0909,  1.3009,  1.6022],
#         [ 0.6104, -0.0454,  1.7280,  0.6341],
#         [-0.6156, -0.6430, -0.0898, -0.1687]])
# tensor([0, 0, 0,  ..., 2, 2, 0])

# %%
class SpikingNeuron(nn.Module):
    """Parent class for spiking neuron models."""

    instances = []
    """Each :mod:`snntorch.SpikingNeuron` neuron
    (e.g., :mod:`snntorch.Synaptic`) will populate the
    :mod:`snntorch.SpikingNeuron.instances` list with a new entry.
    The list is used to initialize and clear neuron states when the
    argument `init_hidden=True`."""

    reset_dict = {
        "subtract": 0,
        "zero": 1,
        "none": 2,
    }

    def __init__(
        self,
        threshold=1.0,
        spike_grad=None,
        surrogate_disable=False,
        init_hidden=False,
        inhibition=False,
        learn_threshold=False,
        reset_mechanism="subtract",
        state_quant=False,
        output=False,
        graded_spikes_factor=1.0,
        learn_graded_spikes_factor=False,
    ):
        super(SpikingNeuron, self).__init__()

        SpikingNeuron.instances.append(self)
        self.init_hidden = init_hidden
        self.inhibition = inhibition
        self.output = output
        self.surrogate_disable = surrogate_disable

        self._snn_cases(reset_mechanism, inhibition)
        self._snn_register_buffer(
            threshold=threshold,
            learn_threshold=learn_threshold,
            reset_mechanism=reset_mechanism,
            graded_spikes_factor=graded_spikes_factor,
            learn_graded_spikes_factor=learn_graded_spikes_factor,
        )
        self._reset_mechanism = reset_mechanism

        if spike_grad is None:
            self.spike_grad = self.ATan.apply
        else:
            self.spike_grad = spike_grad

        if self.surrogate_disable:
            self.spike_grad = self._surrogate_bypass

        self.state_quant = state_quant

    def fire(self, mem):
        """Generates spike if mem > threshold.
        Returns spk."""

        if self.state_quant:
            mem = self.state_quant(mem)

        mem_shift = mem - self.threshold
        spk = self.spike_grad(mem_shift)

        spk = spk * self.graded_spikes_factor

        return spk

    def fire_inhibition(self, batch_size, mem):
        """Generates spike if mem > threshold, only for the largest membrane.
        All others neurons will be inhibited for that time step.
        Returns spk."""
        mem_shift = mem - self.threshold
        index = torch.argmax(mem_shift, dim=1)
        spk_tmp = self.spike_grad(mem_shift)

        mask_spk1 = torch.zeros_like(spk_tmp)
        mask_spk1[torch.arange(batch_size), index] = 1
        spk = spk_tmp * mask_spk1
        # reset = spk.clone().detach()

        return spk

    def mem_reset(self, mem):
        """Generates detached reset signal if mem > threshold.
        Returns reset."""
        mem_shift = mem - self.threshold
        reset = self.spike_grad(mem_shift).clone().detach()

        return reset

    def _snn_cases(self, reset_mechanism, inhibition):
        self._reset_cases(reset_mechanism)

        if inhibition:
            warn(
                "Inhibition is an unstable feature that has only been tested "
                "for dense (fully-connected) layers. Use with caution!",
                UserWarning,
            )

    def _reset_cases(self, reset_mechanism):
        if (
            reset_mechanism != "subtract"
            and reset_mechanism != "zero"
            and reset_mechanism != "none"
        ):
            raise ValueError(
                "reset_mechanism must be set to either 'subtract', "
                "'zero', or 'none'."
            )

    def _snn_register_buffer(
        self,
        threshold,
        learn_threshold,
        reset_mechanism,
        graded_spikes_factor,
        learn_graded_spikes_factor,
    ):
        """Set variables as learnable parameters else register them in the
        buffer."""

        self._threshold_buffer(threshold, learn_threshold)
        self._graded_spikes_buffer(
            graded_spikes_factor, learn_graded_spikes_factor
        )

        # reset buffer
        try:
            # if reset_mechanism_val is loaded from .pt, override
            # reset_mechanism
            if torch.is_tensor(self.reset_mechanism_val):
                self.reset_mechanism = list(SpikingNeuron.reset_dict)[
                    self.reset_mechanism_val
                ]
        except AttributeError:
            # reset_mechanism_val has not yet been created, create it
            self._reset_mechanism_buffer(reset_mechanism)

    def _graded_spikes_buffer(
        self, graded_spikes_factor, learn_graded_spikes_factor
    ):
        if not isinstance(graded_spikes_factor, torch.Tensor):
            graded_spikes_factor = torch.as_tensor(graded_spikes_factor)
        if learn_graded_spikes_factor:
            self.graded_spikes_factor = nn.Parameter(graded_spikes_factor)
        else:
            self.register_buffer("graded_spikes_factor", graded_spikes_factor)

    def _threshold_buffer(self, threshold, learn_threshold):
        if not isinstance(threshold, torch.Tensor):
            threshold = torch.as_tensor(threshold)
        if learn_threshold:
            self.threshold = nn.Parameter(threshold)
        else:
            self.register_buffer("threshold", threshold)

    def _reset_mechanism_buffer(self, reset_mechanism):
        """Assign mapping to each reset mechanism state.
        Must be of type tensor to store in register buffer. See reset_dict
        for mapping."""
        reset_mechanism_val = torch.as_tensor(
            SpikingNeuron.reset_dict[reset_mechanism]
        )
        self.register_buffer("reset_mechanism_val", reset_mechanism_val)

    def _V_register_buffer(self, V, learn_V):
        if not isinstance(V, torch.Tensor):
            V = torch.as_tensor(V)
        if learn_V:
            self.V = nn.Parameter(V)
        else:
            self.register_buffer("V", V)

    @property
    def reset_mechanism(self):
        """If reset_mechanism is modified, reset_mechanism_val is triggered
        to update.
        0: subtract, 1: zero, 2: none."""
        return self._reset_mechanism

    @reset_mechanism.setter
    def reset_mechanism(self, new_reset_mechanism):
        self._reset_cases(new_reset_mechanism)
        self.reset_mechanism_val = torch.as_tensor(
            SpikingNeuron.reset_dict[new_reset_mechanism]
        )
        self._reset_mechanism = new_reset_mechanism

    @classmethod
    def init(cls):
        """Removes all items from :mod:`snntorch.SpikingNeuron.instances`
        when called."""
        cls.instances = []

    @staticmethod
    def detach(*args):
        """Used to detach input arguments from the current graph.
        Intended for use in truncated backpropagation through time where
        hidden state variables are global variables."""
        for state in args:
            state.detach_()

    @staticmethod
    def zeros(*args):
        """Used to clear hidden state variables to zero.
        Intended for use where hidden state variables are global variables."""
        for state in args:
            state = torch.zeros_like(state)

    @staticmethod
    def _surrogate_bypass(input_):
        return (input_ > 0).float()

    @staticmethod
    class ATan(torch.autograd.Function):
        """
        Surrogate gradient of the Heaviside step function.

        **Forward pass:** Heaviside step function shifted.

            .. math::

                S=\\begin{cases} 1 & \\text{if U ≥ U$_{\\rm thr}$} \\\\
                0 & \\text{if U < U$_{\\rm thr}$}
                \\end{cases}

        **Backward pass:** Gradient of shifted arc-tan function.

            .. math::

                    S&≈\\frac{1}{π}\\text{arctan}(πU \\frac{α}{2}) \\\\
                    \\frac{∂S}{∂U}&=\\frac{1}{π}\
                    \\frac{1}{(1+(πU\\frac{α}{2})^2)}


        :math:`alpha` defaults to 2, and can be modified by calling
        ``surrogate.atan(alpha=2)``.

        Adapted from:

        *W. Fang, Z. Yu, Y. Chen, T. Masquelier, T. Huang, Y. Tian (2021)
        Incorporating Learnable Membrane Time Constants to Enhance Learning
        of Spiking Neural Networks. Proc. IEEE/CVF Int. Conf. Computer
        Vision (ICCV), pp. 2661-2671.*"""

        @staticmethod
        def forward(ctx, input_, alpha=2.0):
            ctx.save_for_backward(input_)
            ctx.alpha = alpha
            out = (input_ > 0).float()
            return out

        @staticmethod
        def backward(ctx, grad_output):
            (input_,) = ctx.saved_tensors
            grad_input = grad_output.clone()
            grad = (
                ctx.alpha
                / 2
                / (1 + (torch.pi / 2 * ctx.alpha * input_).pow_(2))
                * grad_input
            )
            return grad, None

# %%
class Izhikevich(SpikingNeuron):

    def __init__(
        self, a, b, c, d,
        threshold=1.0,
        spike_grad=None,
        surrogate_disable=False,
        init_hidden=False,
        inhibition=False,
        learn_beta=False,
        learn_threshold=False,
        reset_mechanism="subtract",
        state_quant=False,
        output=False,
        graded_spikes_factor=1.0,
        learn_graded_spikes_factor=False,
    ):
        super().__init__(
            threshold,
            spike_grad,
            surrogate_disable,
            init_hidden,
            inhibition,
            learn_threshold,
            reset_mechanism,
            state_quant,
            output,
            graded_spikes_factor,
            learn_graded_spikes_factor,
        )

        self.spike_gradient = self.ATan.apply
        self.a = a            # Membrane capacitance
        self.b = b          # Leak conductance
        self.c = c          # Leak reversal potential
        self.d = d  # Slope factor
        self.u = torch.tensor(0.0)         # Initial adaptation current
        
        if self.init_hidden:
            self.mem = self.init_leaky()

    def forward(self, input_, mem=False):

        if hasattr(mem, "init_flag"):  # only triggered on first-pass
            mem = _SpikeTorchConv(mem, input_=input_)
        elif mem is False and hasattr(
            self.mem, "init_flag"
        ):  # init_hidden case
            
            self.mem = _SpikeTorchConv(self.mem, input_=input_)
 
        dt = 0.1
        spk = self.spike_gradient((mem - (-50)))  # call the Heaviside function

        # dV = (self.g_L * (self.E_L - mem) + self.g_L * self.Delta_T * torch.exp((mem - self.V_T) / self.Delta_T) - self.w + abs(input_)) / self.Cm
        dV = torch.tensor(0.04) * (mem ** 2) + 5 * mem + 140 - self.u + abs(input_)
        du = self.a * (self.b*mem) - self.u

        mem = mem + dV * dt  # Avoid in-place modification
        self.u = self.u + du * dt  # Avoid in-place modification

        spike_mask = mem >= 30  # Spike condition
        mem = torch.where(spike_mask, torch.tensor(self.c), mem)  # Reset membrane potential where spike occurs
        self.u = self.u + self.d * spike_mask.float()  # Spike-triggered adaptation

        return spk, mem

    
    @staticmethod
    def init_Izhikevich():
        """
        Used to initialize mem as an empty SpikeTensor.
        ``init_flag`` is used as an attribute in the forward pass to convert
        the hidden states to the same as the input.
        """
        mem = _SpikeTensor(init_flag=False)

        return mem

# %%
a = 0.02
b = 0.2
c = -65
d = 8

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()

        # Initialize layers
        self.fc1 = nn.Linear(num_inputs, num_hidden)
        self.IZ1 = Izhikevich(a,b,c,d)
        self.fc2 = nn.Linear(num_hidden, num_outputs)
        self.IZ2 = Izhikevich(a,b,c,d)

    def forward(self, x):

        # Initialize hidden states at t=0
        mem1 = self.IZ1.init_Izhikevich()
        mem2 = self.IZ2.init_Izhikevich()

        # Record the final layer
        spk2_rec = []
        mem2_rec = []

        for step in range(num_steps):
            cur1 = self.fc1(x)
            spk1, mem1 = self.IZ1(cur1*100, mem1)
            cur2 = self.fc2(spk1)
            spk2, mem2 = self.IZ2(cur2*100, mem2)
            spk2_rec.append(spk2)
            mem2_rec.append(mem2)

        return torch.stack(spk2_rec, dim=0), torch.stack(mem2_rec, dim=0)
        
# Load the network onto CUDA if available
net = Net().to(device)

# %%
test_accuracy_data = []
train_accuracy_data = []

def print_batch_accuracy(data, targets, train=False):
    output, _ = net(data.view(batch_size, -1))
    _, idx = output.sum(dim=0).max(1)
    acc = np.mean((targets == idx).detach().cpu().numpy())

    if train:
        print(f"Train set accuracy for a single minibatch: {acc*100:.2f}%")
        train_accuracy_data.append(acc*100)
    else:
        print(f"Test set accuracy for a single minibatch: {acc*100:.2f}%")
        test_accuracy_data.append(acc*100)

def train_printer(
    data, targets, epoch,
    counter, iter_counter,
        loss_hist, test_loss_hist, test_data, test_targets):
    print(f"Epoch {epoch}, Iteration {iter_counter}")
    print(f"Train Set Loss: {loss_hist[counter]:.2f}")
    print(f"Test Set Loss: {test_loss_hist[counter]:.2f}")
    print_batch_accuracy(data, targets, train=True)
    print_batch_accuracy(test_data, test_targets, train=False)
    print("\n")

# %%
loss = nn.CrossEntropyLoss()
#dice, hinge
optimizer = torch.optim.Adam(net.parameters(), lr=learning_rate, betas=(0.9, 0.999))

# %%
data, targets = next(iter(data_loader))
data = data.to(device)
targets = targets.to(device)

# %%
spk_rec, mem_rec = net(data.view(batch_size, -1))
print(mem_rec.size())
# Out:
# torch.Size([10, 100, 7])

# %%
# initialize the total loss value
loss_val = torch.zeros((1), dtype=dtype, device=device)

# sum loss at every step
for step in range(num_steps):
  loss_val += loss(mem_rec[step], targets)

print(f"Training loss: {loss_val.item():.3f}")
print_batch_accuracy(data, targets, train=True)
# Out:
# Training loss: 77.401
# Train set accuracy for a single minibatch: 34.00%

# %%
# Outer training loop
# torch.autograd.set_detect_anomaly(True)

for epoch in range(num_epochs):
    iter_counter = 0
    train_batch = iter(data_loader)

    # Minibatch training loop
    for data, targets in train_batch:
        data = data.to(device)
        targets = targets.to(device)

        # forward pass
        net.train()
        # print(data.shape)
        spk_rec, mem_rec = net(data.view(batch_size, -1))

        # initialize the loss & sum over time
        loss_val = torch.zeros((1), dtype=dtype, device=device)
        for step in range(num_steps):
            loss_val += loss(mem_rec[step], targets)

        # Gradient calculation + weight update
        optimizer.zero_grad()
        loss_val.backward()
        optimizer.step()

        # Store loss history for future plotting
        loss_hist.append(loss_val.item())

        # Test set
        with torch.no_grad():
            net.eval()
            test_data, test_targets = next(iter(data_loader))
            test_data = test_data.to(device)
            test_targets = test_targets.to(device)

            # Test set forward pass
            test_spk, test_mem = net(test_data.view(batch_size, -1))

            # Test set loss
            test_loss = torch.zeros((1), dtype=dtype, device=device)
            for step in range(num_steps):
                test_loss += loss(test_mem[step], test_targets)
            test_loss_hist.append(test_loss.item())

            # Print train/test loss/accuracy
            if counter % 5 == 0:
                train_printer(
                    data, targets, epoch,
                    counter, iter_counter,
                    loss_hist, test_loss_hist,
                    test_data, test_targets)
            counter += 1
            iter_counter +=1
# Out:
# Epoch 0, Iteration 0
# Train Set Loss: 70.92
# Test Set Loss: 61.99
# Train set accuracy for a single minibatch: 35.00%
# Test set accuracy for a single minibatch: 37.00%
#
#
# Epoch 0, Iteration 5
# Train Set Loss: 53.37
# Test Set Loss: 56.21
# Train set accuracy for a single minibatch: 43.00%
# Test set accuracy for a single minibatch: 45.00%
#
#
# Epoch 0, Iteration 10
# Train Set Loss: 46.99
# Test Set Loss: 47.47
# Train set accuracy for a single minibatch: 38.00%
# Test set accuracy for a single minibatch: 44.00%
#
#
# Epoch 0, Iteration 15
# Train Set Loss: 44.13
# Test Set Loss: 40.65
# Train set accuracy for a single minibatch: 42.00%
# Test set accuracy for a single minibatch: 41.00%
#
#
# Epoch 0, Iteration 20
# Train Set Loss: 33.47
# Test Set Loss: 32.31
# Train set accuracy for a single minibatch: 54.00%
# Test set accuracy for a single minibatch: 51.00%
#
#
# Epoch 0, Iteration 25
# Train Set Loss: 30.23
# Test Set Loss: 35.96
# Train set accuracy for a single minibatch: 45.00%
# Test set accuracy for a single minibatch: 40.00%
#
#
# Epoch 0, Iteration 30
# Train Set Loss: 33.34
# Test Set Loss: 27.81
# Train set accuracy for a single minibatch: 45.00%
# Test set accuracy for a single minibatch: 58.00%
#
#
# Epoch 0, Iteration 35
# Train Set Loss: 27.82
# Test Set Loss: 28.04
# Train set accuracy for a single minibatch: 52.00%
# Test set accuracy for a single minibatch: 47.00%
#
#
# Epoch 0, Iteration 40
# Train Set Loss: 23.96
# Test Set Loss: 25.81
# Train set accuracy for a single minibatch: 50.00%
# Test set accuracy for a single minibatch: 44.00%
#
#
# Epoch 0, Iteration 45
# Train Set Loss: 23.13
# Test Set Loss: 21.94
# Train set accuracy for a single minibatch: 50.00%
# Test set accuracy for a single minibatch: 48.00%
#
#
# Epoch 0, Iteration 50
# Train Set Loss: 22.59
# Test Set Loss: 22.68
# Train set accuracy for a single minibatch: 50.00%
# Test set accuracy for a single minibatch: 46.00%
#
#
# Epoch 0, Iteration 55
# Train Set Loss: 18.48
# Test Set Loss: 20.63
# Train set accuracy for a single minibatch: 58.00%
# Test set accuracy for a single minibatch: 51.00%
#
#
# Epoch 0, Iteration 60
# Train Set Loss: 20.88
# Test Set Loss: 19.69
# Train set accuracy for a single minibatch: 51.00%
# Test set accuracy for a single minibatch: 55.00%
#
#
# Epoch 0, Iteration 65
# Train Set Loss: 20.13
# Test Set Loss: 17.14
# Train set accuracy for a single minibatch: 49.00%
# Test set accuracy for a single minibatch: 49.00%
#
#
# Epoch 0, Iteration 70
# Train Set Loss: 16.37
# Test Set Loss: 18.84
# Train set accuracy for a single minibatch: 52.00%
# Test set accuracy for a single minibatch: 52.00%
#
#
# Epoch 0, Iteration 75
# Train Set Loss: 18.80
# Test Set Loss: 15.64
# Train set accuracy for a single minibatch: 49.00%
# Test set accuracy for a single minibatch: 52.00%
#
#
# Epoch 0, Iteration 80
# Train Set Loss: 15.87
# Test Set Loss: 15.97
# Train set accuracy for a single minibatch: 56.00%
# Test set accuracy for a single minibatch: 51.00%
#
#
# Epoch 0, Iteration 85
# Train Set Loss: 14.78
# Test Set Loss: 16.02
# Train set accuracy for a single minibatch: 56.00%
# Test set accuracy for a single minibatch: 52.00%
#
#
# Epoch 0, Iteration 90
# Train Set Loss: 13.91
# Test Set Loss: 14.64
# Train set accuracy for a single minibatch: 54.00%
# Test set accuracy for a single minibatch: 62.00%
#
#
# Epoch 1, Iteration 0
# Train Set Loss: 15.79
# Test Set Loss: 13.65
# Train set accuracy for a single minibatch: 57.00%
# Test set accuracy for a single minibatch: 58.00%
#
#
# Epoch 1, Iteration 5
# Train Set Loss: 14.76
# Test Set Loss: 14.27
# Train set accuracy for a single minibatch: 57.00%
# Test set accuracy for a single minibatch: 49.00%
#
#
# Epoch 1, Iteration 10
# Train Set Loss: 13.61
# Test Set Loss: 14.36
# Train set accuracy for a single minibatch: 53.00%
# Test set accuracy for a single minibatch: 56.00%
#
#
# Epoch 1, Iteration 15
# Train Set Loss: 13.95
# Test Set Loss: 13.51
# Train set accuracy for a single minibatch: 56.00%
# Test set accuracy for a single minibatch: 57.00%
#
#
# Epoch 1, Iteration 20
# Train Set Loss: 14.17
# Test Set Loss: 14.50
# Train set accuracy for a single minibatch: 44.00%
# Test set accuracy for a single minibatch: 55.00%
#
#
# Epoch 1, Iteration 25
# Train Set Loss: 14.01
# Test Set Loss: 14.54
# Train set accuracy for a single minibatch: 51.00%
# Test set accuracy for a single minibatch: 48.00%
#
#
# Epoch 1, Iteration 30
# Train Set Loss: 12.57
# Test Set Loss: 13.71
# Train set accuracy for a single minibatch: 58.00%
# Test set accuracy for a single minibatch: 60.00%
#
#
# Epoch 1, Iteration 35
# Train Set Loss: 14.50
# Test Set Loss: 13.79
# Train set accuracy for a single minibatch: 47.00%
# Test set accuracy for a single minibatch: 51.00%
#
#
# Epoch 1, Iteration 40
# Train Set Loss: 13.49
# Test Set Loss: 11.09
# Train set accuracy for a single minibatch: 54.00%
# Test set accuracy for a single minibatch: 59.00%
#
#
# Epoch 1, Iteration 45
# Train Set Loss: 12.38
# Test Set Loss: 12.08
# Train set accuracy for a single minibatch: 52.00%
# Test set accuracy for a single minibatch: 59.00%
#
#
# Epoch 1, Iteration 50
# Train Set Loss: 12.37
# Test Set Loss: 12.11
# Train set accuracy for a single minibatch: 57.00%
# Test set accuracy for a single minibatch: 62.00%
#
#
# Epoch 1, Iteration 55
# Train Set Loss: 13.54
# Test Set Loss: 13.51
# Train set accuracy for a single minibatch: 64.00%
# Test set accuracy for a single minibatch: 55.00%
#
#
# Epoch 1, Iteration 60
# Train Set Loss: 12.67
# Test Set Loss: 12.51
# Train set accuracy for a single minibatch: 57.00%
# Test set accuracy for a single minibatch: 55.00%
#
#
# Epoch 1, Iteration 65
# Train Set Loss: 12.44
# Test Set Loss: 12.42
# Train set accuracy for a single minibatch: 44.00%
# Test set accuracy for a single minibatch: 52.00%
#
#
# Epoch 1, Iteration 70
# Train Set Loss: 12.40
# Test Set Loss: 11.71
# Train set accuracy for a single minibatch: 51.00%
# Test set accuracy for a single minibatch: 56.00%
#
#
# Epoch 1, Iteration 75
# Train Set Loss: 11.58
# Test Set Loss: 13.94
# Train set accuracy for a single minibatch: 57.00%
# Test set accuracy for a single minibatch: 50.00%
#
#
# Epoch 1, Iteration 80
# Train Set Loss: 12.26
# Test Set Loss: 11.90
# Train set accuracy for a single minibatch: 54.00%
# Test set accuracy for a single minibatch: 59.00%
#
#
# Epoch 1, Iteration 85
# Train Set Loss: 12.16
# Test Set Loss: 11.17
# Train set accuracy for a single minibatch: 51.00%
# Test set accuracy for a single minibatch: 49.00%
#
#
# Epoch 1, Iteration 90
# Train Set Loss: 12.05
# Test Set Loss: 11.91
# Train set accuracy for a single minibatch: 50.00%
# Test set accuracy for a single minibatch: 50.00%
#
#
# Epoch 2, Iteration 0
# Train Set Loss: 12.31
# Test Set Loss: 11.74
# Train set accuracy for a single minibatch: 50.00%
# Test set accuracy for a single minibatch: 55.00%
#
#
# Epoch 2, Iteration 5
# Train Set Loss: 11.69
# Test Set Loss: 11.92
# Train set accuracy for a single minibatch: 58.00%
# Test set accuracy for a single minibatch: 53.00%
#
#
# Epoch 2, Iteration 10
# Train Set Loss: 11.27
# Test Set Loss: 10.84
# Train set accuracy for a single minibatch: 41.00%
# Test set accuracy for a single minibatch: 55.00%
#
#
# Epoch 2, Iteration 15
# Train Set Loss: 11.40
# Test Set Loss: 11.66
# Train set accuracy for a single minibatch: 66.00%
# Test set accuracy for a single minibatch: 58.00%
#
#
# Epoch 2, Iteration 20
# Train Set Loss: 12.21
# Test Set Loss: 10.91
# Train set accuracy for a single minibatch: 42.00%
# Test set accuracy for a single minibatch: 56.00%
#
#
# Epoch 2, Iteration 25
# Train Set Loss: 12.06
# Test Set Loss: 12.43
# Train set accuracy for a single minibatch: 51.00%
# Test set accuracy for a single minibatch: 52.00%
#
#
# Epoch 2, Iteration 30
# Train Set Loss: 12.80
# Test Set Loss: 11.75
# Train set accuracy for a single minibatch: 50.00%
# Test set accuracy for a single minibatch: 49.00%
#
#
# Epoch 2, Iteration 35
# Train Set Loss: 12.27
# Test Set Loss: 10.75
# Train set accuracy for a single minibatch: 49.00%
# Test set accuracy for a single minibatch: 63.00%
#
#
# Epoch 2, Iteration 40
# Train Set Loss: 11.50
# Test Set Loss: 12.71
# Train set accuracy for a single minibatch: 54.00%
# Test set accuracy for a single minibatch: 53.00%
#
#
# Epoch 2, Iteration 45
# Train Set Loss: 11.13
# Test Set Loss: 10.82
# Train set accuracy for a single minibatch: 53.00%
# Test set accuracy for a single minibatch: 56.00%
#
#
# Epoch 2, Iteration 50
# Train Set Loss: 10.64
# Test Set Loss: 11.19
# Train set accuracy for a single minibatch: 58.00%
# Test set accuracy for a single minibatch: 54.00%
#
#
# Epoch 2, Iteration 55
# Train Set Loss: 10.37
# Test Set Loss: 11.08
# Train set accuracy for a single minibatch: 60.00%
# Test set accuracy for a single minibatch: 47.00%
#
#
# Epoch 2, Iteration 60
# Train Set Loss: 10.35
# Test Set Loss: 13.22
# Train set accuracy for a single minibatch: 62.00%
# Test set accuracy for a single minibatch: 40.00%
#
#
# Epoch 2, Iteration 65
# Train Set Loss: 10.70
# Test Set Loss: 11.81
# Train set accuracy for a single minibatch: 52.00%
# Test set accuracy for a single minibatch: 56.00%
#
#
# Epoch 2, Iteration 70
# Train Set Loss: 11.46
# Test Set Loss: 12.14
# Train set accuracy for a single minibatch: 61.00%
# Test set accuracy for a single minibatch: 50.00%
#
#
# Epoch 2, Iteration 75
# Train Set Loss: 11.97
# Test Set Loss: 11.61
# Train set accuracy for a single minibatch: 58.00%
# Test set accuracy for a single minibatch: 54.00%
#
#
# Epoch 2, Iteration 80
# Train Set Loss: 10.83
# Test Set Loss: 11.79
# Train set accuracy for a single minibatch: 54.00%
# Test set accuracy for a single minibatch: 47.00%
#
#
# Epoch 2, Iteration 85
# Train Set Loss: 11.01
# Test Set Loss: 11.16
# Train set accuracy for a single minibatch: 53.00%
# Test set accuracy for a single minibatch: 54.00%
#
#
# Epoch 2, Iteration 90
# Train Set Loss: 10.27
# Test Set Loss: 11.20
# Train set accuracy for a single minibatch: 57.00%
# Test set accuracy for a single minibatch: 56.00%
#
#
# Epoch 3, Iteration 0
# Train Set Loss: 11.12
# Test Set Loss: 11.59
# Train set accuracy for a single minibatch: 46.00%
# Test set accuracy for a single minibatch: 53.00%
#
#
# Epoch 3, Iteration 5
# Train Set Loss: 11.95
# Test Set Loss: 12.56
# Train set accuracy for a single minibatch: 50.00%
# Test set accuracy for a single minibatch: 51.00%
#
#
# Epoch 3, Iteration 10
# Train Set Loss: 12.31
# Test Set Loss: 10.96
# Train set accuracy for a single minibatch: 49.00%
# Test set accuracy for a single minibatch: 50.00%
#
#
# Epoch 3, Iteration 15
# Train Set Loss: 10.91
# Test Set Loss: 11.69
# Train set accuracy for a single minibatch: 45.00%
# Test set accuracy for a single minibatch: 48.00%
#
#
# Epoch 3, Iteration 20
# Train Set Loss: 11.09
# Test Set Loss: 11.76
# Train set accuracy for a single minibatch: 55.00%
# Test set accuracy for a single minibatch: 51.00%
#
#
# Epoch 3, Iteration 25
# Train Set Loss: 10.90
# Test Set Loss: 10.88
# Train set accuracy for a single minibatch: 56.00%
# Test set accuracy for a single minibatch: 56.00%
#
#
# Epoch 3, Iteration 30
# Train Set Loss: 10.76
# Test Set Loss: 11.22
# Train set accuracy for a single minibatch: 55.00%
# Test set accuracy for a single minibatch: 56.00%
#
#
# Epoch 3, Iteration 35
# Train Set Loss: 11.06
# Test Set Loss: 10.78
# Train set accuracy for a single minibatch: 57.00%
# Test set accuracy for a single minibatch: 58.00%
#
#
# Epoch 3, Iteration 40
# Train Set Loss: 10.53
# Test Set Loss: 11.16
# Train set accuracy for a single minibatch: 53.00%
# Test set accuracy for a single minibatch: 54.00%
#
#
# Epoch 3, Iteration 45
# Train Set Loss: 10.47
# Test Set Loss: 10.72
# Train set accuracy for a single minibatch: 59.00%
# Test set accuracy for a single minibatch: 62.00%
#
#
# Epoch 3, Iteration 50
# Train Set Loss: 11.22
# Test Set Loss: 11.58
# Train set accuracy for a single minibatch: 49.00%
# Test set accuracy for a single minibatch: 50.00%
#
#
# Epoch 3, Iteration 55
# Train Set Loss: 10.48
# Test Set Loss: 11.19
# Train set accuracy for a single minibatch: 62.00%
# Test set accuracy for a single minibatch: 57.00%
#
#
# Epoch 3, Iteration 60
# Train Set Loss: 10.66
# Test Set Loss: 10.75
# Train set accuracy for a single minibatch: 64.00%
# Test set accuracy for a single minibatch: 58.00%
#
#
# Epoch 3, Iteration 65
# Train Set Loss: 10.38
# Test Set Loss: 10.19
# Train set accuracy for a single minibatch: 61.00%
# Test set accuracy for a single minibatch: 60.00%
#
#
# Epoch 3, Iteration 70
# Train Set Loss: 11.02
# Test Set Loss: 10.20
# Train set accuracy for a single minibatch: 61.00%
# Test set accuracy for a single minibatch: 60.00%
#
#
# Epoch 3, Iteration 75
# Train Set Loss: 10.86
# Test Set Loss: 10.61
# Train set accuracy for a single minibatch: 55.00%
# Test set accuracy for a single minibatch: 57.00%
#
#
# Epoch 3, Iteration 80
# Train Set Loss: 10.95
# Test Set Loss: 11.23
# Train set accuracy for a single minibatch: 56.00%
# Test set accuracy for a single minibatch: 52.00%
#
#
# Epoch 3, Iteration 85
# Train Set Loss: 10.53
# Test Set Loss: 11.44
# Train set accuracy for a single minibatch: 65.00%
# Test set accuracy for a single minibatch: 56.00%
#
#
# Epoch 3, Iteration 90
# Train Set Loss: 10.90
# Test Set Loss: 9.96
# Train set accuracy for a single minibatch: 61.00%
# Test set accuracy for a single minibatch: 67.00%
#
#
# Epoch 4, Iteration 0
# Train Set Loss: 10.07
# Test Set Loss: 10.48
# Train set accuracy for a single minibatch: 59.00%
# Test set accuracy for a single minibatch: 64.00%
#
#
# Epoch 4, Iteration 5
# Train Set Loss: 11.31
# Test Set Loss: 11.97
# Train set accuracy for a single minibatch: 58.00%
# Test set accuracy for a single minibatch: 51.00%
#
#
# Epoch 4, Iteration 10
# Train Set Loss: 10.86
# Test Set Loss: 10.61
# Train set accuracy for a single minibatch: 56.00%
# Test set accuracy for a single minibatch: 61.00%
#
#
# Epoch 4, Iteration 15
# Train Set Loss: 10.52
# Test Set Loss: 10.70
# Train set accuracy for a single minibatch: 57.00%
# Test set accuracy for a single minibatch: 55.00%
#
#
# Epoch 4, Iteration 20
# Train Set Loss: 11.07
# Test Set Loss: 10.52
# Train set accuracy for a single minibatch: 61.00%
# Test set accuracy for a single minibatch: 59.00%
#
#
# Epoch 4, Iteration 25
# Train Set Loss: 10.33
# Test Set Loss: 10.92
# Train set accuracy for a single minibatch: 68.00%
# Test set accuracy for a single minibatch: 57.00%
#
#
# Epoch 4, Iteration 30
# Train Set Loss: 10.79
# Test Set Loss: 10.44
# Train set accuracy for a single minibatch: 54.00%
# Test set accuracy for a single minibatch: 59.00%
#
#
# Epoch 4, Iteration 35
# Train Set Loss: 10.29
# Test Set Loss: 11.33
# Train set accuracy for a single minibatch: 62.00%
# Test set accuracy for a single minibatch: 59.00%
#
#
# Epoch 4, Iteration 40
# Train Set Loss: 9.92
# Test Set Loss: 11.17
# Train set accuracy for a single minibatch: 66.00%
# Test set accuracy for a single minibatch: 55.00%
#
#
# Epoch 4, Iteration 45
# Train Set Loss: 9.45
# Test Set Loss: 10.62
# Train set accuracy for a single minibatch: 70.00%
# Test set accuracy for a single minibatch: 70.00%
#
#
# Epoch 4, Iteration 50
# Train Set Loss: 10.86
# Test Set Loss: 10.86
# Train set accuracy for a single minibatch: 51.00%
# Test set accuracy for a single minibatch: 52.00%
#
#
# Epoch 4, Iteration 55
# Train Set Loss: 10.53
# Test Set Loss: 11.25
# Train set accuracy for a single minibatch: 60.00%
# Test set accuracy for a single minibatch: 55.00%
#
#
# Epoch 4, Iteration 60
# Train Set Loss: 10.76
# Test Set Loss: 11.02
# Train set accuracy for a single minibatch: 58.00%
# Test set accuracy for a single minibatch: 56.00%
#
#
# Epoch 4, Iteration 65
# Train Set Loss: 10.80
# Test Set Loss: 10.55
# Train set accuracy for a single minibatch: 64.00%
# Test set accuracy for a single minibatch: 60.00%
#
#
# Epoch 4, Iteration 70
# Train Set Loss: 10.49
# Test Set Loss: 10.88
# Train set accuracy for a single minibatch: 59.00%
# Test set accuracy for a single minibatch: 61.00%
#
#
# Epoch 4, Iteration 75
# Train Set Loss: 10.82
# Test Set Loss: 10.29
# Train set accuracy for a single minibatch: 53.00%
# Test set accuracy for a single minibatch: 65.00%
#
#
# Epoch 4, Iteration 80
# Train Set Loss: 10.37
# Test Set Loss: 10.64
# Train set accuracy for a single minibatch: 64.00%
# Test set accuracy for a single minibatch: 54.00%
#
#
# Epoch 4, Iteration 85
# Train Set Loss: 9.90
# Test Set Loss: 9.94
# Train set accuracy for a single minibatch: 57.00%
# Test set accuracy for a single minibatch: 62.00%
#
#
# Epoch 4, Iteration 90
# Train Set Loss: 9.38
# Test Set Loss: 10.54
# Train set accuracy for a single minibatch: 58.00%
# Test set accuracy for a single minibatch: 61.00%
#
#
# Epoch 5, Iteration 0
# Train Set Loss: 10.40
# Test Set Loss: 11.35
# Train set accuracy for a single minibatch: 56.00%
# Test set accuracy for a single minibatch: 57.00%
#
#
# Epoch 5, Iteration 5
# Train Set Loss: 10.55
# Test Set Loss: 10.63
# Train set accuracy for a single minibatch: 57.00%
# Test set accuracy for a single minibatch: 60.00%
#
#
# Epoch 5, Iteration 10
# Train Set Loss: 10.26
# Test Set Loss: 10.04
# Train set accuracy for a single minibatch: 58.00%
# Test set accuracy for a single minibatch: 60.00%
#
#
# Epoch 5, Iteration 15
# Train Set Loss: 10.45
# Test Set Loss: 10.09
# Train set accuracy for a single minibatch: 54.00%
# Test set accuracy for a single minibatch: 60.00%
#
#
# Epoch 5, Iteration 20
# Train Set Loss: 10.73
# Test Set Loss: 11.21
# Train set accuracy for a single minibatch: 53.00%
# Test set accuracy for a single minibatch: 61.00%
#
#
# Epoch 5, Iteration 25
# Train Set Loss: 10.72
# Test Set Loss: 10.30
# Train set accuracy for a single minibatch: 57.00%
# Test set accuracy for a single minibatch: 60.00%
#
#
# Epoch 5, Iteration 30
# Train Set Loss: 9.94
# Test Set Loss: 10.81
# Train set accuracy for a single minibatch: 62.00%
# Test set accuracy for a single minibatch: 58.00%
#
#
# Epoch 5, Iteration 35
# Train Set Loss: 10.33
# Test Set Loss: 11.55
# Train set accuracy for a single minibatch: 56.00%
# Test set accuracy for a single minibatch: 58.00%
#
#
# Epoch 5, Iteration 40
# Train Set Loss: 10.11
# Test Set Loss: 9.05
# Train set accuracy for a single minibatch: 63.00%
# Test set accuracy for a single minibatch: 68.00%
#
#
# Epoch 5, Iteration 45
# Train Set Loss: 9.63
# Test Set Loss: 10.69
# Train set accuracy for a single minibatch: 62.00%
# Test set accuracy for a single minibatch: 54.00%
#
#
# Epoch 5, Iteration 50
# Train Set Loss: 10.75
# Test Set Loss: 10.19
# Train set accuracy for a single minibatch: 58.00%
# Test set accuracy for a single minibatch: 59.00%
#
#
# Epoch 5, Iteration 55
# Train Set Loss: 10.31
# Test Set Loss: 9.44
# Train set accuracy for a single minibatch: 59.00%
# Test set accuracy for a single minibatch: 68.00%
#
#
# Epoch 5, Iteration 60
# Train Set Loss: 10.82
# Test Set Loss: 10.03
# Train set accuracy for a single minibatch: 65.00%
# Test set accuracy for a single minibatch: 64.00%
#
#
# Epoch 5, Iteration 65
# Train Set Loss: 10.06
# Test Set Loss: 10.96
# Train set accuracy for a single minibatch: 62.00%
# Test set accuracy for a single minibatch: 59.00%
#
#
# Epoch 5, Iteration 70
# Train Set Loss: 10.94
# Test Set Loss: 9.41
# Train set accuracy for a single minibatch: 60.00%
# Test set accuracy for a single minibatch: 64.00%
#
#
# Epoch 5, Iteration 75
# Train Set Loss: 9.96
# Test Set Loss: 11.30
# Train set accuracy for a single minibatch: 67.00%
# Test set accuracy for a single minibatch: 62.00%
#
#
# Epoch 5, Iteration 80
# Train Set Loss: 9.97
# Test Set Loss: 9.72
# Train set accuracy for a single minibatch: 68.00%
# Test set accuracy for a single minibatch: 70.00%
#
#
# Epoch 5, Iteration 85
# Train Set Loss: 10.19
# Test Set Loss: 9.90
# Train set accuracy for a single minibatch: 62.00%
# Test set accuracy for a single minibatch: 65.00%
#
#
# Epoch 5, Iteration 90
# Train Set Loss: 10.21
# Test Set Loss: 9.60
# Train set accuracy for a single minibatch: 59.00%
# Test set accuracy for a single minibatch: 65.00%
#
#
# Epoch 6, Iteration 0
# Train Set Loss: 10.69
# Test Set Loss: 10.56
# Train set accuracy for a single minibatch: 59.00%
# Test set accuracy for a single minibatch: 56.00%
#
#
# Epoch 6, Iteration 5
# Train Set Loss: 9.44
# Test Set Loss: 10.73
# Train set accuracy for a single minibatch: 69.00%
# Test set accuracy for a single minibatch: 54.00%
#
#
# Epoch 6, Iteration 10
# Train Set Loss: 9.34
# Test Set Loss: 10.74
# Train set accuracy for a single minibatch: 69.00%
# Test set accuracy for a single minibatch: 53.00%
#
#
# Epoch 6, Iteration 15
# Train Set Loss: 9.57
# Test Set Loss: 9.42
# Train set accuracy for a single minibatch: 74.00%
# Test set accuracy for a single minibatch: 65.00%
#
#
# Epoch 6, Iteration 20
# Train Set Loss: 10.17
# Test Set Loss: 10.38
# Train set accuracy for a single minibatch: 58.00%
# Test set accuracy for a single minibatch: 56.00%
#
#
# Epoch 6, Iteration 25
# Train Set Loss: 9.63
# Test Set Loss: 9.04
# Train set accuracy for a single minibatch: 65.00%
# Test set accuracy for a single minibatch: 72.00%
#
#
# Epoch 6, Iteration 30
# Train Set Loss: 9.82
# Test Set Loss: 10.46
# Train set accuracy for a single minibatch: 70.00%
# Test set accuracy for a single minibatch: 65.00%
#
#
# Epoch 6, Iteration 35
# Train Set Loss: 10.25
# Test Set Loss: 11.72
# Train set accuracy for a single minibatch: 57.00%
# Test set accuracy for a single minibatch: 49.00%
#
#
# Epoch 6, Iteration 40
# Train Set Loss: 10.19
# Test Set Loss: 9.33
# Train set accuracy for a single minibatch: 57.00%
# Test set accuracy for a single minibatch: 71.00%
#
#
# Epoch 6, Iteration 45
# Train Set Loss: 9.77
# Test Set Loss: 10.09
# Train set accuracy for a single minibatch: 63.00%
# Test set accuracy for a single minibatch: 64.00%
#
#
# Epoch 6, Iteration 50
# Train Set Loss: 9.38
# Test Set Loss: 10.65
# Train set accuracy for a single minibatch: 69.00%
# Test set accuracy for a single minibatch: 61.00%
#
#
# Epoch 6, Iteration 55
# Train Set Loss: 10.11
# Test Set Loss: 9.43
# Train set accuracy for a single minibatch: 63.00%
# Test set accuracy for a single minibatch: 67.00%
#
#
# Epoch 6, Iteration 60
# Train Set Loss: 9.34
# Test Set Loss: 10.97
# Train set accuracy for a single minibatch: 67.00%
# Test set accuracy for a single minibatch: 59.00%
#
#
# Epoch 6, Iteration 65
# Train Set Loss: 9.80
# Test Set Loss: 9.98
# Train set accuracy for a single minibatch: 60.00%
# Test set accuracy for a single minibatch: 63.00%
#
#
# Epoch 6, Iteration 70
# Train Set Loss: 10.51
# Test Set Loss: 10.26
# Train set accuracy for a single minibatch: 55.00%
# Test set accuracy for a single minibatch: 58.00%
#
#
# Epoch 6, Iteration 75
# Train Set Loss: 10.09
# Test Set Loss: 10.12
# Train set accuracy for a single minibatch: 60.00%
# Test set accuracy for a single minibatch: 64.00%
#
#
# Epoch 6, Iteration 80
# Train Set Loss: 9.61
# Test Set Loss: 9.01
# Train set accuracy for a single minibatch: 66.00%
# Test set accuracy for a single minibatch: 69.00%
#
#
# Epoch 6, Iteration 85
# Train Set Loss: 10.13
# Test Set Loss: 9.80
# Train set accuracy for a single minibatch: 63.00%
# Test set accuracy for a single minibatch: 63.00%
#
#
# Epoch 6, Iteration 90
# Train Set Loss: 10.43
# Test Set Loss: 9.87
# Train set accuracy for a single minibatch: 67.00%
# Test set accuracy for a single minibatch: 65.00%
#
#
# Epoch 7, Iteration 0
# Train Set Loss: 9.58
# Test Set Loss: 10.07
# Train set accuracy for a single minibatch: 64.00%
# Test set accuracy for a single minibatch: 62.00%
#
#
# Epoch 7, Iteration 5
# Train Set Loss: 11.10
# Test Set Loss: 10.02
# Train set accuracy for a single minibatch: 66.00%
# Test set accuracy for a single minibatch: 65.00%
#
#
# Epoch 7, Iteration 10
# Train Set Loss: 9.30
# Test Set Loss: 10.07
# Train set accuracy for a single minibatch: 66.00%
# Test set accuracy for a single minibatch: 65.00%
#
#
# Epoch 7, Iteration 15
# Train Set Loss: 10.28
# Test Set Loss: 9.56
# Train set accuracy for a single minibatch: 57.00%
# Test set accuracy for a single minibatch: 70.00%
#
#
# Epoch 7, Iteration 20
# Train Set Loss: 9.96
# Test Set Loss: 9.67
# Train set accuracy for a single minibatch: 63.00%
# Test set accuracy for a single minibatch: 63.00%
#
#
# Epoch 7, Iteration 25
# Train Set Loss: 10.05
# Test Set Loss: 9.32
# Train set accuracy for a single minibatch: 67.00%
# Test set accuracy for a single minibatch: 62.00%
#
#
# Epoch 7, Iteration 30
# Train Set Loss: 9.90
# Test Set Loss: 9.04
# Train set accuracy for a single minibatch: 67.00%
# Test set accuracy for a single minibatch: 69.00%
#
#
# Epoch 7, Iteration 35
# Train Set Loss: 9.51
# Test Set Loss: 10.15
# Train set accuracy for a single minibatch: 70.00%
# Test set accuracy for a single minibatch: 63.00%
#
#
# Epoch 7, Iteration 40
# Train Set Loss: 10.12
# Test Set Loss: 9.51
# Train set accuracy for a single minibatch: 61.00%
# Test set accuracy for a single minibatch: 66.00%
#
#
# Epoch 7, Iteration 45
# Train Set Loss: 9.41
# Test Set Loss: 9.63
# Train set accuracy for a single minibatch: 66.00%
# Test set accuracy for a single minibatch: 66.00%
#
#
# Epoch 7, Iteration 50
# Train Set Loss: 9.48
# Test Set Loss: 10.36
# Train set accuracy for a single minibatch: 71.00%
# Test set accuracy for a single minibatch: 67.00%
#
#
# Epoch 7, Iteration 55
# Train Set Loss: 9.70
# Test Set Loss: 10.27
# Train set accuracy for a single minibatch: 64.00%
# Test set accuracy for a single minibatch: 57.00%
#
#
# Epoch 7, Iteration 60
# Train Set Loss: 10.08
# Test Set Loss: 9.10
# Train set accuracy for a single minibatch: 59.00%
# Test set accuracy for a single minibatch: 70.00%
#
#
# Epoch 7, Iteration 65
# Train Set Loss: 10.19
# Test Set Loss: 9.61
# Train set accuracy for a single minibatch: 56.00%
# Test set accuracy for a single minibatch: 59.00%
#
#
# Epoch 7, Iteration 70
# Train Set Loss: 10.50
# Test Set Loss: 9.88
# Train set accuracy for a single minibatch: 65.00%
# Test set accuracy for a single minibatch: 66.00%
#
#
# Epoch 7, Iteration 75
# Train Set Loss: 9.90
# Test Set Loss: 10.15
# Train set accuracy for a single minibatch: 66.00%
# Test set accuracy for a single minibatch: 72.00%
#
#
# Epoch 7, Iteration 80
# Train Set Loss: 9.42
# Test Set Loss: 9.18
# Train set accuracy for a single minibatch: 68.00%
# Test set accuracy for a single minibatch: 69.00%
#
#
# Epoch 7, Iteration 85
# Train Set Loss: 9.22
# Test Set Loss: 9.17
# Train set accuracy for a single minibatch: 68.00%
# Test set accuracy for a single minibatch: 64.00%
#
#
# Epoch 7, Iteration 90
# Train Set Loss: 9.53
# Test Set Loss: 9.46
# Train set accuracy for a single minibatch: 70.00%
# Test set accuracy for a single minibatch: 63.00%
#
#
# Epoch 8, Iteration 0
# Train Set Loss: 8.88
# Test Set Loss: 10.16
# Train set accuracy for a single minibatch: 72.00%
# Test set accuracy for a single minibatch: 57.00%
#
#
# Epoch 8, Iteration 5
# Train Set Loss: 9.65
# Test Set Loss: 9.93
# Train set accuracy for a single minibatch: 67.00%
# Test set accuracy for a single minibatch: 59.00%
#
#
# Epoch 8, Iteration 10
# Train Set Loss: 9.83
# Test Set Loss: 10.70
# Train set accuracy for a single minibatch: 58.00%
# Test set accuracy for a single minibatch: 58.00%
#
#
# Epoch 8, Iteration 15
# Train Set Loss: 10.17
# Test Set Loss: 9.83
# Train set accuracy for a single minibatch: 60.00%
# Test set accuracy for a single minibatch: 65.00%
#
#
# Epoch 8, Iteration 20
# Train Set Loss: 10.82
# Test Set Loss: 10.18
# Train set accuracy for a single minibatch: 53.00%
# Test set accuracy for a single minibatch: 67.00%
#
#
# Epoch 8, Iteration 25
# Train Set Loss: 9.26
# Test Set Loss: 9.14
# Train set accuracy for a single minibatch: 62.00%
# Test set accuracy for a single minibatch: 70.00%
#
#
# Epoch 8, Iteration 30
# Train Set Loss: 10.55
# Test Set Loss: 8.75
# Train set accuracy for a single minibatch: 61.00%
# Test set accuracy for a single minibatch: 68.00%
#
#
# Epoch 8, Iteration 35
# Train Set Loss: 9.84
# Test Set Loss: 8.58
# Train set accuracy for a single minibatch: 66.00%
# Test set accuracy for a single minibatch: 73.00%
#
#
# Epoch 8, Iteration 40
# Train Set Loss: 9.41
# Test Set Loss: 10.19
# Train set accuracy for a single minibatch: 60.00%
# Test set accuracy for a single minibatch: 60.00%
#
#
# Epoch 8, Iteration 45
# Train Set Loss: 8.92
# Test Set Loss: 10.09
# Train set accuracy for a single minibatch: 75.00%
# Test set accuracy for a single minibatch: 64.00%
#
#
# Epoch 8, Iteration 50
# Train Set Loss: 10.60
# Test Set Loss: 8.75
# Train set accuracy for a single minibatch: 65.00%
# Test set accuracy for a single minibatch: 72.00%
#
#
# Epoch 8, Iteration 55
# Train Set Loss: 9.55
# Test Set Loss: 10.00
# Train set accuracy for a single minibatch: 65.00%
# Test set accuracy for a single minibatch: 67.00%
#
#
# Epoch 8, Iteration 60
# Train Set Loss: 9.68
# Test Set Loss: 8.80
# Train set accuracy for a single minibatch: 62.00%
# Test set accuracy for a single minibatch: 65.00%
#
#
# Epoch 8, Iteration 65
# Train Set Loss: 9.49
# Test Set Loss: 9.98
# Train set accuracy for a single minibatch: 65.00%
# Test set accuracy for a single minibatch: 62.00%
#
#
# Epoch 8, Iteration 70
# Train Set Loss: 9.15
# Test Set Loss: 9.31
# Train set accuracy for a single minibatch: 68.00%
# Test set accuracy for a single minibatch: 70.00%
#
#
# Epoch 8, Iteration 75
# Train Set Loss: 9.57
# Test Set Loss: 9.10
# Train set accuracy for a single minibatch: 70.00%
# Test set accuracy for a single minibatch: 62.00%
#
#
# Epoch 8, Iteration 80
# Train Set Loss: 8.68
# Test Set Loss: 9.25
# Train set accuracy for a single minibatch: 63.00%
# Test set accuracy for a single minibatch: 64.00%
#
#
# Epoch 8, Iteration 85
# Train Set Loss: 9.12
# Test Set Loss: 9.53
# Train set accuracy for a single minibatch: 68.00%
# Test set accuracy for a single minibatch: 70.00%
#
#
# Epoch 8, Iteration 90
# Train Set Loss: 9.85
# Test Set Loss: 9.06
# Train set accuracy for a single minibatch: 64.00%
# Test set accuracy for a single minibatch: 73.00%
#
#
# Epoch 9, Iteration 0
# Train Set Loss: 10.14
# Test Set Loss: 9.61
# Train set accuracy for a single minibatch: 56.00%
# Test set accuracy for a single minibatch: 66.00%
#
#
# Epoch 9, Iteration 5
# Train Set Loss: 9.22
# Test Set Loss: 10.33
# Train set accuracy for a single minibatch: 66.00%
# Test set accuracy for a single minibatch: 62.00%
#
#
# Epoch 9, Iteration 10
# Train Set Loss: 10.22
# Test Set Loss: 9.26
# Train set accuracy for a single minibatch: 63.00%
# Test set accuracy for a single minibatch: 68.00%
#
#
# Epoch 9, Iteration 15
# Train Set Loss: 9.47
# Test Set Loss: 9.07
# Train set accuracy for a single minibatch: 65.00%
# Test set accuracy for a single minibatch: 69.00%
#
#
# Epoch 9, Iteration 20
# Train Set Loss: 9.18
# Test Set Loss: 9.13
# Train set accuracy for a single minibatch: 65.00%
# Test set accuracy for a single minibatch: 68.00%
#
#
# Epoch 9, Iteration 25
# Train Set Loss: 9.38
# Test Set Loss: 9.25
# Train set accuracy for a single minibatch: 59.00%
# Test set accuracy for a single minibatch: 64.00%
#
#
# Epoch 9, Iteration 30
# Train Set Loss: 8.96
# Test Set Loss: 10.02
# Train set accuracy for a single minibatch: 70.00%
# Test set accuracy for a single minibatch: 59.00%
#
#
# Epoch 9, Iteration 35
# Train Set Loss: 9.77
# Test Set Loss: 8.85
# Train set accuracy for a single minibatch: 57.00%
# Test set accuracy for a single minibatch: 67.00%
#
#
# Epoch 9, Iteration 40
# Train Set Loss: 9.73
# Test Set Loss: 8.58
# Train set accuracy for a single minibatch: 63.00%
# Test set accuracy for a single minibatch: 69.00%
#
#
# Epoch 9, Iteration 45
# Train Set Loss: 9.93
# Test Set Loss: 9.03
# Train set accuracy for a single minibatch: 68.00%
# Test set accuracy for a single minibatch: 69.00%
#
#
# Epoch 9, Iteration 50
# Train Set Loss: 9.70
# Test Set Loss: 9.73
# Train set accuracy for a single minibatch: 61.00%
# Test set accuracy for a single minibatch: 56.00%
#
#
# Epoch 9, Iteration 55
# Train Set Loss: 8.76
# Test Set Loss: 9.39
# Train set accuracy for a single minibatch: 70.00%
# Test set accuracy for a single minibatch: 60.00%
#
#
# Epoch 9, Iteration 60
# Train Set Loss: 9.10
# Test Set Loss: 8.46
# Train set accuracy for a single minibatch: 64.00%
# Test set accuracy for a single minibatch: 76.00%
#
#
# Epoch 9, Iteration 65
# Train Set Loss: 8.61
# Test Set Loss: 9.06
# Train set accuracy for a single minibatch: 73.00%
# Test set accuracy for a single minibatch: 67.00%
#
#
# Epoch 9, Iteration 70
# Train Set Loss: 9.80
# Test Set Loss: 9.49
# Train set accuracy for a single minibatch: 67.00%
# Test set accuracy for a single minibatch: 66.00%
#
#
# Epoch 9, Iteration 75
# Train Set Loss: 9.84
# Test Set Loss: 9.78
# Train set accuracy for a single minibatch: 68.00%
# Test set accuracy for a single minibatch: 67.00%
#
#
# Epoch 9, Iteration 80
# Train Set Loss: 8.74
# Test Set Loss: 9.31
# Train set accuracy for a single minibatch: 81.00%
# Test set accuracy for a single minibatch: 66.00%
#
#
# Epoch 9, Iteration 85
# Train Set Loss: 8.89
# Test Set Loss: 9.12
# Train set accuracy for a single minibatch: 70.00%
# Test set accuracy for a single minibatch: 72.00%
#
#
# Epoch 9, Iteration 90
# Train Set Loss: 9.82
# Test Set Loss: 10.52
# Train set accuracy for a single minibatch: 68.00%
# Test set accuracy for a single minibatch: 61.00%
#
#
# Epoch 10, Iteration 0
# Train Set Loss: 9.40
# Test Set Loss: 9.02
# Train set accuracy for a single minibatch: 70.00%
# Test set accuracy for a single minibatch: 65.00%
#
#
# Epoch 10, Iteration 5
# Train Set Loss: 8.94
# Test Set Loss: 9.56
# Train set accuracy for a single minibatch: 71.00%
# Test set accuracy for a single minibatch: 61.00%
#
#
# Epoch 10, Iteration 10
# Train Set Loss: 8.92
# Test Set Loss: 10.21
# Train set accuracy for a single minibatch: 63.00%
# Test set accuracy for a single minibatch: 62.00%
#
#
# Epoch 10, Iteration 15
# Train Set Loss: 9.12
# Test Set Loss: 10.24
# Train set accuracy for a single minibatch: 65.00%
# Test set accuracy for a single minibatch: 60.00%
#
#
# Epoch 10, Iteration 20
# Train Set Loss: 9.84
# Test Set Loss: 8.75
# Train set accuracy for a single minibatch: 65.00%
# Test set accuracy for a single minibatch: 70.00%
#
#
# Epoch 10, Iteration 25
# Train Set Loss: 9.09
# Test Set Loss: 9.30
# Train set accuracy for a single minibatch: 67.00%
# Test set accuracy for a single minibatch: 57.00%
#
#
# Epoch 10, Iteration 30
# Train Set Loss: 8.66
# Test Set Loss: 8.88
# Train set accuracy for a single minibatch: 70.00%
# Test set accuracy for a single minibatch: 68.00%
#
#
# Epoch 10, Iteration 35
# Train Set Loss: 8.98
# Test Set Loss: 9.28
# Train set accuracy for a single minibatch: 71.00%
# Test set accuracy for a single minibatch: 64.00%
#
#
# Epoch 10, Iteration 40
# Train Set Loss: 9.13
# Test Set Loss: 8.70
# Train set accuracy for a single minibatch: 67.00%
# Test set accuracy for a single minibatch: 72.00%
#
#
# Epoch 10, Iteration 45
# Train Set Loss: 8.66
# Test Set Loss: 9.28
# Train set accuracy for a single minibatch: 65.00%
# Test set accuracy for a single minibatch: 72.00%
#
#
# Epoch 10, Iteration 50
# Train Set Loss: 9.72
# Test Set Loss: 8.13
# Train set accuracy for a single minibatch: 60.00%
# Test set accuracy for a single minibatch: 79.00%
#
#
# Epoch 10, Iteration 55
# Train Set Loss: 8.45
# Test Set Loss: 8.92
# Train set accuracy for a single minibatch: 71.00%
# Test set accuracy for a single minibatch: 69.00%
#
#
# Epoch 10, Iteration 60
# Train Set Loss: 9.66
# Test Set Loss: 9.37
# Train set accuracy for a single minibatch: 66.00%
# Test set accuracy for a single minibatch: 68.00%
#
#
# Epoch 10, Iteration 65
# Train Set Loss: 9.54
# Test Set Loss: 9.32
# Train set accuracy for a single minibatch: 62.00%
# Test set accuracy for a single minibatch: 67.00%
#
#
# Epoch 10, Iteration 70
# Train Set Loss: 8.28
# Test Set Loss: 9.44
# Train set accuracy for a single minibatch: 73.00%
# Test set accuracy for a single minibatch: 69.00%
#
#
# Epoch 10, Iteration 75
# Train Set Loss: 8.94
# Test Set Loss: 9.26
# Train set accuracy for a single minibatch: 67.00%
# Test set accuracy for a single minibatch: 70.00%
#
#
# Epoch 10, Iteration 80
# Train Set Loss: 9.62
# Test Set Loss: 9.30
# Train set accuracy for a single minibatch: 65.00%
# Test set accuracy for a single minibatch: 61.00%
#
#
# Epoch 10, Iteration 85
# Train Set Loss: 10.54
# Test Set Loss: 8.81
# Train set accuracy for a single minibatch: 66.00%
# Test set accuracy for a single minibatch: 73.00%
#
#
# Epoch 10, Iteration 90
# Train Set Loss: 10.04
# Test Set Loss: 9.10
# Train set accuracy for a single minibatch: 66.00%
# Test set accuracy for a single minibatch: 67.00%
#
#
# Epoch 11, Iteration 0
# Train Set Loss: 8.49
# Test Set Loss: 9.66
# Train set accuracy for a single minibatch: 74.00%
# Test set accuracy for a single minibatch: 66.00%
#
#
# Epoch 11, Iteration 5
# Train Set Loss: 8.88
# Test Set Loss: 8.65
# Train set accuracy for a single minibatch: 62.00%
# Test set accuracy for a single minibatch: 72.00%
#
#
# Epoch 11, Iteration 10
# Train Set Loss: 9.73
# Test Set Loss: 9.19
# Train set accuracy for a single minibatch: 59.00%
# Test set accuracy for a single minibatch: 65.00%
#
#
# Epoch 11, Iteration 15
# Train Set Loss: 8.90
# Test Set Loss: 8.94
# Train set accuracy for a single minibatch: 68.00%
# Test set accuracy for a single minibatch: 70.00%
#
#
# Epoch 11, Iteration 20
# Train Set Loss: 10.54
# Test Set Loss: 9.17
# Train set accuracy for a single minibatch: 54.00%
# Test set accuracy for a single minibatch: 59.00%
#
#
# Epoch 11, Iteration 25
# Train Set Loss: 9.37
# Test Set Loss: 9.03
# Train set accuracy for a single minibatch: 62.00%
# Test set accuracy for a single minibatch: 66.00%
#
#
# Epoch 11, Iteration 30
# Train Set Loss: 9.19
# Test Set Loss: 9.63
# Train set accuracy for a single minibatch: 67.00%
# Test set accuracy for a single minibatch: 61.00%
#
#
# Epoch 11, Iteration 35
# Train Set Loss: 8.13
# Test Set Loss: 8.45
# Train set accuracy for a single minibatch: 76.00%
# Test set accuracy for a single minibatch: 73.00%
#
#
# Epoch 11, Iteration 40
# Train Set Loss: 10.23
# Test Set Loss: 9.14
# Train set accuracy for a single minibatch: 60.00%
# Test set accuracy for a single minibatch: 62.00%
#
#
# Epoch 11, Iteration 45
# Train Set Loss: 8.64
# Test Set Loss: 8.98
# Train set accuracy for a single minibatch: 68.00%
# Test set accuracy for a single minibatch: 69.00%
#
#
# Epoch 11, Iteration 50
# Train Set Loss: 8.50
# Test Set Loss: 9.14
# Train set accuracy for a single minibatch: 72.00%
# Test set accuracy for a single minibatch: 66.00%
#
#
# Epoch 11, Iteration 55
# Train Set Loss: 9.76
# Test Set Loss: 9.52
# Train set accuracy for a single minibatch: 55.00%
# Test set accuracy for a single minibatch: 68.00%
#
#
# Epoch 11, Iteration 60
# Train Set Loss: 9.35
# Test Set Loss: 9.47
# Train set accuracy for a single minibatch: 60.00%
# Test set accuracy for a single minibatch: 67.00%
#
#
# Epoch 11, Iteration 65
# Train Set Loss: 7.99
# Test Set Loss: 9.21
# Train set accuracy for a single minibatch: 78.00%
# Test set accuracy for a single minibatch: 62.00%
#
#
# Epoch 11, Iteration 70
# Train Set Loss: 9.17
# Test Set Loss: 10.24
# Train set accuracy for a single minibatch: 63.00%
# Test set accuracy for a single minibatch: 61.00%
#
#
# Epoch 11, Iteration 75
# Train Set Loss: 9.26
# Test Set Loss: 9.45
# Train set accuracy for a single minibatch: 66.00%
# Test set accuracy for a single minibatch: 63.00%
#
#
# Epoch 11, Iteration 80
# Train Set Loss: 9.47
# Test Set Loss: 9.30
# Train set accuracy for a single minibatch: 54.00%
# Test set accuracy for a single minibatch: 63.00%
#
#
# Epoch 11, Iteration 85
# Train Set Loss: 9.18
# Test Set Loss: 8.46
# Train set accuracy for a single minibatch: 65.00%
# Test set accuracy for a single minibatch: 69.00%
#
#
# Epoch 11, Iteration 90
# Train Set Loss: 9.20
# Test Set Loss: 8.72
# Train set accuracy for a single minibatch: 69.00%
# Test set accuracy for a single minibatch: 73.00%
#
#
# Epoch 12, Iteration 0
# Train Set Loss: 9.34
# Test Set Loss: 9.16
# Train set accuracy for a single minibatch: 67.00%
# Test set accuracy for a single minibatch: 65.00%
#
#
# Epoch 12, Iteration 5
# Train Set Loss: 9.01
# Test Set Loss: 8.77
# Train set accuracy for a single minibatch: 70.00%
# Test set accuracy for a single minibatch: 65.00%
#
#
# Epoch 12, Iteration 10
# Train Set Loss: 9.85
# Test Set Loss: 9.40
# Train set accuracy for a single minibatch: 61.00%
# Test set accuracy for a single minibatch: 62.00%
#
#
# Epoch 12, Iteration 15
# Train Set Loss: 9.00
# Test Set Loss: 7.83
# Train set accuracy for a single minibatch: 60.00%
# Test set accuracy for a single minibatch: 75.00%
#
#
# Epoch 12, Iteration 20
# Train Set Loss: 9.84
# Test Set Loss: 9.13
# Train set accuracy for a single minibatch: 71.00%
# Test set accuracy for a single minibatch: 67.00%
#
#
# Epoch 12, Iteration 25
# Train Set Loss: 8.49
# Test Set Loss: 9.16
# Train set accuracy for a single minibatch: 72.00%
# Test set accuracy for a single minibatch: 67.00%
#
#
# Epoch 12, Iteration 30
# Train Set Loss: 9.46
# Test Set Loss: 9.03
# Train set accuracy for a single minibatch: 60.00%
# Test set accuracy for a single minibatch: 71.00%
#
#
# Epoch 12, Iteration 35
# Train Set Loss: 9.69
# Test Set Loss: 8.34
# Train set accuracy for a single minibatch: 58.00%
# Test set accuracy for a single minibatch: 71.00%
#
#
# Epoch 12, Iteration 40
# Train Set Loss: 8.28
# Test Set Loss: 9.01
# Train set accuracy for a single minibatch: 76.00%
# Test set accuracy for a single minibatch: 68.00%
#
#
# Epoch 12, Iteration 45
# Train Set Loss: 9.09
# Test Set Loss: 8.88
# Train set accuracy for a single minibatch: 60.00%
# Test set accuracy for a single minibatch: 65.00%
#
#
# Epoch 12, Iteration 50
# Train Set Loss: 9.07
# Test Set Loss: 9.70
# Train set accuracy for a single minibatch: 67.00%
# Test set accuracy for a single minibatch: 67.00%
#
#
# Epoch 12, Iteration 55
# Train Set Loss: 9.18
# Test Set Loss: 8.69
# Train set accuracy for a single minibatch: 62.00%
# Test set accuracy for a single minibatch: 65.00%
#
#
# Epoch 12, Iteration 60
# Train Set Loss: 9.38
# Test Set Loss: 9.33
# Train set accuracy for a single minibatch: 63.00%
# Test set accuracy for a single minibatch: 69.00%
#
#
# Epoch 12, Iteration 65
# Train Set Loss: 8.53
# Test Set Loss: 8.89
# Train set accuracy for a single minibatch: 67.00%
# Test set accuracy for a single minibatch: 64.00%
#
#
# Epoch 12, Iteration 70
# Train Set Loss: 9.02
# Test Set Loss: 10.38
# Train set accuracy for a single minibatch: 68.00%
# Test set accuracy for a single minibatch: 53.00%
#
#
# Epoch 12, Iteration 75
# Train Set Loss: 8.27
# Test Set Loss: 7.97
# Train set accuracy for a single minibatch: 76.00%
# Test set accuracy for a single minibatch: 73.00%
#
#
# Epoch 12, Iteration 80
# Train Set Loss: 8.32
# Test Set Loss: 9.59
# Train set accuracy for a single minibatch: 69.00%
# Test set accuracy for a single minibatch: 61.00%
#
#
# Epoch 12, Iteration 85
# Train Set Loss: 10.03
# Test Set Loss: 9.04
# Train set accuracy for a single minibatch: 56.00%
# Test set accuracy for a single minibatch: 61.00%
#
#
# Epoch 12, Iteration 90
# Train Set Loss: 8.53
# Test Set Loss: 8.35
# Train set accuracy for a single minibatch: 71.00%
# Test set accuracy for a single minibatch: 72.00%
#
#
# Epoch 13, Iteration 0
# Train Set Loss: 8.02
# Test Set Loss: 9.47
# Train set accuracy for a single minibatch: 74.00%
# Test set accuracy for a single minibatch: 64.00%
#
#
# Epoch 13, Iteration 5
# Train Set Loss: 10.37
# Test Set Loss: 9.49
# Train set accuracy for a single minibatch: 59.00%
# Test set accuracy for a single minibatch: 68.00%
#
#
# Epoch 13, Iteration 10
# Train Set Loss: 10.32
# Test Set Loss: 9.37
# Train set accuracy for a single minibatch: 60.00%
# Test set accuracy for a single minibatch: 70.00%
#
#
# Epoch 13, Iteration 15
# Train Set Loss: 9.88
# Test Set Loss: 9.20
# Train set accuracy for a single minibatch: 63.00%
# Test set accuracy for a single minibatch: 64.00%
#
#
# Epoch 13, Iteration 20
# Train Set Loss: 9.45
# Test Set Loss: 9.28
# Train set accuracy for a single minibatch: 68.00%
# Test set accuracy for a single minibatch: 63.00%
#
#
# Epoch 13, Iteration 25
# Train Set Loss: 8.82
# Test Set Loss: 9.90
# Train set accuracy for a single minibatch: 64.00%
# Test set accuracy for a single minibatch: 59.00%
#
#
# Epoch 13, Iteration 30
# Train Set Loss: 8.44
# Test Set Loss: 8.79
# Train set accuracy for a single minibatch: 74.00%
# Test set accuracy for a single minibatch: 69.00%
#
#
# Epoch 13, Iteration 35
# Train Set Loss: 8.71
# Test Set Loss: 9.17
# Train set accuracy for a single minibatch: 69.00%
# Test set accuracy for a single minibatch: 66.00%
#
#
# Epoch 13, Iteration 40
# Train Set Loss: 8.93
# Test Set Loss: 9.66
# Train set accuracy for a single minibatch: 65.00%
# Test set accuracy for a single minibatch: 56.00%
#
#
# Epoch 13, Iteration 45
# Train Set Loss: 8.60
# Test Set Loss: 8.47
# Train set accuracy for a single minibatch: 78.00%
# Test set accuracy for a single minibatch: 75.00%
#
#
# Epoch 13, Iteration 50
# Train Set Loss: 9.12
# Test Set Loss: 8.33
# Train set accuracy for a single minibatch: 70.00%
# Test set accuracy for a single minibatch: 69.00%
#
#
# Epoch 13, Iteration 55
# Train Set Loss: 9.03
# Test Set Loss: 9.79
# Train set accuracy for a single minibatch: 61.00%
# Test set accuracy for a single minibatch: 68.00%
#
#
# Epoch 13, Iteration 60
# Train Set Loss: 9.34
# Test Set Loss: 8.91
# Train set accuracy for a single minibatch: 61.00%
# Test set accuracy for a single minibatch: 71.00%
#
#
# Epoch 13, Iteration 65
# Train Set Loss: 9.37
# Test Set Loss: 9.57
# Train set accuracy for a single minibatch: 64.00%
# Test set accuracy for a single minibatch: 67.00%
#
#
# Epoch 13, Iteration 70
# Train Set Loss: 9.76
# Test Set Loss: 10.07
# Train set accuracy for a single minibatch: 62.00%
# Test set accuracy for a single minibatch: 67.00%
#
#
# Epoch 13, Iteration 75
# Train Set Loss: 8.64
# Test Set Loss: 9.51
# Train set accuracy for a single minibatch: 66.00%
# Test set accuracy for a single minibatch: 69.00%
#
#
# Epoch 13, Iteration 80
# Train Set Loss: 8.54
# Test Set Loss: 9.42
# Train set accuracy for a single minibatch: 64.00%
# Test set accuracy for a single minibatch: 67.00%
#
#
# Epoch 13, Iteration 85
# Train Set Loss: 8.89
# Test Set Loss: 9.24
# Train set accuracy for a single minibatch: 64.00%
# Test set accuracy for a single minibatch: 64.00%
#
#
# Epoch 13, Iteration 90
# Train Set Loss: 9.15
# Test Set Loss: 8.77
# Train set accuracy for a single minibatch: 69.00%
# Test set accuracy for a single minibatch: 66.00%
#
#
# Epoch 14, Iteration 0
# Train Set Loss: 8.32
# Test Set Loss: 8.40
# Train set accuracy for a single minibatch: 70.00%
# Test set accuracy for a single minibatch: 70.00%
#
#
# Epoch 14, Iteration 5
# Train Set Loss: 9.09
# Test Set Loss: 9.56
# Train set accuracy for a single minibatch: 66.00%
# Test set accuracy for a single minibatch: 66.00%
#
#
# Epoch 14, Iteration 10
# Train Set Loss: 9.04
# Test Set Loss: 9.16
# Train set accuracy for a single minibatch: 68.00%
# Test set accuracy for a single minibatch: 68.00%
#
#
# Epoch 14, Iteration 15
# Train Set Loss: 8.44
# Test Set Loss: 8.98
# Train set accuracy for a single minibatch: 72.00%
# Test set accuracy for a single minibatch: 65.00%
#
#
# Epoch 14, Iteration 20
# Train Set Loss: 8.85
# Test Set Loss: 9.64
# Train set accuracy for a single minibatch: 78.00%
# Test set accuracy for a single minibatch: 65.00%
#
#
# Epoch 14, Iteration 25
# Train Set Loss: 7.97
# Test Set Loss: 9.00
# Train set accuracy for a single minibatch: 76.00%
# Test set accuracy for a single minibatch: 69.00%
#
#
# Epoch 14, Iteration 30
# Train Set Loss: 8.91
# Test Set Loss: 9.71
# Train set accuracy for a single minibatch: 71.00%
# Test set accuracy for a single minibatch: 62.00%
#
#
# Epoch 14, Iteration 35
# Train Set Loss: 8.94
# Test Set Loss: 9.94
# Train set accuracy for a single minibatch: 61.00%
# Test set accuracy for a single minibatch: 57.00%
#
#
# Epoch 14, Iteration 40
# Train Set Loss: 8.33
# Test Set Loss: 8.98
# Train set accuracy for a single minibatch: 72.00%
# Test set accuracy for a single minibatch: 65.00%
#
#
# Epoch 14, Iteration 45
# Train Set Loss: 8.72
# Test Set Loss: 9.05
# Train set accuracy for a single minibatch: 69.00%
# Test set accuracy for a single minibatch: 68.00%
#
#
# Epoch 14, Iteration 50
# Train Set Loss: 8.52
# Test Set Loss: 9.14
# Train set accuracy for a single minibatch: 67.00%
# Test set accuracy for a single minibatch: 64.00%
#
#
# Epoch 14, Iteration 55
# Train Set Loss: 9.54
# Test Set Loss: 8.23
# Train set accuracy for a single minibatch: 63.00%
# Test set accuracy for a single minibatch: 69.00%
#
#
# Epoch 14, Iteration 60
# Train Set Loss: 8.67
# Test Set Loss: 9.00
# Train set accuracy for a single minibatch: 64.00%
# Test set accuracy for a single minibatch: 60.00%
#
#
# Epoch 14, Iteration 65
# Train Set Loss: 9.32
# Test Set Loss: 9.01
# Train set accuracy for a single minibatch: 59.00%
# Test set accuracy for a single minibatch: 71.00%
#
#
# Epoch 14, Iteration 70
# Train Set Loss: 9.05
# Test Set Loss: 9.04
# Train set accuracy for a single minibatch: 67.00%
# Test set accuracy for a single minibatch: 65.00%
#
#
# Epoch 14, Iteration 75
# Train Set Loss: 8.61
# Test Set Loss: 9.25
# Train set accuracy for a single minibatch: 67.00%
# Test set accuracy for a single minibatch: 65.00%
#
#
# Epoch 14, Iteration 80
# Train Set Loss: 9.13
# Test Set Loss: 9.40
# Train set accuracy for a single minibatch: 66.00%
# Test set accuracy for a single minibatch: 66.00%
#
#
# Epoch 14, Iteration 85
# Train Set Loss: 9.16
# Test Set Loss: 8.59
# Train set accuracy for a single minibatch: 62.00%
# Test set accuracy for a single minibatch: 62.00%
#
#
# Epoch 14, Iteration 90
# Train Set Loss: 9.62
# Test Set Loss: 8.77
# Train set accuracy for a single minibatch: 61.00%
# Test set accuracy for a single minibatch: 65.00%
#
#
# Epoch 15, Iteration 0
# Train Set Loss: 8.57
# Test Set Loss: 9.62
# Train set accuracy for a single minibatch: 72.00%
# Test set accuracy for a single minibatch: 67.00%
#
#
# Epoch 15, Iteration 5
# Train Set Loss: 8.87
# Test Set Loss: 9.43
# Train set accuracy for a single minibatch: 70.00%
# Test set accuracy for a single minibatch: 60.00%
#
#
# Epoch 15, Iteration 10
# Train Set Loss: 9.34
# Test Set Loss: 8.63
# Train set accuracy for a single minibatch: 61.00%
# Test set accuracy for a single minibatch: 71.00%
#
#
# Epoch 15, Iteration 15
# Train Set Loss: 9.44
# Test Set Loss: 9.01
# Train set accuracy for a single minibatch: 64.00%
# Test set accuracy for a single minibatch: 58.00%
#
#
# Epoch 15, Iteration 20
# Train Set Loss: 9.62
# Test Set Loss: 8.93
# Train set accuracy for a single minibatch: 71.00%
# Test set accuracy for a single minibatch: 60.00%
#
#
# Epoch 15, Iteration 25
# Train Set Loss: 8.38
# Test Set Loss: 8.99
# ...
# Test set accuracy for a single minibatch: 92.00%
#
#
# Epoch 114, Iteration 90
# Train Set Loss: 5.02
# Test Set Loss: 4.94
# Train set accuracy for a single minibatch: 91.00%
# Test set accuracy for a single minibatch: 90.00%
#
#
# Epoch 115, Iteration 0
# Train Set Loss: 5.20
# Test Set Loss: 5.48
# Train set accuracy for a single minibatch: 92.00%
# Test set accuracy for a single minibatch: 89.00%
#
#
# Epoch 115, Iteration 5
# Train Set Loss: 5.32
# Test Set Loss: 4.72
# Train set accuracy for a single minibatch: 90.00%
# Test set accuracy for a single minibatch: 90.00%
#
#
# Epoch 115, Iteration 10
# Train Set Loss: 4.54
# Test Set Loss: 5.27
# Train set accuracy for a single minibatch: 90.00%
# Test set accuracy for a single minibatch: 85.00%
#
#
# Epoch 115, Iteration 15
# Train Set Loss: 4.72
# Test Set Loss: 4.99
# Train set accuracy for a single minibatch: 97.00%
# Test set accuracy for a single minibatch: 87.00%
#
#
# Epoch 115, Iteration 20
# Train Set Loss: 5.06
# Test Set Loss: 5.25
# Train set accuracy for a single minibatch: 93.00%
# Test set accuracy for a single minibatch: 90.00%
#
#
# Epoch 115, Iteration 25
# Train Set Loss: 5.02
# Test Set Loss: 4.76
# Train set accuracy for a single minibatch: 94.00%
# Test set accuracy for a single minibatch: 93.00%
#
#
# Epoch 115, Iteration 30
# Train Set Loss: 4.68
# Test Set Loss: 5.13
# Train set accuracy for a single minibatch: 84.00%
# Test set accuracy for a single minibatch: 87.00%
#
#
# Epoch 115, Iteration 35
# Train Set Loss: 5.58
# Test Set Loss: 4.45
# Train set accuracy for a single minibatch: 95.00%
# Test set accuracy for a single minibatch: 94.00%
#
#
# Epoch 115, Iteration 40
# Train Set Loss: 4.81
# Test Set Loss: 4.70
# Train set accuracy for a single minibatch: 92.00%
# Test set accuracy for a single minibatch: 90.00%
#
#
# Epoch 115, Iteration 45
# Train Set Loss: 4.68
# Test Set Loss: 5.06
# Train set accuracy for a single minibatch: 92.00%
# Test set accuracy for a single minibatch: 93.00%
#
#
# Epoch 115, Iteration 50
# Train Set Loss: 5.00
# Test Set Loss: 5.31
# Train set accuracy for a single minibatch: 92.00%
# Test set accuracy for a single minibatch: 90.00%
#
#
# Epoch 115, Iteration 55
# Train Set Loss: 4.99
# Test Set Loss: 5.45
# Train set accuracy for a single minibatch: 89.00%
# Test set accuracy for a single minibatch: 87.00%
#
#
# Epoch 115, Iteration 60
# Train Set Loss: 5.24
# Test Set Loss: 5.46
# Train set accuracy for a single minibatch: 90.00%
# Test set accuracy for a single minibatch: 90.00%
#
#
# Epoch 115, Iteration 65
# Train Set Loss: 5.47
# Test Set Loss: 5.56
# Train set accuracy for a single minibatch: 87.00%
# Test set accuracy for a single minibatch: 90.00%
#
#
# Epoch 115, Iteration 70
# Train Set Loss: 5.00
# Test Set Loss: 5.64
# Train set accuracy for a single minibatch: 91.00%
# Test set accuracy for a single minibatch: 88.00%
#
#
# Epoch 115, Iteration 75
# Train Set Loss: 4.87
# Test Set Loss: 5.11
# Train set accuracy for a single minibatch: 96.00%
# Test set accuracy for a single minibatch: 83.00%
#
#
# Epoch 115, Iteration 80
# Train Set Loss: 5.06
# Test Set Loss: 4.87
# Train set accuracy for a single minibatch: 93.00%
# Test set accuracy for a single minibatch: 95.00%
#
#
# Epoch 115, Iteration 85
# Train Set Loss: 4.85
# Test Set Loss: 5.10
# Train set accuracy for a single minibatch: 94.00%
# Test set accuracy for a single minibatch: 87.00%
#
#
# Epoch 115, Iteration 90
# Train Set Loss: 5.35
# Test Set Loss: 5.49
# Train set accuracy for a single minibatch: 94.00%
# Test set accuracy for a single minibatch: 92.00%
#
#
# Epoch 116, Iteration 0
# Train Set Loss: 4.76
# Test Set Loss: 4.84
# Train set accuracy for a single minibatch: 95.00%
# Test set accuracy for a single minibatch: 92.00%
#
#
# Epoch 116, Iteration 5
# Train Set Loss: 5.03
# Test Set Loss: 5.80
# Train set accuracy for a single minibatch: 92.00%
# Test set accuracy for a single minibatch: 90.00%
#
#
# Epoch 116, Iteration 10
# Train Set Loss: 5.10
# Test Set Loss: 4.97
# Train set accuracy for a single minibatch: 92.00%
# Test set accuracy for a single minibatch: 91.00%
#
#
# Epoch 116, Iteration 15
# Train Set Loss: 4.77
# Test Set Loss: 4.60
# Train set accuracy for a single minibatch: 96.00%
# Test set accuracy for a single minibatch: 96.00%
#
#
# Epoch 116, Iteration 20
# Train Set Loss: 5.10
# Test Set Loss: 4.91
# Train set accuracy for a single minibatch: 86.00%
# Test set accuracy for a single minibatch: 92.00%
#
#
# Epoch 116, Iteration 25
# Train Set Loss: 5.18
# Test Set Loss: 5.40
# Train set accuracy for a single minibatch: 89.00%
# Test set accuracy for a single minibatch: 95.00%
#
#
# Epoch 116, Iteration 30
# Train Set Loss: 5.78
# Test Set Loss: 5.04
# Train set accuracy for a single minibatch: 92.00%
# Test set accuracy for a single minibatch: 94.00%
#
#
# Epoch 116, Iteration 35
# Train Set Loss: 5.32
# Test Set Loss: 5.01
# Train set accuracy for a single minibatch: 93.00%
# Test set accuracy for a single minibatch: 93.00%
#
#
# Epoch 116, Iteration 40
# Train Set Loss: 5.30
# Test Set Loss: 5.03
# Train set accuracy for a single minibatch: 91.00%
# Test set accuracy for a single minibatch: 93.00%
#
#
# Epoch 116, Iteration 45
# Train Set Loss: 4.65
# Test Set Loss: 5.00
# Train set accuracy for a single minibatch: 98.00%
# Test set accuracy for a single minibatch: 95.00%
#
#
# Epoch 116, Iteration 50
# Train Set Loss: 4.91
# Test Set Loss: 5.24
# Train set accuracy for a single minibatch: 92.00%
# Test set accuracy for a single minibatch: 94.00%
#
#
# Epoch 116, Iteration 55
# Train Set Loss: 4.82
# Test Set Loss: 4.66
# Train set accuracy for a single minibatch: 92.00%
# Test set accuracy for a single minibatch: 97.00%
#
#
# Epoch 116, Iteration 60
# Train Set Loss: 5.08
# Test Set Loss: 4.67
# Train set accuracy for a single minibatch: 89.00%
# Test set accuracy for a single minibatch: 90.00%
#
#
# Epoch 116, Iteration 65
# Train Set Loss: 5.08
# Test Set Loss: 4.79
# Train set accuracy for a single minibatch: 93.00%
# Test set accuracy for a single minibatch: 95.00%
#
#
# Epoch 116, Iteration 70
# Train Set Loss: 5.63
# Test Set Loss: 4.76
# Train set accuracy for a single minibatch: 88.00%
# Test set accuracy for a single minibatch: 92.00%
#
#
# Epoch 116, Iteration 75
# Train Set Loss: 4.98
# Test Set Loss: 4.95
# Train set accuracy for a single minibatch: 92.00%
# Test set accuracy for a single minibatch: 94.00%
#
#
# Epoch 116, Iteration 80
# Train Set Loss: 4.82
# Test Set Loss: 4.58
# Train set accuracy for a single minibatch: 95.00%
# Test set accuracy for a single minibatch: 92.00%
#
#
# Epoch 116, Iteration 85
# Train Set Loss: 5.50
# Test Set Loss: 4.76
# Train set accuracy for a single minibatch: 95.00%
# Test set accuracy for a single minibatch: 94.00%
#
#
# Epoch 116, Iteration 90
# Train Set Loss: 5.21
# Test Set Loss: 5.29
# Train set accuracy for a single minibatch: 87.00%
# Test set accuracy for a single minibatch: 93.00%
#
#
# Epoch 117, Iteration 0
# Train Set Loss: 5.20
# Test Set Loss: 4.65
# Train set accuracy for a single minibatch: 92.00%
# Test set accuracy for a single minibatch: 90.00%
#
#
# Epoch 117, Iteration 5
# Train Set Loss: 5.01
# Test Set Loss: 5.52
# Train set accuracy for a single minibatch: 92.00%
# Test set accuracy for a single minibatch: 87.00%
#
#
# Epoch 117, Iteration 10
# Train Set Loss: 4.89
# Test Set Loss: 5.86
# Train set accuracy for a single minibatch: 90.00%
# Test set accuracy for a single minibatch: 87.00%
#
#
# Epoch 117, Iteration 15
# Train Set Loss: 4.81
# Test Set Loss: 4.79
# Train set accuracy for a single minibatch: 92.00%
# Test set accuracy for a single minibatch: 96.00%
#
#
# Epoch 117, Iteration 20
# Train Set Loss: 4.58
# Test Set Loss: 6.33
# Train set accuracy for a single minibatch: 95.00%
# Test set accuracy for a single minibatch: 92.00%
#
#
# Epoch 117, Iteration 25
# Train Set Loss: 4.85
# Test Set Loss: 5.26
# Train set accuracy for a single minibatch: 93.00%
# Test set accuracy for a single minibatch: 95.00%
#
#
# Epoch 117, Iteration 30
# Train Set Loss: 5.68
# Test Set Loss: 4.64
# Train set accuracy for a single minibatch: 93.00%
# Test set accuracy for a single minibatch: 94.00%
#
#
# Epoch 117, Iteration 35
# Train Set Loss: 5.28
# Test Set Loss: 5.16
# Train set accuracy for a single minibatch: 93.00%
# Test set accuracy for a single minibatch: 94.00%
#
#
# Epoch 117, Iteration 40
# Train Set Loss: 4.83
# Test Set Loss: 4.60
# Train set accuracy for a single minibatch: 94.00%
# Test set accuracy for a single minibatch: 96.00%
#
#
# Epoch 117, Iteration 45
# Train Set Loss: 4.79
# Test Set Loss: 4.91
# Train set accuracy for a single minibatch: 91.00%
# Test set accuracy for a single minibatch: 93.00%
#
#
# Epoch 117, Iteration 50
# Train Set Loss: 4.77
# Test Set Loss: 6.04
# Train set accuracy for a single minibatch: 96.00%
# Test set accuracy for a single minibatch: 87.00%
#
#
# Epoch 117, Iteration 55
# Train Set Loss: 6.04
# Test Set Loss: 5.36
# Train set accuracy for a single minibatch: 90.00%
# Test set accuracy for a single minibatch: 87.00%
#
#
# Epoch 117, Iteration 60
# Train Set Loss: 5.36
# Test Set Loss: 4.63
# Train set accuracy for a single minibatch: 91.00%
# Test set accuracy for a single minibatch: 92.00%
#
#
# Epoch 117, Iteration 65
# Train Set Loss: 4.90
# Test Set Loss: 5.01
# Train set accuracy for a single minibatch: 91.00%
# Test set accuracy for a single minibatch: 92.00%
#
#
# Epoch 117, Iteration 70
# Train Set Loss: 4.87
# Test Set Loss: 4.99
# Train set accuracy for a single minibatch: 89.00%
# Test set accuracy for a single minibatch: 96.00%
#
#
# Epoch 117, Iteration 75
# Train Set Loss: 5.61
# Test Set Loss: 4.82
# Train set accuracy for a single minibatch: 86.00%
# Test set accuracy for a single minibatch: 93.00%
#
#
# Epoch 117, Iteration 80
# Train Set Loss: 5.03
# Test Set Loss: 4.82
# Train set accuracy for a single minibatch: 96.00%
# Test set accuracy for a single minibatch: 92.00%
#
#
# Epoch 117, Iteration 85
# Train Set Loss: 4.92
# Test Set Loss: 5.28
# Train set accuracy for a single minibatch: 96.00%
# Test set accuracy for a single minibatch: 89.00%
#
#
# Epoch 117, Iteration 90
# Train Set Loss: 4.65
# Test Set Loss: 4.91
# Train set accuracy for a single minibatch: 96.00%
# Test set accuracy for a single minibatch: 95.00%
#
#
# Epoch 118, Iteration 0
# Train Set Loss: 4.76
# Test Set Loss: 5.07
# Train set accuracy for a single minibatch: 92.00%
# Test set accuracy for a single minibatch: 94.00%
#
#
# Epoch 118, Iteration 5
# Train Set Loss: 5.52
# Test Set Loss: 5.01
# Train set accuracy for a single minibatch: 91.00%
# Test set accuracy for a single minibatch: 91.00%
#
#
# Epoch 118, Iteration 10
# Train Set Loss: 4.65
# Test Set Loss: 4.94
# Train set accuracy for a single minibatch: 89.00%
# Test set accuracy for a single minibatch: 91.00%
#
#
# Epoch 118, Iteration 15
# Train Set Loss: 6.31
# Test Set Loss: 4.72
# Train set accuracy for a single minibatch: 91.00%
# Test set accuracy for a single minibatch: 93.00%
#
#
# Epoch 118, Iteration 20
# Train Set Loss: 5.21
# Test Set Loss: 4.61
# Train set accuracy for a single minibatch: 94.00%
# Test set accuracy for a single minibatch: 90.00%
#
#
# Epoch 118, Iteration 25
# Train Set Loss: 5.80
# Test Set Loss: 4.74
# Train set accuracy for a single minibatch: 91.00%
# Test set accuracy for a single minibatch: 92.00%
#
#
# Epoch 118, Iteration 30
# Train Set Loss: 4.90
# Test Set Loss: 4.94
# Train set accuracy for a single minibatch: 95.00%
# Test set accuracy for a single minibatch: 96.00%
#
#
# Epoch 118, Iteration 35
# Train Set Loss: 4.79
# Test Set Loss: 5.63
# Train set accuracy for a single minibatch: 94.00%
# Test set accuracy for a single minibatch: 92.00%
#
#
# Epoch 118, Iteration 40
# Train Set Loss: 5.00
# Test Set Loss: 4.98
# Train set accuracy for a single minibatch: 89.00%
# Test set accuracy for a single minibatch: 87.00%
#
#
# Epoch 118, Iteration 45
# Train Set Loss: 4.93
# Test Set Loss: 4.97
# Train set accuracy for a single minibatch: 92.00%
# Test set accuracy for a single minibatch: 88.00%
#
#
# Epoch 118, Iteration 50
# Train Set Loss: 4.60
# Test Set Loss: 4.75
# Train set accuracy for a single minibatch: 93.00%
# Test set accuracy for a single minibatch: 92.00%
#
#
# Epoch 118, Iteration 55
# Train Set Loss: 4.91
# Test Set Loss: 4.79
# Train set accuracy for a single minibatch: 88.00%
# Test set accuracy for a single minibatch: 89.00%
#
#
# Epoch 118, Iteration 60
# Train Set Loss: 4.98
# Test Set Loss: 5.02
# Train set accuracy for a single minibatch: 91.00%
# Test set accuracy for a single minibatch: 94.00%
#
#
# Epoch 118, Iteration 65
# Train Set Loss: 5.67
# Test Set Loss: 4.80
# Train set accuracy for a single minibatch: 86.00%
# Test set accuracy for a single minibatch: 92.00%
#
#
# Epoch 118, Iteration 70
# Train Set Loss: 5.18
# Test Set Loss: 4.72
# Train set accuracy for a single minibatch: 93.00%
# Test set accuracy for a single minibatch: 91.00%
#
#
# Epoch 118, Iteration 75
# Train Set Loss: 5.39
# Test Set Loss: 4.77
# Train set accuracy for a single minibatch: 91.00%
# Test set accuracy for a single minibatch: 98.00%
#
#
# Epoch 118, Iteration 80
# Train Set Loss: 5.71
# Test Set Loss: 5.00
# Train set accuracy for a single minibatch: 90.00%
# Test set accuracy for a single minibatch: 87.00%
#
#
# Epoch 118, Iteration 85
# Train Set Loss: 4.94
# Test Set Loss: 4.54
# Train set accuracy for a single minibatch: 91.00%
# Test set accuracy for a single minibatch: 94.00%
#
#
# Epoch 118, Iteration 90
# Train Set Loss: 5.10
# Test Set Loss: 4.65
# Train set accuracy for a single minibatch: 92.00%
# Test set accuracy for a single minibatch: 95.00%
#
#
# Epoch 119, Iteration 0
# Train Set Loss: 5.07
# Test Set Loss: 5.16
# Train set accuracy for a single minibatch: 91.00%
# Test set accuracy for a single minibatch: 94.00%
#
#
# Epoch 119, Iteration 5
# Train Set Loss: 5.24
# Test Set Loss: 4.81
# Train set accuracy for a single minibatch: 92.00%
# Test set accuracy for a single minibatch: 96.00%
#
#
# Epoch 119, Iteration 10
# Train Set Loss: 4.71
# Test Set Loss: 5.47
# Train set accuracy for a single minibatch: 97.00%
# Test set accuracy for a single minibatch: 88.00%
#
#
# Epoch 119, Iteration 15
# Train Set Loss: 4.91
# Test Set Loss: 5.34
# Train set accuracy for a single minibatch: 89.00%
# Test set accuracy for a single minibatch: 94.00%
#
#
# Epoch 119, Iteration 20
# Train Set Loss: 5.12
# Test Set Loss: 5.87
# Train set accuracy for a single minibatch: 91.00%
# Test set accuracy for a single minibatch: 90.00%
#
#
# Epoch 119, Iteration 25
# Train Set Loss: 5.26
# Test Set Loss: 5.05
# Train set accuracy for a single minibatch: 94.00%
# Test set accuracy for a single minibatch: 92.00%
#
#
# Epoch 119, Iteration 30
# Train Set Loss: 4.94
# Test Set Loss: 4.56
# Train set accuracy for a single minibatch: 93.00%
# Test set accuracy for a single minibatch: 94.00%
#
#
# Epoch 119, Iteration 35
# Train Set Loss: 5.22
# Test Set Loss: 4.91
# Train set accuracy for a single minibatch: 90.00%
# Test set accuracy for a single minibatch: 92.00%
#
#
# Epoch 119, Iteration 40
# Train Set Loss: 4.72
# Test Set Loss: 4.89
# Train set accuracy for a single minibatch: 89.00%
# Test set accuracy for a single minibatch: 91.00%
#
#
# Epoch 119, Iteration 45
# Train Set Loss: 4.85
# Test Set Loss: 4.76
# Train set accuracy for a single minibatch: 90.00%
# Test set accuracy for a single minibatch: 93.00%
#
#
# Epoch 119, Iteration 50
# Train Set Loss: 5.08
# Test Set Loss: 4.73
# Train set accuracy for a single minibatch: 87.00%
# Test set accuracy for a single minibatch: 92.00%
#
#
# Epoch 119, Iteration 55
# Train Set Loss: 5.38
# Test Set Loss: 4.79
# Train set accuracy for a single minibatch: 94.00%
# Test set accuracy for a single minibatch: 94.00%
#
#
# Epoch 119, Iteration 60
# Train Set Loss: 5.35
# Test Set Loss: 5.80
# Train set accuracy for a single minibatch: 88.00%
# Test set accuracy for a single minibatch: 88.00%
#
#
# Epoch 119, Iteration 65
# Train Set Loss: 5.15
# Test Set Loss: 5.04
# Train set accuracy for a single minibatch: 94.00%
# Test set accuracy for a single minibatch: 93.00%
#
#
# Epoch 119, Iteration 70
# Train Set Loss: 4.63
# Test Set Loss: 4.85
# Train set accuracy for a single minibatch: 99.00%
# Test set accuracy for a single minibatch: 95.00%
#
#
# Epoch 119, Iteration 75
# Train Set Loss: 5.32
# Test Set Loss: 5.15
# Train set accuracy for a single minibatch: 95.00%
# Test set accuracy for a single minibatch: 94.00%
#
#
# Epoch 119, Iteration 80
# Train Set Loss: 4.59
# Test Set Loss: 4.37
# Train set accuracy for a single minibatch: 92.00%
# Test set accuracy for a single minibatch: 96.00%
#
#
# Epoch 119, Iteration 85
# Train Set Loss: 5.00
# Test Set Loss: 5.10
# Train set accuracy for a single minibatch: 95.00%
# Test set accuracy for a single minibatch: 91.00%
#
#
# Epoch 119, Iteration 90
# Train Set Loss: 5.53
# Test Set Loss: 5.64
# Train set accuracy for a single minibatch: 89.00%
# Test set accuracy for a single minibatch: 93.00%

# %%
# Plot Loss
fig = plt.figure(facecolor="w", figsize=(10, 5))
plt.plot(loss_hist)
plt.plot(test_loss_hist)
plt.title("Loss Curves")
plt.legend(["Train Loss", "Test Loss"])
plt.ylabel("Loss")
plt.xlabel("Iterations")
plt.show()

# %%
fig = plt.figure(facecolor="w", figsize=(10, 5))
plt.plot(test_accuracy_data)
plt.plot(train_accuracy_data)
plt.title("Accuracy Cuve")
plt.legend(["Test accuracy", "Train accuracy"])
plt.ylabel("Accuracy")
plt.xlabel("Iterations")
plt.show()

# %%
total = 0
correct = 0

# drop_last switched to False to keep all samples
test_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True, drop_last=False)

with torch.no_grad():
  net.eval()
  for data, targets in test_loader:
    data = data.to(device)
    targets = targets.to(device)
    
    # forward pass
    test_spk, _ = net(data.view(data.size(0), -1))

    # calculate total accuracy
    _, predicted = test_spk.sum(dim=0).max(1)
    total += targets.size(0)
    correct += (predicted == targets).sum().item()

print(f"Total correctly classified test set : {correct}/{total}")
print(f"Test Set Accuracy: {100 * correct / total:.2f}%")
# Out:
# Total correctly classified test set : 8877/9500
# Test Set Accuracy: 93.44%

# %%
conf_matrix = confusion_matrix(targets, predicted)

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix*5, annot=True, fmt="d", cmap="Blues", cbar=False)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()

# %%
# Calculating specificity for each class
num_classes = len(conf_matrix)
specificity = np.zeros(num_classes)

for i in range(num_classes):
    # True negatives for the current class
    tn = np.sum(np.delete(np.delete(conf_matrix, i, axis=0), i, axis=1))
    
    # False positives for other classes
    fp = np.sum(np.delete(conf_matrix[i, :], i))
    
    # Specificity for the current class
    specificity[i] = tn / (tn + fp)

print("Confusion Matrix:")
print(conf_matrix)
print(specificity)
# Out:
# Confusion Matrix:
# [[36  0  0  0  0  0  0]
#  [ 0  8  0  0  0  1  0]
#  [ 0  0 16  0  0  0  0]
#  [ 4  0  0  4  0  0  0]
#  [ 0  0  0  1 19  0  0]
#  [ 0  0  0  0  0  6  0]
#  [ 0  0  0  1  0  0  4]]
# [1.         0.98913043 1.         0.95744681 0.98765432 1.
#  0.98958333]
