# %%
import numpy as np
import snntorch as snn
import torch
from snntorch import spikegen
from snntorch import utils
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from torch.utils.data import TensorDataset, DataLoader

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

from snntorch import spikeplot as splt
import torch.nn as nn
import pandas as pd
from sklearn.preprocessing import StandardScaler

import matplotlib.pyplot as plt
import numpy as np
import itertools

from snntorch import surrogate
import seaborn as sns
from sklearn.metrics import confusion_matrix

# %%
class _SpikeTensor(torch.Tensor):
    """Inherits from torch.Tensor with additional attributes.
    ``init_flag`` is set at the time of initialization.
    When called in the forward function of any neuron, they are parsed and
    replaced with a torch.Tensor variable.
    """

    @staticmethod
    def __new__(cls, *args, init_flag=False, **kwargs):
        return super().__new__(cls, *args, **kwargs)

    def __init__(
        self,
        *args,
        init_flag=True,
    ):
        # super().__init__() # optional
        self.init_flag = init_flag


def _SpikeTorchConv(*args, input_):
    """Convert SpikeTensor to torch.Tensor of the same size as ``input_``."""

    states = []
    # if len(input_.size()) == 0:
    #     _batch_size = 1  # assume batch_size=1 if 1D input
    # else:
    #     _batch_size = input_.size(0)
    if (
        len(args) == 1 and type(args) is not tuple
    ):  # if only one hidden state, make it iterable
        args = (args,)
    for arg in args:
        arg = arg.to("cpu")
        arg = torch.Tensor(arg)  # wash away the SpikeTensor class
        arg = torch.zeros_like(input_, requires_grad=True)
        states.append(arg)
    if len(states) == 1:  # otherwise, list isn't unpacked
        return states[0]

    return states

# %%
# file = open("Arthymia_4_para.csv")

# num_steps = 10
# batch_size = 100
# num_epochs = 170
# loss_hist = []
# test_loss_hist = []
# counter = 0
# num_inputs = 1*4
# num_hidden = 9
# num_outputs = 7
# learning_rate = 2e-3
# torch.manual_seed(490) 
# dtype = torch.float       # 93.07

file = open("Arthymia_4_para.csv")

num_steps = 10
batch_size = 100
num_epochs = 170
loss_hist = []
test_loss_hist = []
counter = 0
num_inputs = 1*4
num_hidden = 15
num_outputs = 7
learning_rate = 1.3e-3
torch.manual_seed(490) 
dtype = torch.float #          94.26%

# %%
numpy_array = np.genfromtxt("Arthymia_4_para.csv", delimiter=",", dtype=None, names=True, encoding=None)

# %%
data = pd.read_csv("Arthymia_4_para.csv")
input_features = data.iloc[:, :4].values
scaler = StandardScaler()
scaler.fit(input_features)

normalized_input_features = scaler.transform(input_features)

normalized_data = pd.DataFrame(normalized_input_features, columns=data.columns[:4])

# %%
in_data = normalized_data.values
in_data
# Out:
# array([[-0.49296855, -0.5591449 ,  0.08902292,  0.30357406],
#        [-0.53383502, -0.42284481,  0.08902292, -0.42838187],
#        [-0.47083254, -0.45429868, -0.09970679,  0.49246591],
#        ...,
#        [ 0.61723741,  0.09090167,  1.30086632,  1.60220554],
#        [ 0.61042633, -0.04539841,  1.72799145,  0.6341348 ],
#        [-0.61556798, -0.64302188, -0.08977365, -0.16865557]])

# %%
# in_data = np.array([(x[0], x[1], x[2], x[3]) for x in numpy_array])
out_data = np.array([(x[4]) for x in numpy_array])

class_enum = {'NORMAL SINUS RHYTHM': 0,
 'SINUS BRADYCARDIA': 1,
 'WIDE BRADYCARDIA': 2,
 'SINUS TACHYCARDIA': 3,
 'WIDE TACHYCARDIA': 4,
 'NARROW BRADYCARDIA': 5,
 'NARROW TACHYCARDIA': 6}

output_data = [class_enum[x] for x in out_data]

inputs_tensor = torch.tensor(in_data, dtype=torch.float32)
outputs_tensor = torch.tensor(output_data, dtype=torch.long)

dataset = TensorDataset(inputs_tensor, outputs_tensor)

data_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# %%
print(inputs_tensor)
print(outputs_tensor)
# Out:
# tensor([[-0.4930, -0.5591,  0.0890,  0.3036],
#         [-0.5338, -0.4228,  0.0890, -0.4284],
#         [-0.4708, -0.4543, -0.0997,  0.4925],
#         ...,
#         [ 0.6172,  0.0909,  1.3009,  1.6022],
#         [ 0.6104, -0.0454,  1.7280,  0.6341],
#         [-0.6156, -0.6430, -0.0898, -0.1687]])
# tensor([0, 0, 0,  ..., 2, 2, 0])

# %%
# class AdEx(nn.Module):
#   def __init__(self, Cm, g_L, E_L, Delta_T, V_T, a, tau_w):
#       super(AdEx, self).__init__()

#       # initialize decay rate beta and threshold
#       self.Cm = Cm            # Membrane capacitance
#       self.g_L = g_L          # Leak conductance
#       self.E_L = E_L          # Leak reversal potential
#       self.Delta_T = Delta_T  # Slope factor
#       self.V_T = V_T          # Spike threshold
#       self.a = a              # Subthreshold adaptation parameter
#       self.tau_w = tau_w      # Adaptation time constant
        
#       # self.V = torch.tensor(float(E_L))  # Initial membrane potential as float tensor
#       self.w = torch.tensor(0.0)         # Initial adaptation current
#       self.spike_gradient = self.ATan.apply

#   # the forward function is called each time 
#   def forward(self, I, mem):
    
#     dt = 0.1
#     spk = self.spike_gradient((mem - self.V_T))  # call the Heaviside function
    
#     dV = (self.g_L * (self.E_L - mem) + self.g_L * self.Delta_T * torch.exp((mem - self.V_T) / self.Delta_T) - self.w + I) / self.Cm
#     dw = (self.a * (mem - self.E_L) - self.w) / self.tau_w
    
#     mem += dV * dt
#     self.w += dw * dt
        
#     if mem >= 0:  # Spike condition
#         mem = torch.tensor(float(self.E_L))  # Reset membrane potential as float tensor
#         self.w += 2       # Spike-triggered adaptation
        
#     # mem = self.V.item()
#     return spk, mem
  
#   @staticmethod
#   def init_AdEx():
#         """
#         Used to initialize mem as an empty SpikeTensor.
#         ``init_flag`` is used as an attribute in the forward pass to convert
#         the hidden states to the same as the input.
#         """
#         mem = _SpikeTensor(init_flag=False)
#         return mem  
  
#   # Forward pass: Heaviside function
#   # Backward pass: Override Dirac Delta with the ArcTan function
#   @staticmethod
#   class ATan(torch.autograd.Function):
#       @staticmethod
#       def forward(ctx, mem):
#           spk = (mem > 0).float() # Heaviside on the forward pass: Eq(2)
#           ctx.save_for_backward(mem)  # store the membrane for use in the backward pass
#           return spk

#       @staticmethod
#       def backward(ctx, grad_output):
#           (mem,) = ctx.saved_tensors  # retrieve the membrane potential
#           grad = 1 / (1 + (np.pi * mem).pow_(2)) * grad_output # Eqn 5
#           return grad

# %%
class SpikingNeuron(nn.Module):
    """Parent class for spiking neuron models."""

    instances = []
    """Each :mod:`snntorch.SpikingNeuron` neuron
    (e.g., :mod:`snntorch.Synaptic`) will populate the
    :mod:`snntorch.SpikingNeuron.instances` list with a new entry.
    The list is used to initialize and clear neuron states when the
    argument `init_hidden=True`."""

    reset_dict = {
        "subtract": 0,
        "zero": 1,
        "none": 2,
    }

    def __init__(
        self,
        threshold=1.0,
        spike_grad=None,
        surrogate_disable=False,
        init_hidden=False,
        inhibition=False,
        learn_threshold=False,
        reset_mechanism="subtract",
        state_quant=False,
        output=False,
        graded_spikes_factor=1.0,
        learn_graded_spikes_factor=False,
    ):
        super(SpikingNeuron, self).__init__()

        SpikingNeuron.instances.append(self)
        self.init_hidden = init_hidden
        self.inhibition = inhibition
        self.output = output
        self.surrogate_disable = surrogate_disable

        self._snn_cases(reset_mechanism, inhibition)
        self._snn_register_buffer(
            threshold=threshold,
            learn_threshold=learn_threshold,
            reset_mechanism=reset_mechanism,
            graded_spikes_factor=graded_spikes_factor,
            learn_graded_spikes_factor=learn_graded_spikes_factor,
        )
        self._reset_mechanism = reset_mechanism

        if spike_grad is None:
            self.spike_grad = self.ATan.apply
        else:
            self.spike_grad = spike_grad

        if self.surrogate_disable:
            self.spike_grad = self._surrogate_bypass

        self.state_quant = state_quant

    def fire(self, mem):
        """Generates spike if mem > threshold.
        Returns spk."""

        if self.state_quant:
            mem = self.state_quant(mem)

        mem_shift = mem - self.threshold
        spk = self.spike_grad(mem_shift)

        spk = spk * self.graded_spikes_factor

        return spk

    def fire_inhibition(self, batch_size, mem):
        """Generates spike if mem > threshold, only for the largest membrane.
        All others neurons will be inhibited for that time step.
        Returns spk."""
        mem_shift = mem - self.threshold
        index = torch.argmax(mem_shift, dim=1)
        spk_tmp = self.spike_grad(mem_shift)

        mask_spk1 = torch.zeros_like(spk_tmp)
        mask_spk1[torch.arange(batch_size), index] = 1
        spk = spk_tmp * mask_spk1
        # reset = spk.clone().detach()

        return spk

    def mem_reset(self, mem):
        """Generates detached reset signal if mem > threshold.
        Returns reset."""
        mem_shift = mem - self.threshold
        reset = self.spike_grad(mem_shift).clone().detach()

        return reset

    def _snn_cases(self, reset_mechanism, inhibition):
        self._reset_cases(reset_mechanism)

        if inhibition:
            warn(
                "Inhibition is an unstable feature that has only been tested "
                "for dense (fully-connected) layers. Use with caution!",
                UserWarning,
            )

    def _reset_cases(self, reset_mechanism):
        if (
            reset_mechanism != "subtract"
            and reset_mechanism != "zero"
            and reset_mechanism != "none"
        ):
            raise ValueError(
                "reset_mechanism must be set to either 'subtract', "
                "'zero', or 'none'."
            )

    def _snn_register_buffer(
        self,
        threshold,
        learn_threshold,
        reset_mechanism,
        graded_spikes_factor,
        learn_graded_spikes_factor,
    ):
        """Set variables as learnable parameters else register them in the
        buffer."""

        self._threshold_buffer(threshold, learn_threshold)
        self._graded_spikes_buffer(
            graded_spikes_factor, learn_graded_spikes_factor
        )

        # reset buffer
        try:
            # if reset_mechanism_val is loaded from .pt, override
            # reset_mechanism
            if torch.is_tensor(self.reset_mechanism_val):
                self.reset_mechanism = list(SpikingNeuron.reset_dict)[
                    self.reset_mechanism_val
                ]
        except AttributeError:
            # reset_mechanism_val has not yet been created, create it
            self._reset_mechanism_buffer(reset_mechanism)

    def _graded_spikes_buffer(
        self, graded_spikes_factor, learn_graded_spikes_factor
    ):
        if not isinstance(graded_spikes_factor, torch.Tensor):
            graded_spikes_factor = torch.as_tensor(graded_spikes_factor)
        if learn_graded_spikes_factor:
            self.graded_spikes_factor = nn.Parameter(graded_spikes_factor)
        else:
            self.register_buffer("graded_spikes_factor", graded_spikes_factor)

    def _threshold_buffer(self, threshold, learn_threshold):
        if not isinstance(threshold, torch.Tensor):
            threshold = torch.as_tensor(threshold)
        if learn_threshold:
            self.threshold = nn.Parameter(threshold)
        else:
            self.register_buffer("threshold", threshold)

    def _reset_mechanism_buffer(self, reset_mechanism):
        """Assign mapping to each reset mechanism state.
        Must be of type tensor to store in register buffer. See reset_dict
        for mapping."""
        reset_mechanism_val = torch.as_tensor(
            SpikingNeuron.reset_dict[reset_mechanism]
        )
        self.register_buffer("reset_mechanism_val", reset_mechanism_val)

    def _V_register_buffer(self, V, learn_V):
        if not isinstance(V, torch.Tensor):
            V = torch.as_tensor(V)
        if learn_V:
            self.V = nn.Parameter(V)
        else:
            self.register_buffer("V", V)

    @property
    def reset_mechanism(self):
        """If reset_mechanism is modified, reset_mechanism_val is triggered
        to update.
        0: subtract, 1: zero, 2: none."""
        return self._reset_mechanism

    @reset_mechanism.setter
    def reset_mechanism(self, new_reset_mechanism):
        self._reset_cases(new_reset_mechanism)
        self.reset_mechanism_val = torch.as_tensor(
            SpikingNeuron.reset_dict[new_reset_mechanism]
        )
        self._reset_mechanism = new_reset_mechanism

    @classmethod
    def init(cls):
        """Removes all items from :mod:`snntorch.SpikingNeuron.instances`
        when called."""
        cls.instances = []

    @staticmethod
    def detach(*args):
        """Used to detach input arguments from the current graph.
        Intended for use in truncated backpropagation through time where
        hidden state variables are global variables."""
        for state in args:
            state.detach_()

    @staticmethod
    def zeros(*args):
        """Used to clear hidden state variables to zero.
        Intended for use where hidden state variables are global variables."""
        for state in args:
            state = torch.zeros_like(state)

    @staticmethod
    def _surrogate_bypass(input_):
        return (input_ > 0).float()

    @staticmethod
    class ATan(torch.autograd.Function):
        """
        Surrogate gradient of the Heaviside step function.

        **Forward pass:** Heaviside step function shifted.

            .. math::

                S=\\begin{cases} 1 & \\text{if U ≥ U$_{\\rm thr}$} \\\\
                0 & \\text{if U < U$_{\\rm thr}$}
                \\end{cases}

        **Backward pass:** Gradient of shifted arc-tan function.

            .. math::

                    S&≈\\frac{1}{π}\\text{arctan}(πU \\frac{α}{2}) \\\\
                    \\frac{∂S}{∂U}&=\\frac{1}{π}\
                    \\frac{1}{(1+(πU\\frac{α}{2})^2)}


        :math:`alpha` defaults to 2, and can be modified by calling
        ``surrogate.atan(alpha=2)``.

        Adapted from:

        *W. Fang, Z. Yu, Y. Chen, T. Masquelier, T. Huang, Y. Tian (2021)
        Incorporating Learnable Membrane Time Constants to Enhance Learning
        of Spiking Neural Networks. Proc. IEEE/CVF Int. Conf. Computer
        Vision (ICCV), pp. 2661-2671.*"""

        @staticmethod
        def forward(ctx, input_, alpha=2.0):
            ctx.save_for_backward(input_)
            ctx.alpha = alpha
            out = (input_ > 0).float()
            return out

        @staticmethod
        def backward(ctx, grad_output):
            (input_,) = ctx.saved_tensors
            grad_input = grad_output.clone()
            grad = (
                ctx.alpha
                / 2
                / (1 + (torch.pi / 2 * ctx.alpha * input_).pow_(2))
                * grad_input
            )
            return grad, None

# %%
class AdEx(SpikingNeuron):

    def __init__(
        self, Cm, g_L, E_L, Delta_T, V_T, a, tau_w,
        threshold=1.0,
        spike_grad=None,
        surrogate_disable=False,
        init_hidden=False,
        inhibition=False,
        learn_beta=False,
        learn_threshold=False,
        reset_mechanism="subtract",
        state_quant=False,
        output=False,
        graded_spikes_factor=1.0,
        learn_graded_spikes_factor=False,
    ):
        super().__init__(
            threshold,
            spike_grad,
            surrogate_disable,
            init_hidden,
            inhibition,
            learn_threshold,
            reset_mechanism,
            state_quant,
            output,
            graded_spikes_factor,
            learn_graded_spikes_factor,
        )

        self.spike_gradient = self.ATan.apply
        self.Cm = Cm            # Membrane capacitance
        self.g_L = g_L          # Leak conductance
        self.E_L = E_L          # Leak reversal potential
        self.Delta_T = Delta_T  # Slope factor
        self.V_T = V_T          # Spike threshold
        self.a = a              # Subthreshold adaptation parameter
        self.tau_w = tau_w      # Adaptation time constant
        self.w = torch.tensor(0.0)         # Initial adaptation current
        
        if self.init_hidden:
            self.mem = self.init_leaky()

    def forward(self, input_, mem=False):

        if hasattr(mem, "init_flag"):  # only triggered on first-pass
            mem = _SpikeTorchConv(mem, input_=input_)
        elif mem is False and hasattr(
            self.mem, "init_flag"
        ):  # init_hidden case
            
            self.mem = _SpikeTorchConv(self.mem, input_=input_)
 
        dt = 0.1
        spk = self.spike_gradient((mem - self.V_T))  # call the Heaviside function

        dV = (self.g_L * (self.E_L - mem) + self.g_L * self.Delta_T * torch.exp((mem - self.V_T) / self.Delta_T) - self.w + abs(input_)) / self.Cm
        dw = (self.a * (mem - self.E_L) - self.w) / self.tau_w

        mem = mem + dV * dt  # Avoid in-place modification
        self.w = self.w + dw * dt  # Avoid in-place modification

        spike_mask = mem >= 0  # Spike condition
        mem = torch.where(spike_mask, torch.tensor(float(self.E_L)), mem)  # Reset membrane potential where spike occurs
        self.w = self.w + 2 * spike_mask.float()  # Spike-triggered adaptation

        return spk, mem

    
    @staticmethod
    def init_AdEx():
        """
        Used to initialize mem as an empty SpikeTensor.
        ``init_flag`` is used as an attribute in the forward pass to convert
        the hidden states to the same as the input.
        """
        mem = _SpikeTensor(init_flag=False)

        return mem

# %%
Cm = 200   # Membrane capacitance (200 pF)
g_L = 10    # Leak conductance (10 nS)
E_L = -70   # Leak reversal potential (-70 mV)
Delta_T = 10 # Slope factor (2 mV)
V_T = -50   # Spike threshold (-50 mV)
a = 2       # Subthreshold adaptation parameter (2 nS)
tau_w = 30  # Adaptation time constant (30 ms)

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()

        # Initialize layers
        self.fc1 = nn.Linear(num_inputs, num_hidden)
        self.adex1 = AdEx(Cm, g_L, E_L, Delta_T, V_T, a, tau_w)
        self.fc2 = nn.Linear(num_hidden, num_outputs)
        self.adex2 = AdEx(Cm, g_L, E_L, Delta_T, V_T, a, tau_w)

    def forward(self, x):

        # Initialize hidden states at t=0
        mem1 = self.adex1.init_AdEx()
        mem2 = self.adex2.init_AdEx()

        # Record the final layer
        spk2_rec = []
        mem2_rec = []

        for step in range(num_steps):
            cur1 = self.fc1(x)
            spk1, mem1 = self.adex1(cur1*1000, mem1)
            cur2 = self.fc2(spk1)
            spk2, mem2 = self.adex2(cur2*1000, mem2)
            spk2_rec.append(spk2)
            mem2_rec.append(mem2)

        return torch.stack(spk2_rec, dim=0), torch.stack(mem2_rec, dim=0)
        
# Load the network onto CUDA if available
net = Net().to(device)

# %%
test_accuracy_data = []
train_accuracy_data = []

def print_batch_accuracy(data, targets, train=False):
    output, _ = net(data.view(batch_size, -1))
    _, idx = output.sum(dim=0).max(1)
    acc = np.mean((targets == idx).detach().cpu().numpy())

    if train:
        print(f"Train set accuracy for a single minibatch: {acc*100:.2f}%")
        train_accuracy_data.append(acc*100)
    else:
        print(f"Test set accuracy for a single minibatch: {acc*100:.2f}%")
        test_accuracy_data.append(acc*100)

def train_printer(
    data, targets, epoch,
    counter, iter_counter,
        loss_hist, test_loss_hist, test_data, test_targets):
    print(f"Epoch {epoch}, Iteration {iter_counter}")
    print(f"Train Set Loss: {loss_hist[counter]:.2f}")
    print(f"Test Set Loss: {test_loss_hist[counter]:.2f}")
    print_batch_accuracy(data, targets, train=True)
    print_batch_accuracy(test_data, test_targets, train=False)
    print("\n")

# %%
loss = nn.CrossEntropyLoss()
#dice, hinge
optimizer = torch.optim.Adam(net.parameters(), lr=learning_rate, betas=(0.9, 0.999))

# %%
data, targets = next(iter(data_loader))
data = data.to(device)
targets = targets.to(device)

# %%
spk_rec, mem_rec = net(data.view(batch_size, -1))
print(mem_rec.size())
# Out:
# torch.Size([10, 100, 7])

# %%
# initialize the total loss value
loss_val = torch.zeros((1), dtype=dtype, device=device)

# sum loss at every step
for step in range(num_steps):
  loss_val += loss(mem_rec[step], targets)

print(f"Training loss: {loss_val.item():.3f}")
print_batch_accuracy(data, targets, train=True)
# Out:
# Training loss: 19.257
# Train set accuracy for a single minibatch: 38.00%

# %%
# Outer training loop
# torch.autograd.set_detect_anomaly(True)

for epoch in range(num_epochs):
    iter_counter = 0
    train_batch = iter(data_loader)

    # Minibatch training loop
    for data, targets in train_batch:
        data = data.to(device)
        targets = targets.to(device)

        # forward pass
        net.train()
        # print(data.shape)
        spk_rec, mem_rec = net(data.view(batch_size, -1))

        # initialize the loss & sum over time
        loss_val = torch.zeros((1), dtype=dtype, device=device)
        for step in range(num_steps):
            loss_val += loss(mem_rec[step], targets)

        # Gradient calculation + weight update
        optimizer.zero_grad()
        loss_val.backward()
        optimizer.step()

        # Store loss history for future plotting
        loss_hist.append(loss_val.item())

        # Test set
        with torch.no_grad():
            net.eval()
            test_data, test_targets = next(iter(data_loader))
            test_data = test_data.to(device)
            test_targets = test_targets.to(device)

            # Test set forward pass
            test_spk, test_mem = net(test_data.view(batch_size, -1))

            # Test set loss
            test_loss = torch.zeros((1), dtype=dtype, device=device)
            for step in range(num_steps):
                test_loss += loss(test_mem[step], test_targets)
            test_loss_hist.append(test_loss.item())

            # Print train/test loss/accuracy
            if counter % 5 == 0:
                train_printer(
                    data, targets, epoch,
                    counter, iter_counter,
                    loss_hist, test_loss_hist,
                    test_data, test_targets)
            counter += 1
            iter_counter +=1
# Out:
# Epoch 0, Iteration 0
# Train Set Loss: 19.15
# Test Set Loss: 19.17
# Train set accuracy for a single minibatch: 42.00%
# Test set accuracy for a single minibatch: 38.00%
#
#
# Epoch 0, Iteration 5
# Train Set Loss: 19.13
# Test Set Loss: 19.26
# Train set accuracy for a single minibatch: 34.00%
# Test set accuracy for a single minibatch: 29.00%
#
#
# Epoch 0, Iteration 10
# Train Set Loss: 19.11
# Test Set Loss: 18.99
# Train set accuracy for a single minibatch: 33.00%
# Test set accuracy for a single minibatch: 42.00%
#
#
# Epoch 0, Iteration 15
# Train Set Loss: 18.99
# Test Set Loss: 19.05
# Train set accuracy for a single minibatch: 37.00%
# Test set accuracy for a single minibatch: 29.00%
#
#
# Epoch 0, Iteration 20
# Train Set Loss: 18.92
# Test Set Loss: 18.87
# Train set accuracy for a single minibatch: 44.00%
# Test set accuracy for a single minibatch: 40.00%
#
#
# Epoch 0, Iteration 25
# Train Set Loss: 19.05
# Test Set Loss: 18.98
# Train set accuracy for a single minibatch: 29.00%
# Test set accuracy for a single minibatch: 35.00%
#
#
# Epoch 0, Iteration 30
# Train Set Loss: 18.96
# Test Set Loss: 18.87
# Train set accuracy for a single minibatch: 37.00%
# Test set accuracy for a single minibatch: 37.00%
#
#
# Epoch 0, Iteration 35
# Train Set Loss: 18.98
# Test Set Loss: 18.82
# Train set accuracy for a single minibatch: 30.00%
# Test set accuracy for a single minibatch: 30.00%
#
#
# Epoch 0, Iteration 40
# Train Set Loss: 18.95
# Test Set Loss: 19.01
# Train set accuracy for a single minibatch: 31.00%
# Test set accuracy for a single minibatch: 27.00%
#
#
# Epoch 0, Iteration 45
# Train Set Loss: 18.62
# Test Set Loss: 18.66
# Train set accuracy for a single minibatch: 32.00%
# Test set accuracy for a single minibatch: 38.00%
#
#
# Epoch 0, Iteration 50
# Train Set Loss: 18.77
# Test Set Loss: 18.52
# Train set accuracy for a single minibatch: 31.00%
# Test set accuracy for a single minibatch: 41.00%
#
#
# Epoch 0, Iteration 55
# Train Set Loss: 18.58
# Test Set Loss: 18.69
# Train set accuracy for a single minibatch: 40.00%
# Test set accuracy for a single minibatch: 34.00%
#
#
# Epoch 0, Iteration 60
# Train Set Loss: 18.70
# Test Set Loss: 18.55
# Train set accuracy for a single minibatch: 31.00%
# Test set accuracy for a single minibatch: 41.00%
#
#
# Epoch 0, Iteration 65
# Train Set Loss: 18.90
# Test Set Loss: 18.67
# Train set accuracy for a single minibatch: 25.00%
# Test set accuracy for a single minibatch: 34.00%
#
#
# Epoch 0, Iteration 70
# Train Set Loss: 18.72
# Test Set Loss: 18.74
# Train set accuracy for a single minibatch: 35.00%
# Test set accuracy for a single minibatch: 31.00%
#
#
# Epoch 0, Iteration 75
# Train Set Loss: 18.48
# Test Set Loss: 18.59
# Train set accuracy for a single minibatch: 38.00%
# Test set accuracy for a single minibatch: 35.00%
#
#
# Epoch 0, Iteration 80
# Train Set Loss: 18.58
# Test Set Loss: 18.84
# Train set accuracy for a single minibatch: 33.00%
# Test set accuracy for a single minibatch: 28.00%
#
#
# Epoch 0, Iteration 85
# Train Set Loss: 18.95
# Test Set Loss: 18.41
# Train set accuracy for a single minibatch: 30.00%
# Test set accuracy for a single minibatch: 39.00%
#
#
# Epoch 0, Iteration 90
# Train Set Loss: 18.61
# Test Set Loss: 18.39
# Train set accuracy for a single minibatch: 31.00%
# Test set accuracy for a single minibatch: 38.00%
#
#
# Epoch 1, Iteration 0
# Train Set Loss: 18.77
# Test Set Loss: 18.40
# Train set accuracy for a single minibatch: 29.00%
# Test set accuracy for a single minibatch: 39.00%
#
#
# Epoch 1, Iteration 5
# Train Set Loss: 18.56
# Test Set Loss: 18.46
# Train set accuracy for a single minibatch: 39.00%
# Test set accuracy for a single minibatch: 33.00%
#
#
# Epoch 1, Iteration 10
# Train Set Loss: 18.11
# Test Set Loss: 18.22
# Train set accuracy for a single minibatch: 39.00%
# Test set accuracy for a single minibatch: 38.00%
#
#
# Epoch 1, Iteration 15
# Train Set Loss: 18.29
# Test Set Loss: 18.48
# Train set accuracy for a single minibatch: 36.00%
# Test set accuracy for a single minibatch: 34.00%
#
#
# Epoch 1, Iteration 20
# Train Set Loss: 18.40
# Test Set Loss: 18.01
# Train set accuracy for a single minibatch: 35.00%
# Test set accuracy for a single minibatch: 38.00%
#
#
# Epoch 1, Iteration 25
# Train Set Loss: 18.53
# Test Set Loss: 17.79
# Train set accuracy for a single minibatch: 33.00%
# Test set accuracy for a single minibatch: 44.00%
#
#
# Epoch 1, Iteration 30
# Train Set Loss: 18.12
# Test Set Loss: 18.39
# Train set accuracy for a single minibatch: 41.00%
# Test set accuracy for a single minibatch: 36.00%
#
#
# Epoch 1, Iteration 35
# Train Set Loss: 18.51
# Test Set Loss: 18.66
# Train set accuracy for a single minibatch: 29.00%
# Test set accuracy for a single minibatch: 29.00%
#
#
# Epoch 1, Iteration 40
# Train Set Loss: 18.53
# Test Set Loss: 18.17
# Train set accuracy for a single minibatch: 34.00%
# Test set accuracy for a single minibatch: 35.00%
#
#
# Epoch 1, Iteration 45
# Train Set Loss: 18.04
# Test Set Loss: 18.32
# Train set accuracy for a single minibatch: 34.00%
# Test set accuracy for a single minibatch: 36.00%
#
#
# Epoch 1, Iteration 50
# Train Set Loss: 18.50
# Test Set Loss: 18.53
# Train set accuracy for a single minibatch: 34.00%
# Test set accuracy for a single minibatch: 32.00%
#
#
# Epoch 1, Iteration 55
# Train Set Loss: 18.67
# Test Set Loss: 18.24
# Train set accuracy for a single minibatch: 27.00%
# Test set accuracy for a single minibatch: 37.00%
#
#
# Epoch 1, Iteration 60
# Train Set Loss: 18.76
# Test Set Loss: 18.23
# Train set accuracy for a single minibatch: 28.00%
# Test set accuracy for a single minibatch: 36.00%
#
#
# Epoch 1, Iteration 65
# Train Set Loss: 18.96
# Test Set Loss: 18.24
# Train set accuracy for a single minibatch: 24.00%
# Test set accuracy for a single minibatch: 34.00%
#
#
# Epoch 1, Iteration 70
# Train Set Loss: 17.93
# Test Set Loss: 18.03
# Train set accuracy for a single minibatch: 38.00%
# Test set accuracy for a single minibatch: 38.00%
#
#
# Epoch 1, Iteration 75
# Train Set Loss: 18.44
# Test Set Loss: 18.42
# Train set accuracy for a single minibatch: 34.00%
# Test set accuracy for a single minibatch: 30.00%
#
#
# Epoch 1, Iteration 80
# Train Set Loss: 18.64
# Test Set Loss: 18.57
# Train set accuracy for a single minibatch: 32.00%
# Test set accuracy for a single minibatch: 31.00%
#
#
# Epoch 1, Iteration 85
# Train Set Loss: 18.23
# Test Set Loss: 18.46
# Train set accuracy for a single minibatch: 34.00%
# Test set accuracy for a single minibatch: 31.00%
#
#
# Epoch 1, Iteration 90
# Train Set Loss: 18.32
# Test Set Loss: 18.42
# Train set accuracy for a single minibatch: 37.00%
# Test set accuracy for a single minibatch: 32.00%
#
#
# Epoch 2, Iteration 0
# Train Set Loss: 18.30
# Test Set Loss: 18.10
# Train set accuracy for a single minibatch: 36.00%
# Test set accuracy for a single minibatch: 39.00%
#
#
# Epoch 2, Iteration 5
# Train Set Loss: 18.01
# Test Set Loss: 18.58
# Train set accuracy for a single minibatch: 40.00%
# Test set accuracy for a single minibatch: 31.00%
#
#
# Epoch 2, Iteration 10
# Train Set Loss: 18.38
# Test Set Loss: 17.83
# Train set accuracy for a single minibatch: 32.00%
# Test set accuracy for a single minibatch: 41.00%
#
#
# Epoch 2, Iteration 15
# Train Set Loss: 18.26
# Test Set Loss: 18.22
# Train set accuracy for a single minibatch: 35.00%
# Test set accuracy for a single minibatch: 34.00%
#
#
# Epoch 2, Iteration 20
# Train Set Loss: 18.42
# Test Set Loss: 18.55
# Train set accuracy for a single minibatch: 33.00%
# Test set accuracy for a single minibatch: 34.00%
#
#
# Epoch 2, Iteration 25
# Train Set Loss: 18.13
# Test Set Loss: 18.48
# Train set accuracy for a single minibatch: 34.00%
# Test set accuracy for a single minibatch: 31.00%
#
#
# Epoch 2, Iteration 30
# Train Set Loss: 18.46
# Test Set Loss: 19.01
# Train set accuracy for a single minibatch: 30.00%
# Test set accuracy for a single minibatch: 24.00%
#
#
# Epoch 2, Iteration 35
# Train Set Loss: 18.32
# Test Set Loss: 18.11
# Train set accuracy for a single minibatch: 32.00%
# Test set accuracy for a single minibatch: 37.00%
#
#
# Epoch 2, Iteration 40
# Train Set Loss: 18.44
# Test Set Loss: 18.81
# Train set accuracy for a single minibatch: 34.00%
# Test set accuracy for a single minibatch: 31.00%
#
#
# Epoch 2, Iteration 45
# Train Set Loss: 18.33
# Test Set Loss: 18.71
# Train set accuracy for a single minibatch: 32.00%
# Test set accuracy for a single minibatch: 30.00%
#
#
# Epoch 2, Iteration 50
# Train Set Loss: 18.93
# Test Set Loss: 18.89
# Train set accuracy for a single minibatch: 24.00%
# Test set accuracy for a single minibatch: 28.00%
#
#
# Epoch 2, Iteration 55
# Train Set Loss: 18.40
# Test Set Loss: 18.32
# Train set accuracy for a single minibatch: 33.00%
# Test set accuracy for a single minibatch: 39.00%
#
#
# Epoch 2, Iteration 60
# Train Set Loss: 18.06
# Test Set Loss: 18.21
# Train set accuracy for a single minibatch: 36.00%
# Test set accuracy for a single minibatch: 34.00%
#
#
# Epoch 2, Iteration 65
# Train Set Loss: 18.78
# Test Set Loss: 18.46
# Train set accuracy for a single minibatch: 27.00%
# Test set accuracy for a single minibatch: 26.00%
#
#
# Epoch 2, Iteration 70
# Train Set Loss: 17.95
# Test Set Loss: 19.01
# Train set accuracy for a single minibatch: 35.00%
# Test set accuracy for a single minibatch: 24.00%
#
#
# Epoch 2, Iteration 75
# Train Set Loss: 18.77
# Test Set Loss: 18.44
# Train set accuracy for a single minibatch: 33.00%
# Test set accuracy for a single minibatch: 29.00%
#
#
# Epoch 2, Iteration 80
# Train Set Loss: 18.08
# Test Set Loss: 18.52
# Train set accuracy for a single minibatch: 36.00%
# Test set accuracy for a single minibatch: 35.00%
#
#
# Epoch 2, Iteration 85
# Train Set Loss: 18.41
# Test Set Loss: 18.74
# Train set accuracy for a single minibatch: 31.00%
# Test set accuracy for a single minibatch: 32.00%
#
#
# Epoch 2, Iteration 90
# Train Set Loss: 17.89
# Test Set Loss: 19.05
# Train set accuracy for a single minibatch: 38.00%
# Test set accuracy for a single minibatch: 27.00%
#
#
# Epoch 3, Iteration 0
# Train Set Loss: 18.36
# Test Set Loss: 18.29
# Train set accuracy for a single minibatch: 35.00%
# Test set accuracy for a single minibatch: 33.00%
#
#
# Epoch 3, Iteration 5
# Train Set Loss: 18.28
# Test Set Loss: 18.07
# Train set accuracy for a single minibatch: 34.00%
# Test set accuracy for a single minibatch: 33.00%
#
#
# Epoch 3, Iteration 10
# Train Set Loss: 18.39
# Test Set Loss: 18.92
# Train set accuracy for a single minibatch: 35.00%
# Test set accuracy for a single minibatch: 28.00%
#
#
# Epoch 3, Iteration 15
# Train Set Loss: 18.51
# Test Set Loss: 17.71
# Train set accuracy for a single minibatch: 35.00%
# Test set accuracy for a single minibatch: 37.00%
#
#
# Epoch 3, Iteration 20
# Train Set Loss: 18.41
# Test Set Loss: 18.12
# Train set accuracy for a single minibatch: 38.00%
# Test set accuracy for a single minibatch: 32.00%
#
#
# Epoch 3, Iteration 25
# Train Set Loss: 17.80
# Test Set Loss: 18.63
# Train set accuracy for a single minibatch: 37.00%
# Test set accuracy for a single minibatch: 33.00%
#
#
# Epoch 3, Iteration 30
# Train Set Loss: 18.19
# Test Set Loss: 18.51
# Train set accuracy for a single minibatch: 36.00%
# Test set accuracy for a single minibatch: 25.00%
#
#
# Epoch 3, Iteration 35
# Train Set Loss: 18.25
# Test Set Loss: 18.66
# Train set accuracy for a single minibatch: 36.00%
# Test set accuracy for a single minibatch: 30.00%
#
#
# Epoch 3, Iteration 40
# Train Set Loss: 18.38
# Test Set Loss: 18.44
# Train set accuracy for a single minibatch: 31.00%
# Test set accuracy for a single minibatch: 34.00%
#
#
# Epoch 3, Iteration 45
# Train Set Loss: 18.23
# Test Set Loss: 18.39
# Train set accuracy for a single minibatch: 30.00%
# Test set accuracy for a single minibatch: 36.00%
#
#
# Epoch 3, Iteration 50
# Train Set Loss: 18.13
# Test Set Loss: 18.08
# Train set accuracy for a single minibatch: 36.00%
# Test set accuracy for a single minibatch: 36.00%
#
#
# Epoch 3, Iteration 55
# Train Set Loss: 18.42
# Test Set Loss: 17.83
# Train set accuracy for a single minibatch: 32.00%
# Test set accuracy for a single minibatch: 35.00%
#
#
# Epoch 3, Iteration 60
# Train Set Loss: 18.00
# Test Set Loss: 19.11
# Train set accuracy for a single minibatch: 36.00%
# Test set accuracy for a single minibatch: 28.00%
#
#
# Epoch 3, Iteration 65
# Train Set Loss: 18.15
# Test Set Loss: 18.10
# Train set accuracy for a single minibatch: 37.00%
# Test set accuracy for a single minibatch: 32.00%
#
#
# Epoch 3, Iteration 70
# Train Set Loss: 18.13
# Test Set Loss: 18.33
# Train set accuracy for a single minibatch: 35.00%
# Test set accuracy for a single minibatch: 36.00%
#
#
# Epoch 3, Iteration 75
# Train Set Loss: 18.61
# Test Set Loss: 17.44
# Train set accuracy for a single minibatch: 28.00%
# Test set accuracy for a single minibatch: 41.00%
#
#
# Epoch 3, Iteration 80
# Train Set Loss: 18.67
# Test Set Loss: 18.64
# Train set accuracy for a single minibatch: 30.00%
# Test set accuracy for a single minibatch: 28.00%
#
#
# Epoch 3, Iteration 85
# Train Set Loss: 18.39
# Test Set Loss: 17.70
# Train set accuracy for a single minibatch: 32.00%
# Test set accuracy for a single minibatch: 42.00%
#
#
# Epoch 3, Iteration 90
# Train Set Loss: 17.79
# Test Set Loss: 18.38
# Train set accuracy for a single minibatch: 40.00%
# Test set accuracy for a single minibatch: 32.00%
#
#
# Epoch 4, Iteration 0
# Train Set Loss: 18.01
# Test Set Loss: 18.35
# Train set accuracy for a single minibatch: 40.00%
# Test set accuracy for a single minibatch: 32.00%
#
#
# Epoch 4, Iteration 5
# Train Set Loss: 18.43
# Test Set Loss: 18.41
# Train set accuracy for a single minibatch: 29.00%
# Test set accuracy for a single minibatch: 27.00%
#
#
# Epoch 4, Iteration 10
# Train Set Loss: 18.69
# Test Set Loss: 18.45
# Train set accuracy for a single minibatch: 31.00%
# Test set accuracy for a single minibatch: 33.00%
#
#
# Epoch 4, Iteration 15
# Train Set Loss: 18.34
# Test Set Loss: 18.94
# Train set accuracy for a single minibatch: 33.00%
# Test set accuracy for a single minibatch: 21.00%
#
#
# Epoch 4, Iteration 20
# Train Set Loss: 18.51
# Test Set Loss: 17.97
# Train set accuracy for a single minibatch: 29.00%
# Test set accuracy for a single minibatch: 35.00%
#
#
# Epoch 4, Iteration 25
# Train Set Loss: 17.74
# Test Set Loss: 18.18
# Train set accuracy for a single minibatch: 33.00%
# Test set accuracy for a single minibatch: 34.00%
#
#
# Epoch 4, Iteration 30
# Train Set Loss: 18.73
# Test Set Loss: 18.74
# Train set accuracy for a single minibatch: 24.00%
# Test set accuracy for a single minibatch: 24.00%
#
#
# Epoch 4, Iteration 35
# Train Set Loss: 18.46
# Test Set Loss: 17.59
# Train set accuracy for a single minibatch: 31.00%
# Test set accuracy for a single minibatch: 38.00%
#
#
# Epoch 4, Iteration 40
# Train Set Loss: 17.79
# Test Set Loss: 18.18
# Train set accuracy for a single minibatch: 36.00%
# Test set accuracy for a single minibatch: 31.00%
#
#
# Epoch 4, Iteration 45
# Train Set Loss: 18.37
# Test Set Loss: 18.75
# Train set accuracy for a single minibatch: 29.00%
# Test set accuracy for a single minibatch: 31.00%
#
#
# Epoch 4, Iteration 50
# Train Set Loss: 17.90
# Test Set Loss: 18.34
# Train set accuracy for a single minibatch: 35.00%
# Test set accuracy for a single minibatch: 31.00%
#
#
# Epoch 4, Iteration 55
# Train Set Loss: 18.05
# Test Set Loss: 17.45
# Train set accuracy for a single minibatch: 34.00%
# Test set accuracy for a single minibatch: 39.00%
#
#
# Epoch 4, Iteration 60
# Train Set Loss: 18.52
# Test Set Loss: 18.15
# Train set accuracy for a single minibatch: 29.00%
# Test set accuracy for a single minibatch: 27.00%
#
#
# Epoch 4, Iteration 65
# Train Set Loss: 17.47
# Test Set Loss: 17.07
# Train set accuracy for a single minibatch: 39.00%
# Test set accuracy for a single minibatch: 44.00%
#
#
# Epoch 4, Iteration 70
# Train Set Loss: 17.92
# Test Set Loss: 17.95
# Train set accuracy for a single minibatch: 33.00%
# Test set accuracy for a single minibatch: 31.00%
#
#
# Epoch 4, Iteration 75
# Train Set Loss: 17.45
# Test Set Loss: 18.42
# Train set accuracy for a single minibatch: 36.00%
# Test set accuracy for a single minibatch: 33.00%
#
#
# Epoch 4, Iteration 80
# Train Set Loss: 18.36
# Test Set Loss: 17.94
# Train set accuracy for a single minibatch: 27.00%
# Test set accuracy for a single minibatch: 35.00%
#
#
# Epoch 4, Iteration 85
# Train Set Loss: 18.26
# Test Set Loss: 18.43
# Train set accuracy for a single minibatch: 31.00%
# Test set accuracy for a single minibatch: 26.00%
#
#
# Epoch 4, Iteration 90
# Train Set Loss: 17.72
# Test Set Loss: 18.00
# Train set accuracy for a single minibatch: 36.00%
# Test set accuracy for a single minibatch: 25.00%
#
#
# Epoch 5, Iteration 0
# Train Set Loss: 18.01
# Test Set Loss: 18.11
# Train set accuracy for a single minibatch: 26.00%
# Test set accuracy for a single minibatch: 30.00%
#
#
# Epoch 5, Iteration 5
# Train Set Loss: 17.33
# Test Set Loss: 18.15
# Train set accuracy for a single minibatch: 36.00%
# Test set accuracy for a single minibatch: 22.00%
#
#
# Epoch 5, Iteration 10
# Train Set Loss: 18.09
# Test Set Loss: 18.01
# Train set accuracy for a single minibatch: 30.00%
# Test set accuracy for a single minibatch: 31.00%
#
#
# Epoch 5, Iteration 15
# Train Set Loss: 17.80
# Test Set Loss: 18.28
# Train set accuracy for a single minibatch: 35.00%
# Test set accuracy for a single minibatch: 29.00%
#
#
# Epoch 5, Iteration 20
# Train Set Loss: 17.26
# Test Set Loss: 17.39
# Train set accuracy for a single minibatch: 32.00%
# Test set accuracy for a single minibatch: 37.00%
#
#
# Epoch 5, Iteration 25
# Train Set Loss: 17.38
# Test Set Loss: 17.53
# Train set accuracy for a single minibatch: 33.00%
# Test set accuracy for a single minibatch: 36.00%
#
#
# Epoch 5, Iteration 30
# Train Set Loss: 17.33
# Test Set Loss: 18.22
# Train set accuracy for a single minibatch: 33.00%
# Test set accuracy for a single minibatch: 28.00%
#
#
# Epoch 5, Iteration 35
# Train Set Loss: 17.27
# Test Set Loss: 18.14
# Train set accuracy for a single minibatch: 37.00%
# Test set accuracy for a single minibatch: 32.00%
#
#
# Epoch 5, Iteration 40
# Train Set Loss: 18.07
# Test Set Loss: 17.51
# Train set accuracy for a single minibatch: 32.00%
# Test set accuracy for a single minibatch: 35.00%
#
#
# Epoch 5, Iteration 45
# Train Set Loss: 18.34
# Test Set Loss: 17.83
# Train set accuracy for a single minibatch: 33.00%
# Test set accuracy for a single minibatch: 32.00%
#
#
# Epoch 5, Iteration 50
# Train Set Loss: 17.47
# Test Set Loss: 17.89
# Train set accuracy for a single minibatch: 39.00%
# Test set accuracy for a single minibatch: 28.00%
#
#
# Epoch 5, Iteration 55
# Train Set Loss: 18.46
# Test Set Loss: 17.74
# Train set accuracy for a single minibatch: 28.00%
# Test set accuracy for a single minibatch: 29.00%
#
#
# Epoch 5, Iteration 60
# Train Set Loss: 17.54
# Test Set Loss: 17.66
# Train set accuracy for a single minibatch: 32.00%
# Test set accuracy for a single minibatch: 33.00%
#
#
# Epoch 5, Iteration 65
# Train Set Loss: 16.72
# Test Set Loss: 17.94
# Train set accuracy for a single minibatch: 39.00%
# Test set accuracy for a single minibatch: 29.00%
#
#
# Epoch 5, Iteration 70
# Train Set Loss: 17.78
# Test Set Loss: 17.50
# Train set accuracy for a single minibatch: 29.00%
# Test set accuracy for a single minibatch: 39.00%
#
#
# Epoch 5, Iteration 75
# Train Set Loss: 17.97
# Test Set Loss: 17.89
# Train set accuracy for a single minibatch: 30.00%
# Test set accuracy for a single minibatch: 32.00%
#
#
# Epoch 5, Iteration 80
# Train Set Loss: 17.71
# Test Set Loss: 18.15
# Train set accuracy for a single minibatch: 36.00%
# Test set accuracy for a single minibatch: 27.00%
#
#
# Epoch 5, Iteration 85
# Train Set Loss: 16.98
# Test Set Loss: 18.28
# Train set accuracy for a single minibatch: 44.00%
# Test set accuracy for a single minibatch: 24.00%
#
#
# Epoch 5, Iteration 90
# Train Set Loss: 17.28
# Test Set Loss: 17.09
# Train set accuracy for a single minibatch: 38.00%
# Test set accuracy for a single minibatch: 36.00%
#
#
# Epoch 6, Iteration 0
# Train Set Loss: 17.72
# Test Set Loss: 16.94
# Train set accuracy for a single minibatch: 30.00%
# Test set accuracy for a single minibatch: 38.00%
#
#
# Epoch 6, Iteration 5
# Train Set Loss: 17.02
# Test Set Loss: 17.02
# Train set accuracy for a single minibatch: 30.00%
# Test set accuracy for a single minibatch: 37.00%
#
#
# Epoch 6, Iteration 10
# Train Set Loss: 17.23
# Test Set Loss: 17.34
# Train set accuracy for a single minibatch: 35.00%
# Test set accuracy for a single minibatch: 32.00%
#
#
# Epoch 6, Iteration 15
# Train Set Loss: 17.91
# Test Set Loss: 17.58
# Train set accuracy for a single minibatch: 27.00%
# Test set accuracy for a single minibatch: 32.00%
#
#
# Epoch 6, Iteration 20
# Train Set Loss: 16.59
# Test Set Loss: 17.02
# Train set accuracy for a single minibatch: 31.00%
# Test set accuracy for a single minibatch: 34.00%
#
#
# Epoch 6, Iteration 25
# Train Set Loss: 17.07
# Test Set Loss: 16.70
# Train set accuracy for a single minibatch: 37.00%
# Test set accuracy for a single minibatch: 45.00%
#
#
# Epoch 6, Iteration 30
# Train Set Loss: 16.66
# Test Set Loss: 17.85
# Train set accuracy for a single minibatch: 36.00%
# Test set accuracy for a single minibatch: 23.00%
#
#
# Epoch 6, Iteration 35
# Train Set Loss: 17.84
# Test Set Loss: 17.59
# Train set accuracy for a single minibatch: 27.00%
# Test set accuracy for a single minibatch: 27.00%
#
#
# Epoch 6, Iteration 40
# Train Set Loss: 17.45
# Test Set Loss: 16.92
# Train set accuracy for a single minibatch: 28.00%
# Test set accuracy for a single minibatch: 30.00%
#
#
# Epoch 6, Iteration 45
# Train Set Loss: 16.92
# Test Set Loss: 17.26
# Train set accuracy for a single minibatch: 34.00%
# Test set accuracy for a single minibatch: 33.00%
#
#
# Epoch 6, Iteration 50
# Train Set Loss: 16.36
# Test Set Loss: 16.88
# Train set accuracy for a single minibatch: 37.00%
# Test set accuracy for a single minibatch: 33.00%
#
#
# Epoch 6, Iteration 55
# Train Set Loss: 17.77
# Test Set Loss: 16.35
# Train set accuracy for a single minibatch: 26.00%
# Test set accuracy for a single minibatch: 32.00%
#
#
# Epoch 6, Iteration 60
# Train Set Loss: 17.30
# Test Set Loss: 17.47
# Train set accuracy for a single minibatch: 33.00%
# Test set accuracy for a single minibatch: 32.00%
#
#
# Epoch 6, Iteration 65
# Train Set Loss: 16.44
# Test Set Loss: 16.80
# Train set accuracy for a single minibatch: 46.00%
# Test set accuracy for a single minibatch: 36.00%
#
#
# Epoch 6, Iteration 70
# Train Set Loss: 17.73
# Test Set Loss: 16.96
# Train set accuracy for a single minibatch: 29.00%
# Test set accuracy for a single minibatch: 28.00%
#
#
# Epoch 6, Iteration 75
# Train Set Loss: 16.63
# Test Set Loss: 16.74
# Train set accuracy for a single minibatch: 33.00%
# Test set accuracy for a single minibatch: 32.00%
#
#
# Epoch 6, Iteration 80
# Train Set Loss: 16.93
# Test Set Loss: 16.93
# Train set accuracy for a single minibatch: 32.00%
# Test set accuracy for a single minibatch: 35.00%
#
#
# Epoch 6, Iteration 85
# Train Set Loss: 16.76
# Test Set Loss: 16.98
# Train set accuracy for a single minibatch: 28.00%
# Test set accuracy for a single minibatch: 33.00%
#
#
# Epoch 6, Iteration 90
# Train Set Loss: 16.21
# Test Set Loss: 16.42
# Train set accuracy for a single minibatch: 36.00%
# Test set accuracy for a single minibatch: 38.00%
#
#
# Epoch 7, Iteration 0
# Train Set Loss: 16.81
# Test Set Loss: 16.46
# Train set accuracy for a single minibatch: 31.00%
# Test set accuracy for a single minibatch: 30.00%
#
#
# Epoch 7, Iteration 5
# Train Set Loss: 16.55
# Test Set Loss: 16.14
# Train set accuracy for a single minibatch: 44.00%
# Test set accuracy for a single minibatch: 36.00%
#
#
# Epoch 7, Iteration 10
# Train Set Loss: 16.18
# Test Set Loss: 16.82
# Train set accuracy for a single minibatch: 40.00%
# Test set accuracy for a single minibatch: 26.00%
#
#
# Epoch 7, Iteration 15
# Train Set Loss: 16.33
# Test Set Loss: 16.73
# Train set accuracy for a single minibatch: 31.00%
# Test set accuracy for a single minibatch: 37.00%
#
#
# Epoch 7, Iteration 20
# Train Set Loss: 16.02
# Test Set Loss: 16.35
# Train set accuracy for a single minibatch: 37.00%
# Test set accuracy for a single minibatch: 34.00%
#
#
# Epoch 7, Iteration 25
# Train Set Loss: 16.62
# Test Set Loss: 15.81
# Train set accuracy for a single minibatch: 33.00%
# Test set accuracy for a single minibatch: 34.00%
#
#
# Epoch 7, Iteration 30
# Train Set Loss: 15.84
# Test Set Loss: 17.52
# Train set accuracy for a single minibatch: 35.00%
# Test set accuracy for a single minibatch: 27.00%
#
#
# Epoch 7, Iteration 35
# Train Set Loss: 16.18
# Test Set Loss: 17.38
# Train set accuracy for a single minibatch: 35.00%
# Test set accuracy for a single minibatch: 26.00%
#
#
# Epoch 7, Iteration 40
# Train Set Loss: 16.76
# Test Set Loss: 16.73
# Train set accuracy for a single minibatch: 28.00%
# Test set accuracy for a single minibatch: 28.00%
#
#
# Epoch 7, Iteration 45
# Train Set Loss: 17.36
# Test Set Loss: 16.09
# Train set accuracy for a single minibatch: 28.00%
# Test set accuracy for a single minibatch: 27.00%
#
#
# Epoch 7, Iteration 50
# Train Set Loss: 16.50
# Test Set Loss: 15.98
# Train set accuracy for a single minibatch: 30.00%
# Test set accuracy for a single minibatch: 28.00%
#
#
# Epoch 7, Iteration 55
# Train Set Loss: 16.83
# Test Set Loss: 16.70
# Train set accuracy for a single minibatch: 26.00%
# Test set accuracy for a single minibatch: 36.00%
#
#
# Epoch 7, Iteration 60
# Train Set Loss: 16.10
# Test Set Loss: 16.59
# Train set accuracy for a single minibatch: 37.00%
# Test set accuracy for a single minibatch: 29.00%
#
#
# Epoch 7, Iteration 65
# Train Set Loss: 16.47
# Test Set Loss: 15.75
# Train set accuracy for a single minibatch: 34.00%
# Test set accuracy for a single minibatch: 35.00%
#
#
# Epoch 7, Iteration 70
# Train Set Loss: 15.89
# Test Set Loss: 16.84
# Train set accuracy for a single minibatch: 31.00%
# Test set accuracy for a single minibatch: 26.00%
#
#
# Epoch 7, Iteration 75
# Train Set Loss: 16.27
# Test Set Loss: 16.61
# Train set accuracy for a single minibatch: 30.00%
# Test set accuracy for a single minibatch: 24.00%
#
#
# Epoch 7, Iteration 80
# Train Set Loss: 15.78
# Test Set Loss: 16.44
# Train set accuracy for a single minibatch: 41.00%
# Test set accuracy for a single minibatch: 35.00%
#
#
# Epoch 7, Iteration 85
# Train Set Loss: 15.86
# Test Set Loss: 16.66
# Train set accuracy for a single minibatch: 39.00%
# Test set accuracy for a single minibatch: 30.00%
#
#
# Epoch 7, Iteration 90
# Train Set Loss: 15.17
# Test Set Loss: 16.12
# Train set accuracy for a single minibatch: 38.00%
# Test set accuracy for a single minibatch: 29.00%
#
#
# Epoch 8, Iteration 0
# Train Set Loss: 16.19
# Test Set Loss: 15.35
# Train set accuracy for a single minibatch: 39.00%
# Test set accuracy for a single minibatch: 33.00%
#
#
# Epoch 8, Iteration 5
# Train Set Loss: 15.80
# Test Set Loss: 16.64
# Train set accuracy for a single minibatch: 35.00%
# Test set accuracy for a single minibatch: 34.00%
#
#
# Epoch 8, Iteration 10
# Train Set Loss: 15.97
# Test Set Loss: 15.86
# Train set accuracy for a single minibatch: 32.00%
# Test set accuracy for a single minibatch: 25.00%
#
#
# Epoch 8, Iteration 15
# Train Set Loss: 15.92
# Test Set Loss: 15.21
# Train set accuracy for a single minibatch: 28.00%
# Test set accuracy for a single minibatch: 34.00%
#
#
# Epoch 8, Iteration 20
# Train Set Loss: 15.57
# Test Set Loss: 15.98
# Train set accuracy for a single minibatch: 36.00%
# Test set accuracy for a single minibatch: 35.00%
#
#
# Epoch 8, Iteration 25
# Train Set Loss: 15.44
# Test Set Loss: 16.38
# Train set accuracy for a single minibatch: 35.00%
# Test set accuracy for a single minibatch: 30.00%
#
#
# Epoch 8, Iteration 30
# Train Set Loss: 15.34
# Test Set Loss: 16.19
# Train set accuracy for a single minibatch: 33.00%
# Test set accuracy for a single minibatch: 35.00%
#
#
# Epoch 8, Iteration 35
# Train Set Loss: 16.30
# Test Set Loss: 15.31
# Train set accuracy for a single minibatch: 28.00%
# Test set accuracy for a single minibatch: 33.00%
#
#
# Epoch 8, Iteration 40
# Train Set Loss: 15.16
# Test Set Loss: 15.54
# Train set accuracy for a single minibatch: 28.00%
# Test set accuracy for a single minibatch: 30.00%
#
#
# Epoch 8, Iteration 45
# Train Set Loss: 15.87
# Test Set Loss: 15.85
# Train set accuracy for a single minibatch: 29.00%
# Test set accuracy for a single minibatch: 29.00%
#
#
# Epoch 8, Iteration 50
# Train Set Loss: 15.46
# Test Set Loss: 15.76
# Train set accuracy for a single minibatch: 29.00%
# Test set accuracy for a single minibatch: 31.00%
#
#
# Epoch 8, Iteration 55
# Train Set Loss: 15.32
# Test Set Loss: 14.92
# Train set accuracy for a single minibatch: 27.00%
# Test set accuracy for a single minibatch: 32.00%
#
#
# Epoch 8, Iteration 60
# Train Set Loss: 15.56
# Test Set Loss: 15.91
# Train set accuracy for a single minibatch: 35.00%
# Test set accuracy for a single minibatch: 28.00%
#
#
# Epoch 8, Iteration 65
# Train Set Loss: 15.23
# Test Set Loss: 15.29
# Train set accuracy for a single minibatch: 32.00%
# Test set accuracy for a single minibatch: 34.00%
#
#
# Epoch 8, Iteration 70
# Train Set Loss: 15.48
# Test Set Loss: 15.36
# Train set accuracy for a single minibatch: 31.00%
# Test set accuracy for a single minibatch: 31.00%
#
#
# Epoch 8, Iteration 75
# Train Set Loss: 15.70
# Test Set Loss: 15.24
# Train set accuracy for a single minibatch: 30.00%
# Test set accuracy for a single minibatch: 31.00%
#
#
# Epoch 8, Iteration 80
# Train Set Loss: 14.92
# Test Set Loss: 15.85
# Train set accuracy for a single minibatch: 39.00%
# Test set accuracy for a single minibatch: 30.00%
#
#
# Epoch 8, Iteration 85
# Train Set Loss: 15.28
# Test Set Loss: 15.33
# Train set accuracy for a single minibatch: 35.00%
# Test set accuracy for a single minibatch: 33.00%
#
#
# Epoch 8, Iteration 90
# Train Set Loss: 16.12
# Test Set Loss: 14.72
# Train set accuracy for a single minibatch: 34.00%
# Test set accuracy for a single minibatch: 43.00%
#
#
# Epoch 9, Iteration 0
# Train Set Loss: 14.90
# Test Set Loss: 15.91
# Train set accuracy for a single minibatch: 43.00%
# Test set accuracy for a single minibatch: 25.00%
#
#
# Epoch 9, Iteration 5
# Train Set Loss: 14.90
# Test Set Loss: 15.01
# Train set accuracy for a single minibatch: 36.00%
# Test set accuracy for a single minibatch: 34.00%
#
#
# Epoch 9, Iteration 10
# Train Set Loss: 15.02
# Test Set Loss: 15.22
# Train set accuracy for a single minibatch: 36.00%
# Test set accuracy for a single minibatch: 27.00%
#
#
# Epoch 9, Iteration 15
# Train Set Loss: 15.22
# Test Set Loss: 15.29
# Train set accuracy for a single minibatch: 32.00%
# Test set accuracy for a single minibatch: 24.00%
#
#
# Epoch 9, Iteration 20
# Train Set Loss: 15.52
# Test Set Loss: 16.13
# Train set accuracy for a single minibatch: 25.00%
# Test set accuracy for a single minibatch: 33.00%
#
#
# Epoch 9, Iteration 25
# Train Set Loss: 14.67
# Test Set Loss: 14.48
# Train set accuracy for a single minibatch: 35.00%
# Test set accuracy for a single minibatch: 35.00%
#
#
# Epoch 9, Iteration 30
# Train Set Loss: 15.10
# Test Set Loss: 15.66
# Train set accuracy for a single minibatch: 34.00%
# Test set accuracy for a single minibatch: 25.00%
#
#
# Epoch 9, Iteration 35
# Train Set Loss: 15.27
# Test Set Loss: 14.65
# Train set accuracy for a single minibatch: 37.00%
# Test set accuracy for a single minibatch: 41.00%
#
#
# Epoch 9, Iteration 40
# Train Set Loss: 14.66
# Test Set Loss: 14.96
# Train set accuracy for a single minibatch: 32.00%
# Test set accuracy for a single minibatch: 38.00%
#
#
# Epoch 9, Iteration 45
# Train Set Loss: 14.94
# Test Set Loss: 14.02
# Train set accuracy for a single minibatch: 40.00%
# Test set accuracy for a single minibatch: 33.00%
#
#
# Epoch 9, Iteration 50
# Train Set Loss: 15.25
# Test Set Loss: 14.61
# Train set accuracy for a single minibatch: 33.00%
# Test set accuracy for a single minibatch: 37.00%
#
#
# Epoch 9, Iteration 55
# Train Set Loss: 14.09
# Test Set Loss: 14.57
# Train set accuracy for a single minibatch: 31.00%
# Test set accuracy for a single minibatch: 38.00%
#
#
# Epoch 9, Iteration 60
# Train Set Loss: 15.18
# Test Set Loss: 15.72
# Train set accuracy for a single minibatch: 34.00%
# Test set accuracy for a single minibatch: 25.00%
#
#
# Epoch 9, Iteration 65
# Train Set Loss: 15.10
# Test Set Loss: 14.86
# Train set accuracy for a single minibatch: 25.00%
# Test set accuracy for a single minibatch: 39.00%
#
#
# Epoch 9, Iteration 70
# Train Set Loss: 15.15
# Test Set Loss: 14.12
# Train set accuracy for a single minibatch: 33.00%
# Test set accuracy for a single minibatch: 36.00%
#
#
# Epoch 9, Iteration 75
# Train Set Loss: 14.63
# Test Set Loss: 14.95
# Train set accuracy for a single minibatch: 29.00%
# Test set accuracy for a single minibatch: 35.00%
#
#
# Epoch 9, Iteration 80
# Train Set Loss: 14.57
# Test Set Loss: 15.14
# Train set accuracy for a single minibatch: 41.00%
# Test set accuracy for a single minibatch: 42.00%
#
#
# Epoch 9, Iteration 85
# Train Set Loss: 14.76
# Test Set Loss: 15.14
# Train set accuracy for a single minibatch: 29.00%
# Test set accuracy for a single minibatch: 32.00%
#
#
# Epoch 9, Iteration 90
# Train Set Loss: 14.96
# Test Set Loss: 15.37
# Train set accuracy for a single minibatch: 28.00%
# Test set accuracy for a single minibatch: 28.00%
#
#
# Epoch 10, Iteration 0
# Train Set Loss: 14.26
# Test Set Loss: 14.33
# Train set accuracy for a single minibatch: 36.00%
# Test set accuracy for a single minibatch: 36.00%
#
#
# Epoch 10, Iteration 5
# Train Set Loss: 14.33
# Test Set Loss: 15.43
# Train set accuracy for a single minibatch: 32.00%
# Test set accuracy for a single minibatch: 29.00%
#
#
# Epoch 10, Iteration 10
# Train Set Loss: 15.24
# Test Set Loss: 14.05
# Train set accuracy for a single minibatch: 24.00%
# Test set accuracy for a single minibatch: 40.00%
#
#
# Epoch 10, Iteration 15
# Train Set Loss: 14.66
# Test Set Loss: 13.94
# Train set accuracy for a single minibatch: 34.00%
# Test set accuracy for a single minibatch: 31.00%
#
#
# Epoch 10, Iteration 20
# Train Set Loss: 14.48
# Test Set Loss: 13.82
# Train set accuracy for a single minibatch: 36.00%
# Test set accuracy for a single minibatch: 44.00%
#
#
# Epoch 10, Iteration 25
# Train Set Loss: 13.99
# Test Set Loss: 14.34
# Train set accuracy for a single minibatch: 40.00%
# Test set accuracy for a single minibatch: 32.00%
#
#
# Epoch 10, Iteration 30
# Train Set Loss: 14.39
# Test Set Loss: 15.21
# Train set accuracy for a single minibatch: 34.00%
# Test set accuracy for a single minibatch: 26.00%
#
#
# Epoch 10, Iteration 35
# Train Set Loss: 14.21
# Test Set Loss: 13.93
# Train set accuracy for a single minibatch: 26.00%
# Test set accuracy for a single minibatch: 41.00%
#
#
# Epoch 10, Iteration 40
# Train Set Loss: 14.06
# Test Set Loss: 13.98
# Train set accuracy for a single minibatch: 36.00%
# Test set accuracy for a single minibatch: 36.00%
#
#
# Epoch 10, Iteration 45
# Train Set Loss: 15.66
# Test Set Loss: 14.50
# Train set accuracy for a single minibatch: 25.00%
# Test set accuracy for a single minibatch: 41.00%
#
#
# Epoch 10, Iteration 50
# Train Set Loss: 14.66
# Test Set Loss: 14.57
# Train set accuracy for a single minibatch: 25.00%
# Test set accuracy for a single minibatch: 26.00%
#
#
# Epoch 10, Iteration 55
# Train Set Loss: 14.56
# Test Set Loss: 14.17
# Train set accuracy for a single minibatch: 35.00%
# Test set accuracy for a single minibatch: 31.00%
#
#
# Epoch 10, Iteration 60
# Train Set Loss: 14.43
# Test Set Loss: 14.55
# Train set accuracy for a single minibatch: 31.00%
# Test set accuracy for a single minibatch: 37.00%
#
#
# Epoch 10, Iteration 65
# Train Set Loss: 14.85
# Test Set Loss: 12.93
# Train set accuracy for a single minibatch: 32.00%
# Test set accuracy for a single minibatch: 44.00%
#
#
# Epoch 10, Iteration 70
# Train Set Loss: 14.00
# Test Set Loss: 14.05
# Train set accuracy for a single minibatch: 37.00%
# Test set accuracy for a single minibatch: 39.00%
#
#
# Epoch 10, Iteration 75
# Train Set Loss: 14.32
# Test Set Loss: 14.23
# Train set accuracy for a single minibatch: 34.00%
# Test set accuracy for a single minibatch: 30.00%
#
#
# Epoch 10, Iteration 80
# Train Set Loss: 13.48
# Test Set Loss: 13.54
# Train set accuracy for a single minibatch: 30.00%
# Test set accuracy for a single minibatch: 34.00%
#
#
# Epoch 10, Iteration 85
# Train Set Loss: 13.68
# Test Set Loss: 14.20
# Train set accuracy for a single minibatch: 33.00%
# Test set accuracy for a single minibatch: 29.00%
#
#
# Epoch 10, Iteration 90
# Train Set Loss: 14.49
# Test Set Loss: 13.73
# Train set accuracy for a single minibatch: 29.00%
# Test set accuracy for a single minibatch: 38.00%
#
#
# Epoch 11, Iteration 0
# Train Set Loss: 15.01
# Test Set Loss: 14.29
# Train set accuracy for a single minibatch: 25.00%
# Test set accuracy for a single minibatch: 29.00%
#
#
# Epoch 11, Iteration 5
# Train Set Loss: 13.65
# Test Set Loss: 13.47
# Train set accuracy for a single minibatch: 35.00%
# Test set accuracy for a single minibatch: 38.00%
#
#
# Epoch 11, Iteration 10
# Train Set Loss: 14.92
# Test Set Loss: 14.47
# Train set accuracy for a single minibatch: 27.00%
# Test set accuracy for a single minibatch: 35.00%
#
#
# Epoch 11, Iteration 15
# Train Set Loss: 14.07
# Test Set Loss: 13.87
# Train set accuracy for a single minibatch: 41.00%
# Test set accuracy for a single minibatch: 35.00%
#
#
# Epoch 11, Iteration 20
# Train Set Loss: 13.85
# Test Set Loss: 14.89
# Train set accuracy for a single minibatch: 27.00%
# Test set accuracy for a single minibatch: 34.00%
#
#
# Epoch 11, Iteration 25
# Train Set Loss: 13.67
# Test Set Loss: 14.54
# Train set accuracy for a single minibatch: 33.00%
# Test set accuracy for a single minibatch: 30.00%
#
#
# Epoch 11, Iteration 30
# Train Set Loss: 14.07
# Test Set Loss: 14.59
# Train set accuracy for a single minibatch: 34.00%
# Test set accuracy for a single minibatch: 33.00%
#
#
# Epoch 11, Iteration 35
# Train Set Loss: 13.97
# Test Set Loss: 13.69
# Train set accuracy for a single minibatch: 33.00%
# Test set accuracy for a single minibatch: 39.00%
#
#
# Epoch 11, Iteration 40
# Train Set Loss: 14.14
# Test Set Loss: 13.29
# Train set accuracy for a single minibatch: 35.00%
# Test set accuracy for a single minibatch: 38.00%
#
#
# Epoch 11, Iteration 45
# Train Set Loss: 13.55
# Test Set Loss: 13.65
# Train set accuracy for a single minibatch: 35.00%
# Test set accuracy for a single minibatch: 37.00%
#
#
# Epoch 11, Iteration 50
# Train Set Loss: 14.24
# Test Set Loss: 14.14
# Train set accuracy for a single minibatch: 25.00%
# Test set accuracy for a single minibatch: 24.00%
#
#
# Epoch 11, Iteration 55
# Train Set Loss: 14.05
# Test Set Loss: 13.58
# Train set accuracy for a single minibatch: 31.00%
# Test set accuracy for a single minibatch: 33.00%
#
#
# Epoch 11, Iteration 60
# Train Set Loss: 14.79
# Test Set Loss: 13.60
# Train set accuracy for a single minibatch: 33.00%
# Test set accuracy for a single minibatch: 27.00%
#
#
# Epoch 11, Iteration 65
# Train Set Loss: 14.02
# Test Set Loss: 13.87
# Train set accuracy for a single minibatch: 31.00%
# Test set accuracy for a single minibatch: 37.00%
#
#
# Epoch 11, Iteration 70
# Train Set Loss: 14.82
# Test Set Loss: 12.91
# Train set accuracy for a single minibatch: 31.00%
# Test set accuracy for a single minibatch: 41.00%
#
#
# Epoch 11, Iteration 75
# Train Set Loss: 13.25
# Test Set Loss: 13.56
# Train set accuracy for a single minibatch: 38.00%
# Test set accuracy for a single minibatch: 34.00%
#
#
# Epoch 11, Iteration 80
# Train Set Loss: 14.22
# Test Set Loss: 13.45
# Train set accuracy for a single minibatch: 24.00%
# Test set accuracy for a single minibatch: 32.00%
#
#
# Epoch 11, Iteration 85
# Train Set Loss: 14.22
# Test Set Loss: 13.78
# Train set accuracy for a single minibatch: 34.00%
# Test set accuracy for a single minibatch: 30.00%
#
#
# Epoch 11, Iteration 90
# Train Set Loss: 12.96
# Test Set Loss: 13.03
# Train set accuracy for a single minibatch: 34.00%
# Test set accuracy for a single minibatch: 29.00%
#
#
# Epoch 12, Iteration 0
# Train Set Loss: 13.45
# Test Set Loss: 14.28
# Train set accuracy for a single minibatch: 38.00%
# Test set accuracy for a single minibatch: 37.00%
#
#
# Epoch 12, Iteration 5
# Train Set Loss: 13.61
# Test Set Loss: 14.60
# Train set accuracy for a single minibatch: 39.00%
# Test set accuracy for a single minibatch: 33.00%
#
#
# Epoch 12, Iteration 10
# Train Set Loss: 13.73
# Test Set Loss: 13.64
# Train set accuracy for a single minibatch: 32.00%
# Test set accuracy for a single minibatch: 32.00%
#
#
# Epoch 12, Iteration 15
# Train Set Loss: 14.40
# Test Set Loss: 13.31
# Train set accuracy for a single minibatch: 30.00%
# Test set accuracy for a single minibatch: 35.00%
#
#
# Epoch 12, Iteration 20
# Train Set Loss: 14.53
# Test Set Loss: 13.56
# Train set accuracy for a single minibatch: 35.00%
# Test set accuracy for a single minibatch: 34.00%
#
#
# Epoch 12, Iteration 25
# Train Set Loss: 13.63
# Test Set Loss: 13.04
# Train set accuracy for a single minibatch: 37.00%
# Test set accuracy for a single minibatch: 39.00%
#
#
# Epoch 12, Iteration 30
# Train Set Loss: 12.48
# Test Set Loss: 13.76
# Train set accuracy for a single minibatch: 43.00%
# Test set accuracy for a single minibatch: 38.00%
#
#
# Epoch 12, Iteration 35
# Train Set Loss: 14.39
# Test Set Loss: 13.19
# Train set accuracy for a single minibatch: 38.00%
# Test set accuracy for a single minibatch: 31.00%
#
#
# Epoch 12, Iteration 40
# Train Set Loss: 13.84
# Test Set Loss: 14.12
# Train set accuracy for a single minibatch: 37.00%
# Test set accuracy for a single minibatch: 28.00%
#
#
# Epoch 12, Iteration 45
# Train Set Loss: 13.69
# Test Set Loss: 13.93
# Train set accuracy for a single minibatch: 32.00%
# Test set accuracy for a single minibatch: 30.00%
#
#
# Epoch 12, Iteration 50
# Train Set Loss: 13.59
# Test Set Loss: 14.47
# Train set accuracy for a single minibatch: 34.00%
# Test set accuracy for a single minibatch: 31.00%
#
#
# Epoch 12, Iteration 55
# Train Set Loss: 13.08
# Test Set Loss: 13.70
# Train set accuracy for a single minibatch: 37.00%
# Test set accuracy for a single minibatch: 32.00%
#
#
# Epoch 12, Iteration 60
# Train Set Loss: 14.27
# Test Set Loss: 13.80
# Train set accuracy for a single minibatch: 32.00%
# Test set accuracy for a single minibatch: 32.00%
#
#
# Epoch 12, Iteration 65
# Train Set Loss: 13.73
# Test Set Loss: 13.95
# Train set accuracy for a single minibatch: 31.00%
# Test set accuracy for a single minibatch: 29.00%
#
#
# Epoch 12, Iteration 70
# Train Set Loss: 13.45
# Test Set Loss: 13.78
# Train set accuracy for a single minibatch: 35.00%
# Test set accuracy for a single minibatch: 28.00%
#
#
# Epoch 12, Iteration 75
# Train Set Loss: 13.52
# Test Set Loss: 13.73
# Train set accuracy for a single minibatch: 33.00%
# Test set accuracy for a single minibatch: 30.00%
#
#
# Epoch 12, Iteration 80
# Train Set Loss: 13.67
# Test Set Loss: 13.61
# Train set accuracy for a single minibatch: 31.00%
# Test set accuracy for a single minibatch: 34.00%
#
#
# Epoch 12, Iteration 85
# Train Set Loss: 12.61
# Test Set Loss: 13.32
# Train set accuracy for a single minibatch: 34.00%
# Test set accuracy for a single minibatch: 39.00%
#
#
# Epoch 12, Iteration 90
# Train Set Loss: 13.29
# Test Set Loss: 13.82
# Train set accuracy for a single minibatch: 35.00%
# Test set accuracy for a single minibatch: 30.00%
#
#
# Epoch 13, Iteration 0
# Train Set Loss: 13.66
# Test Set Loss: 13.62
# Train set accuracy for a single minibatch: 38.00%
# Test set accuracy for a single minibatch: 28.00%
#
#
# Epoch 13, Iteration 5
# Train Set Loss: 13.16
# Test Set Loss: 13.63
# Train set accuracy for a single minibatch: 38.00%
# Test set accuracy for a single minibatch: 32.00%
#
#
# Epoch 13, Iteration 10
# Train Set Loss: 13.02
# Test Set Loss: 12.97
# Train set accuracy for a single minibatch: 36.00%
# Test set accuracy for a single minibatch: 34.00%
#
#
# Epoch 13, Iteration 15
# Train Set Loss: 12.88
# Test Set Loss: 13.10
# Train set accuracy for a single minibatch: 29.00%
# Test set accuracy for a single minibatch: 37.00%
#
#
# Epoch 13, Iteration 20
# Train Set Loss: 13.86
# Test Set Loss: 13.35
# Train set accuracy for a single minibatch: 29.00%
# Test set accuracy for a single minibatch: 32.00%
#
#
# Epoch 13, Iteration 25
# Train Set Loss: 13.08
# Test Set Loss: 13.12
# Train set accuracy for a single minibatch: 30.00%
# Test set accuracy for a single minibatch: 39.00%
#
#
# Epoch 13, Iteration 30
# Train Set Loss: 13.52
# Test Set Loss: 13.36
# Train set accuracy for a single minibatch: 30.00%
# Test set accuracy for a single minibatch: 31.00%
#
#
# Epoch 13, Iteration 35
# Train Set Loss: 13.69
# Test Set Loss: 13.16
# Train set accuracy for a single minibatch: 29.00%
# Test set accuracy for a single minibatch: 35.00%
#
#
# Epoch 13, Iteration 40
# Train Set Loss: 13.28
# Test Set Loss: 12.20
# Train set accuracy for a single minibatch: 30.00%
# Test set accuracy for a single minibatch: 43.00%
#
#
# Epoch 13, Iteration 45
# Train Set Loss: 14.26
# Test Set Loss: 13.48
# Train set accuracy for a single minibatch: 31.00%
# Test set accuracy for a single minibatch: 25.00%
#
#
# Epoch 13, Iteration 50
# Train Set Loss: 13.32
# Test Set Loss: 12.54
# Train set accuracy for a single minibatch: 32.00%
# Test set accuracy for a single minibatch: 36.00%
#
#
# Epoch 13, Iteration 55
# Train Set Loss: 13.70
# Test Set Loss: 12.77
# Train set accuracy for a single minibatch: 32.00%
# Test set accuracy for a single minibatch: 39.00%
#
#
# Epoch 13, Iteration 60
# Train Set Loss: 12.98
# Test Set Loss: 12.64
# Train set accuracy for a single minibatch: 41.00%
# Test set accuracy for a single minibatch: 32.00%
#
#
# Epoch 13, Iteration 65
# Train Set Loss: 13.39
# Test Set Loss: 14.06
# Train set accuracy for a single minibatch: 26.00%
# Test set accuracy for a single minibatch: 32.00%
#
#
# Epoch 13, Iteration 70
# Train Set Loss: 14.27
# Test Set Loss: 12.84
# Train set accuracy for a single minibatch: 34.00%
# Test set accuracy for a single minibatch: 36.00%
#
#
# Epoch 13, Iteration 75
# Train Set Loss: 13.64
# Test Set Loss: 12.68
# Train set accuracy for a single minibatch: 28.00%
# Test set accuracy for a single minibatch: 38.00%
#
#
# Epoch 13, Iteration 80
# Train Set Loss: 13.00
# Test Set Loss: 13.04
# Train set accuracy for a single minibatch: 33.00%
# Test set accuracy for a single minibatch: 31.00%
#
#
# Epoch 13, Iteration 85
# Train Set Loss: 12.69
# Test Set Loss: 13.07
# Train set accuracy for a single minibatch: 31.00%
# Test set accuracy for a single minibatch: 32.00%
#
#
# Epoch 13, Iteration 90
# Train Set Loss: 13.35
# Test Set Loss: 13.58
# Train set accuracy for a single minibatch: 28.00%
# Test set accuracy for a single minibatch: 34.00%
#
#
# Epoch 14, Iteration 0
# Train Set Loss: 13.38
# Test Set Loss: 12.40
# Train set accuracy for a single minibatch: 34.00%
# Test set accuracy for a single minibatch: 35.00%
#
#
# Epoch 14, Iteration 5
# Train Set Loss: 13.29
# Test Set Loss: 13.67
# Train set accuracy for a single minibatch: 27.00%
# Test set accuracy for a single minibatch: 25.00%
#
#
# Epoch 14, Iteration 10
# Train Set Loss: 12.37
# Test Set Loss: 13.22
# Train set accuracy for a single minibatch: 33.00%
# Test set accuracy for a single minibatch: 21.00%
#
#
# Epoch 14, Iteration 15
# Train Set Loss: 13.30
# Test Set Loss: 13.09
# Train set accuracy for a single minibatch: 34.00%
# Test set accuracy for a single minibatch: 33.00%
#
#
# Epoch 14, Iteration 20
# Train Set Loss: 12.50
# Test Set Loss: 13.52
# Train set accuracy for a single minibatch: 36.00%
# Test set accuracy for a single minibatch: 23.00%
#
#
# Epoch 14, Iteration 25
# Train Set Loss: 12.41
# Test Set Loss: 12.30
# Train set accuracy for a single minibatch: 35.00%
# Test set accuracy for a single minibatch: 36.00%
#
#
# Epoch 14, Iteration 30
# Train Set Loss: 13.21
# Test Set Loss: 13.46
# Train set accuracy for a single minibatch: 27.00%
# Test set accuracy for a single minibatch: 31.00%
#
#
# Epoch 14, Iteration 35
# Train Set Loss: 13.17
# Test Set Loss: 12.82
# Train set accuracy for a single minibatch: 31.00%
# Test set accuracy for a single minibatch: 38.00%
#
#
# Epoch 14, Iteration 40
# Train Set Loss: 12.90
# Test Set Loss: 13.32
# Train set accuracy for a single minibatch: 36.00%
# Test set accuracy for a single minibatch: 33.00%
#
#
# Epoch 14, Iteration 45
# Train Set Loss: 12.53
# Test Set Loss: 12.86
# Train set accuracy for a single minibatch: 38.00%
# Test set accuracy for a single minibatch: 34.00%
#
#
# Epoch 14, Iteration 50
# Train Set Loss: 12.96
# Test Set Loss: 12.51
# Train set accuracy for a single minibatch: 28.00%
# Test set accuracy for a single minibatch: 33.00%
#
#
# Epoch 14, Iteration 55
# Train Set Loss: 12.98
# Test Set Loss: 12.43
# Train set accuracy for a single minibatch: 31.00%
# Test set accuracy for a single minibatch: 33.00%
#
#
# Epoch 14, Iteration 60
# Train Set Loss: 12.67
# Test Set Loss: 13.22
# Train set accuracy for a single minibatch: 35.00%
# Test set accuracy for a single minibatch: 34.00%
#
#
# Epoch 14, Iteration 65
# Train Set Loss: 12.45
# Test Set Loss: 12.90
# Train set accuracy for a single minibatch: 32.00%
# Test set accuracy for a single minibatch: 29.00%
#
#
# Epoch 14, Iteration 70
# Train Set Loss: 12.32
# Test Set Loss: 12.36
# Train set accuracy for a single minibatch: 38.00%
# Test set accuracy for a single minibatch: 42.00%
#
#
# Epoch 14, Iteration 75
# Train Set Loss: 12.16
# Test Set Loss: 13.12
# Train set accuracy for a single minibatch: 36.00%
# Test set accuracy for a single minibatch: 31.00%
#
#
# Epoch 14, Iteration 80
# Train Set Loss: 12.37
# Test Set Loss: 13.41
# Train set accuracy for a single minibatch: 31.00%
# Test set accuracy for a single minibatch: 28.00%
#
#
# Epoch 14, Iteration 85
# Train Set Loss: 13.43
# Test Set Loss: 12.21
# Train set accuracy for a single minibatch: 32.00%
# Test set accuracy for a single minibatch: 43.00%
#
#
# Epoch 14, Iteration 90
# Train Set Loss: 12.73
# Test Set Loss: 13.49
# Train set accuracy for a single minibatch: 26.00%
# Test set accuracy for a single minibatch: 32.00%
#
#
# Epoch 15, Iteration 0
# Train Set Loss: 13.16
# Test Set Loss: 12.13
# Train set accuracy for a single minibatch: 30.00%
# Test set accuracy for a single minibatch: 38.00%
#
#
# Epoch 15, Iteration 5
# Train Set Loss: 13.02
# Test Set Loss: 12.53
# Train set accuracy for a single minibatch: 35.00%
# Test set accuracy for a single minibatch: 36.00%
#
#
# Epoch 15, Iteration 10
# Train Set Loss: 13.20
# Test Set Loss: 12.84
# Train set accuracy for a single minibatch: 27.00%
# Test set accuracy for a single minibatch: 35.00%
#
#
# Epoch 15, Iteration 15
# Train Set Loss: 13.80
# Test Set Loss: 12.34
# Train set accuracy for a single minibatch: 29.00%
# ...
# Test set accuracy for a single minibatch: 95.00%
#
#
# Epoch 164, Iteration 90
# Train Set Loss: 6.99
# Test Set Loss: 6.82
# Train set accuracy for a single minibatch: 91.00%
# Test set accuracy for a single minibatch: 92.00%
#
#
# Epoch 165, Iteration 0
# Train Set Loss: 7.19
# Test Set Loss: 6.67
# Train set accuracy for a single minibatch: 93.00%
# Test set accuracy for a single minibatch: 96.00%
#
#
# Epoch 165, Iteration 5
# Train Set Loss: 6.82
# Test Set Loss: 7.03
# Train set accuracy for a single minibatch: 98.00%
# Test set accuracy for a single minibatch: 95.00%
#
#
# Epoch 165, Iteration 10
# Train Set Loss: 6.74
# Test Set Loss: 6.88
# Train set accuracy for a single minibatch: 97.00%
# Test set accuracy for a single minibatch: 93.00%
#
#
# Epoch 165, Iteration 15
# Train Set Loss: 6.92
# Test Set Loss: 7.25
# Train set accuracy for a single minibatch: 95.00%
# Test set accuracy for a single minibatch: 92.00%
#
#
# Epoch 165, Iteration 20
# Train Set Loss: 6.72
# Test Set Loss: 7.14
# Train set accuracy for a single minibatch: 95.00%
# Test set accuracy for a single minibatch: 89.00%
#
#
# Epoch 165, Iteration 25
# Train Set Loss: 7.25
# Test Set Loss: 7.07
# Train set accuracy for a single minibatch: 89.00%
# Test set accuracy for a single minibatch: 94.00%
#
#
# Epoch 165, Iteration 30
# Train Set Loss: 6.78
# Test Set Loss: 7.06
# Train set accuracy for a single minibatch: 96.00%
# Test set accuracy for a single minibatch: 95.00%
#
#
# Epoch 165, Iteration 35
# Train Set Loss: 7.19
# Test Set Loss: 6.89
# Train set accuracy for a single minibatch: 93.00%
# Test set accuracy for a single minibatch: 94.00%
#
#
# Epoch 165, Iteration 40
# Train Set Loss: 7.12
# Test Set Loss: 6.56
# Train set accuracy for a single minibatch: 96.00%
# Test set accuracy for a single minibatch: 95.00%
#
#
# Epoch 165, Iteration 45
# Train Set Loss: 6.95
# Test Set Loss: 6.94
# Train set accuracy for a single minibatch: 94.00%
# Test set accuracy for a single minibatch: 97.00%
#
#
# Epoch 165, Iteration 50
# Train Set Loss: 6.98
# Test Set Loss: 7.27
# Train set accuracy for a single minibatch: 91.00%
# Test set accuracy for a single minibatch: 92.00%
#
#
# Epoch 165, Iteration 55
# Train Set Loss: 6.57
# Test Set Loss: 6.79
# Train set accuracy for a single minibatch: 91.00%
# Test set accuracy for a single minibatch: 91.00%
#
#
# Epoch 165, Iteration 60
# Train Set Loss: 7.20
# Test Set Loss: 6.77
# Train set accuracy for a single minibatch: 95.00%
# Test set accuracy for a single minibatch: 94.00%
#
#
# Epoch 165, Iteration 65
# Train Set Loss: 6.89
# Test Set Loss: 6.94
# Train set accuracy for a single minibatch: 98.00%
# Test set accuracy for a single minibatch: 96.00%
#
#
# Epoch 165, Iteration 70
# Train Set Loss: 7.09
# Test Set Loss: 6.83
# Train set accuracy for a single minibatch: 94.00%
# Test set accuracy for a single minibatch: 94.00%
#
#
# Epoch 165, Iteration 75
# Train Set Loss: 6.67
# Test Set Loss: 6.69
# Train set accuracy for a single minibatch: 96.00%
# Test set accuracy for a single minibatch: 95.00%
#
#
# Epoch 165, Iteration 80
# Train Set Loss: 7.01
# Test Set Loss: 7.55
# Train set accuracy for a single minibatch: 93.00%
# Test set accuracy for a single minibatch: 94.00%
#
#
# Epoch 165, Iteration 85
# Train Set Loss: 6.81
# Test Set Loss: 7.32
# Train set accuracy for a single minibatch: 96.00%
# Test set accuracy for a single minibatch: 88.00%
#
#
# Epoch 165, Iteration 90
# Train Set Loss: 7.24
# Test Set Loss: 7.03
# Train set accuracy for a single minibatch: 94.00%
# Test set accuracy for a single minibatch: 97.00%
#
#
# Epoch 166, Iteration 0
# Train Set Loss: 7.40
# Test Set Loss: 6.97
# Train set accuracy for a single minibatch: 96.00%
# Test set accuracy for a single minibatch: 94.00%
#
#
# Epoch 166, Iteration 5
# Train Set Loss: 6.82
# Test Set Loss: 7.14
# Train set accuracy for a single minibatch: 92.00%
# Test set accuracy for a single minibatch: 92.00%
#
#
# Epoch 166, Iteration 10
# Train Set Loss: 7.30
# Test Set Loss: 6.80
# Train set accuracy for a single minibatch: 90.00%
# Test set accuracy for a single minibatch: 96.00%
#
#
# Epoch 166, Iteration 15
# Train Set Loss: 7.00
# Test Set Loss: 6.87
# Train set accuracy for a single minibatch: 93.00%
# Test set accuracy for a single minibatch: 95.00%
#
#
# Epoch 166, Iteration 20
# Train Set Loss: 7.38
# Test Set Loss: 6.82
# Train set accuracy for a single minibatch: 93.00%
# Test set accuracy for a single minibatch: 91.00%
#
#
# Epoch 166, Iteration 25
# Train Set Loss: 6.77
# Test Set Loss: 6.93
# Train set accuracy for a single minibatch: 95.00%
# Test set accuracy for a single minibatch: 95.00%
#
#
# Epoch 166, Iteration 30
# Train Set Loss: 7.00
# Test Set Loss: 6.75
# Train set accuracy for a single minibatch: 98.00%
# Test set accuracy for a single minibatch: 94.00%
#
#
# Epoch 166, Iteration 35
# Train Set Loss: 7.05
# Test Set Loss: 6.48
# Train set accuracy for a single minibatch: 94.00%
# Test set accuracy for a single minibatch: 94.00%
#
#
# Epoch 166, Iteration 40
# Train Set Loss: 6.85
# Test Set Loss: 6.47
# Train set accuracy for a single minibatch: 97.00%
# Test set accuracy for a single minibatch: 97.00%
#
#
# Epoch 166, Iteration 45
# Train Set Loss: 7.27
# Test Set Loss: 6.62
# Train set accuracy for a single minibatch: 96.00%
# Test set accuracy for a single minibatch: 95.00%
#
#
# Epoch 166, Iteration 50
# Train Set Loss: 6.82
# Test Set Loss: 7.23
# Train set accuracy for a single minibatch: 98.00%
# Test set accuracy for a single minibatch: 93.00%
#
#
# Epoch 166, Iteration 55
# Train Set Loss: 6.59
# Test Set Loss: 6.82
# Train set accuracy for a single minibatch: 96.00%
# Test set accuracy for a single minibatch: 96.00%
#
#
# Epoch 166, Iteration 60
# Train Set Loss: 6.78
# Test Set Loss: 6.49
# Train set accuracy for a single minibatch: 94.00%
# Test set accuracy for a single minibatch: 98.00%
#
#
# Epoch 166, Iteration 65
# Train Set Loss: 7.16
# Test Set Loss: 6.77
# Train set accuracy for a single minibatch: 90.00%
# Test set accuracy for a single minibatch: 93.00%
#
#
# Epoch 166, Iteration 70
# Train Set Loss: 6.66
# Test Set Loss: 6.80
# Train set accuracy for a single minibatch: 94.00%
# Test set accuracy for a single minibatch: 89.00%
#
#
# Epoch 166, Iteration 75
# Train Set Loss: 7.11
# Test Set Loss: 7.14
# Train set accuracy for a single minibatch: 92.00%
# Test set accuracy for a single minibatch: 95.00%
#
#
# Epoch 166, Iteration 80
# Train Set Loss: 6.44
# Test Set Loss: 7.08
# Train set accuracy for a single minibatch: 95.00%
# Test set accuracy for a single minibatch: 95.00%
#
#
# Epoch 166, Iteration 85
# Train Set Loss: 6.85
# Test Set Loss: 7.16
# Train set accuracy for a single minibatch: 93.00%
# Test set accuracy for a single minibatch: 92.00%
#
#
# Epoch 166, Iteration 90
# Train Set Loss: 7.02
# Test Set Loss: 6.75
# Train set accuracy for a single minibatch: 92.00%
# Test set accuracy for a single minibatch: 97.00%
#
#
# Epoch 167, Iteration 0
# Train Set Loss: 6.94
# Test Set Loss: 7.08
# Train set accuracy for a single minibatch: 96.00%
# Test set accuracy for a single minibatch: 89.00%
#
#
# Epoch 167, Iteration 5
# Train Set Loss: 6.84
# Test Set Loss: 7.01
# Train set accuracy for a single minibatch: 97.00%
# Test set accuracy for a single minibatch: 91.00%
#
#
# Epoch 167, Iteration 10
# Train Set Loss: 6.54
# Test Set Loss: 6.72
# Train set accuracy for a single minibatch: 95.00%
# Test set accuracy for a single minibatch: 95.00%
#
#
# Epoch 167, Iteration 15
# Train Set Loss: 6.55
# Test Set Loss: 7.24
# Train set accuracy for a single minibatch: 96.00%
# Test set accuracy for a single minibatch: 93.00%
#
#
# Epoch 167, Iteration 20
# Train Set Loss: 7.39
# Test Set Loss: 7.15
# Train set accuracy for a single minibatch: 91.00%
# Test set accuracy for a single minibatch: 92.00%
#
#
# Epoch 167, Iteration 25
# Train Set Loss: 7.04
# Test Set Loss: 7.10
# Train set accuracy for a single minibatch: 96.00%
# Test set accuracy for a single minibatch: 96.00%
#
#
# Epoch 167, Iteration 30
# Train Set Loss: 6.63
# Test Set Loss: 6.78
# Train set accuracy for a single minibatch: 93.00%
# Test set accuracy for a single minibatch: 96.00%
#
#
# Epoch 167, Iteration 35
# Train Set Loss: 7.59
# Test Set Loss: 7.01
# Train set accuracy for a single minibatch: 94.00%
# Test set accuracy for a single minibatch: 93.00%
#
#
# Epoch 167, Iteration 40
# Train Set Loss: 6.87
# Test Set Loss: 6.85
# Train set accuracy for a single minibatch: 97.00%
# Test set accuracy for a single minibatch: 95.00%
#
#
# Epoch 167, Iteration 45
# Train Set Loss: 7.04
# Test Set Loss: 6.76
# Train set accuracy for a single minibatch: 95.00%
# Test set accuracy for a single minibatch: 91.00%
#
#
# Epoch 167, Iteration 50
# Train Set Loss: 6.56
# Test Set Loss: 7.20
# Train set accuracy for a single minibatch: 98.00%
# Test set accuracy for a single minibatch: 92.00%
#
#
# Epoch 167, Iteration 55
# Train Set Loss: 6.63
# Test Set Loss: 7.37
# Train set accuracy for a single minibatch: 95.00%
# Test set accuracy for a single minibatch: 93.00%
#
#
# Epoch 167, Iteration 60
# Train Set Loss: 6.93
# Test Set Loss: 6.95
# Train set accuracy for a single minibatch: 96.00%
# Test set accuracy for a single minibatch: 95.00%
#
#
# Epoch 167, Iteration 65
# Train Set Loss: 6.20
# Test Set Loss: 6.60
# Train set accuracy for a single minibatch: 99.00%
# Test set accuracy for a single minibatch: 99.00%
#
#
# Epoch 167, Iteration 70
# Train Set Loss: 6.99
# Test Set Loss: 7.20
# Train set accuracy for a single minibatch: 87.00%
# Test set accuracy for a single minibatch: 94.00%
#
#
# Epoch 167, Iteration 75
# Train Set Loss: 6.76
# Test Set Loss: 7.15
# Train set accuracy for a single minibatch: 95.00%
# Test set accuracy for a single minibatch: 90.00%
#
#
# Epoch 167, Iteration 80
# Train Set Loss: 6.76
# Test Set Loss: 6.98
# Train set accuracy for a single minibatch: 95.00%
# Test set accuracy for a single minibatch: 93.00%
#
#
# Epoch 167, Iteration 85
# Train Set Loss: 6.52
# Test Set Loss: 6.79
# Train set accuracy for a single minibatch: 96.00%
# Test set accuracy for a single minibatch: 94.00%
#
#
# Epoch 167, Iteration 90
# Train Set Loss: 6.78
# Test Set Loss: 6.68
# Train set accuracy for a single minibatch: 95.00%
# Test set accuracy for a single minibatch: 100.00%
#
#
# Epoch 168, Iteration 0
# Train Set Loss: 6.86
# Test Set Loss: 6.89
# Train set accuracy for a single minibatch: 92.00%
# Test set accuracy for a single minibatch: 95.00%
#
#
# Epoch 168, Iteration 5
# Train Set Loss: 6.67
# Test Set Loss: 6.86
# Train set accuracy for a single minibatch: 94.00%
# Test set accuracy for a single minibatch: 96.00%
#
#
# Epoch 168, Iteration 10
# Train Set Loss: 6.80
# Test Set Loss: 7.04
# Train set accuracy for a single minibatch: 95.00%
# Test set accuracy for a single minibatch: 92.00%
#
#
# Epoch 168, Iteration 15
# Train Set Loss: 7.23
# Test Set Loss: 7.08
# Train set accuracy for a single minibatch: 92.00%
# Test set accuracy for a single minibatch: 95.00%
#
#
# Epoch 168, Iteration 20
# Train Set Loss: 6.40
# Test Set Loss: 7.00
# Train set accuracy for a single minibatch: 92.00%
# Test set accuracy for a single minibatch: 91.00%
#
#
# Epoch 168, Iteration 25
# Train Set Loss: 7.28
# Test Set Loss: 7.06
# Train set accuracy for a single minibatch: 89.00%
# Test set accuracy for a single minibatch: 92.00%
#
#
# Epoch 168, Iteration 30
# Train Set Loss: 6.88
# Test Set Loss: 6.58
# Train set accuracy for a single minibatch: 95.00%
# Test set accuracy for a single minibatch: 97.00%
#
#
# Epoch 168, Iteration 35
# Train Set Loss: 6.59
# Test Set Loss: 7.36
# Train set accuracy for a single minibatch: 95.00%
# Test set accuracy for a single minibatch: 88.00%
#
#
# Epoch 168, Iteration 40
# Train Set Loss: 7.35
# Test Set Loss: 6.79
# Train set accuracy for a single minibatch: 89.00%
# Test set accuracy for a single minibatch: 96.00%
#
#
# Epoch 168, Iteration 45
# Train Set Loss: 6.89
# Test Set Loss: 7.27
# Train set accuracy for a single minibatch: 98.00%
# Test set accuracy for a single minibatch: 94.00%
#
#
# Epoch 168, Iteration 50
# Train Set Loss: 6.51
# Test Set Loss: 7.03
# Train set accuracy for a single minibatch: 99.00%
# Test set accuracy for a single minibatch: 98.00%
#
#
# Epoch 168, Iteration 55
# Train Set Loss: 7.13
# Test Set Loss: 6.34
# Train set accuracy for a single minibatch: 92.00%
# Test set accuracy for a single minibatch: 97.00%
#
#
# Epoch 168, Iteration 60
# Train Set Loss: 6.99
# Test Set Loss: 7.22
# Train set accuracy for a single minibatch: 92.00%
# Test set accuracy for a single minibatch: 90.00%
#
#
# Epoch 168, Iteration 65
# Train Set Loss: 6.89
# Test Set Loss: 6.71
# Train set accuracy for a single minibatch: 94.00%
# Test set accuracy for a single minibatch: 92.00%
#
#
# Epoch 168, Iteration 70
# Train Set Loss: 7.04
# Test Set Loss: 6.91
# Train set accuracy for a single minibatch: 90.00%
# Test set accuracy for a single minibatch: 95.00%
#
#
# Epoch 168, Iteration 75
# Train Set Loss: 7.64
# Test Set Loss: 7.20
# Train set accuracy for a single minibatch: 94.00%
# Test set accuracy for a single minibatch: 92.00%
#
#
# Epoch 168, Iteration 80
# Train Set Loss: 6.57
# Test Set Loss: 7.24
# Train set accuracy for a single minibatch: 96.00%
# Test set accuracy for a single minibatch: 95.00%
#
#
# Epoch 168, Iteration 85
# Train Set Loss: 6.96
# Test Set Loss: 7.14
# Train set accuracy for a single minibatch: 94.00%
# Test set accuracy for a single minibatch: 93.00%
#
#
# Epoch 168, Iteration 90
# Train Set Loss: 6.88
# Test Set Loss: 6.93
# Train set accuracy for a single minibatch: 96.00%
# Test set accuracy for a single minibatch: 97.00%
#
#
# Epoch 169, Iteration 0
# Train Set Loss: 6.41
# Test Set Loss: 6.61
# Train set accuracy for a single minibatch: 99.00%
# Test set accuracy for a single minibatch: 95.00%
#
#
# Epoch 169, Iteration 5
# Train Set Loss: 7.17
# Test Set Loss: 6.82
# Train set accuracy for a single minibatch: 96.00%
# Test set accuracy for a single minibatch: 97.00%
#
#
# Epoch 169, Iteration 10
# Train Set Loss: 6.49
# Test Set Loss: 6.50
# Train set accuracy for a single minibatch: 93.00%
# Test set accuracy for a single minibatch: 95.00%
#
#
# Epoch 169, Iteration 15
# Train Set Loss: 7.14
# Test Set Loss: 7.00
# Train set accuracy for a single minibatch: 97.00%
# Test set accuracy for a single minibatch: 91.00%
#
#
# Epoch 169, Iteration 20
# Train Set Loss: 7.00
# Test Set Loss: 6.33
# Train set accuracy for a single minibatch: 97.00%
# Test set accuracy for a single minibatch: 98.00%
#
#
# Epoch 169, Iteration 25
# Train Set Loss: 7.00
# Test Set Loss: 7.20
# Train set accuracy for a single minibatch: 95.00%
# Test set accuracy for a single minibatch: 91.00%
#
#
# Epoch 169, Iteration 30
# Train Set Loss: 7.14
# Test Set Loss: 6.45
# Train set accuracy for a single minibatch: 93.00%
# Test set accuracy for a single minibatch: 97.00%
#
#
# Epoch 169, Iteration 35
# Train Set Loss: 6.78
# Test Set Loss: 6.84
# Train set accuracy for a single minibatch: 92.00%
# Test set accuracy for a single minibatch: 94.00%
#
#
# Epoch 169, Iteration 40
# Train Set Loss: 7.13
# Test Set Loss: 6.50
# Train set accuracy for a single minibatch: 91.00%
# Test set accuracy for a single minibatch: 96.00%
#
#
# Epoch 169, Iteration 45
# Train Set Loss: 6.73
# Test Set Loss: 7.27
# Train set accuracy for a single minibatch: 94.00%
# Test set accuracy for a single minibatch: 96.00%
#
#
# Epoch 169, Iteration 50
# Train Set Loss: 6.26
# Test Set Loss: 7.50
# Train set accuracy for a single minibatch: 96.00%
# Test set accuracy for a single minibatch: 85.00%
#
#
# Epoch 169, Iteration 55
# Train Set Loss: 6.26
# Test Set Loss: 6.84
# Train set accuracy for a single minibatch: 94.00%
# Test set accuracy for a single minibatch: 93.00%
#
#
# Epoch 169, Iteration 60
# Train Set Loss: 6.95
# Test Set Loss: 6.69
# Train set accuracy for a single minibatch: 95.00%
# Test set accuracy for a single minibatch: 91.00%
#
#
# Epoch 169, Iteration 65
# Train Set Loss: 6.99
# Test Set Loss: 7.16
# Train set accuracy for a single minibatch: 94.00%
# Test set accuracy for a single minibatch: 92.00%
#
#
# Epoch 169, Iteration 70
# Train Set Loss: 7.33
# Test Set Loss: 6.94
# Train set accuracy for a single minibatch: 94.00%
# Test set accuracy for a single minibatch: 94.00%
#
#
# Epoch 169, Iteration 75
# Train Set Loss: 6.58
# Test Set Loss: 7.15
# Train set accuracy for a single minibatch: 95.00%
# Test set accuracy for a single minibatch: 94.00%
#
#
# Epoch 169, Iteration 80
# Train Set Loss: 7.25
# Test Set Loss: 7.04
# Train set accuracy for a single minibatch: 91.00%
# Test set accuracy for a single minibatch: 97.00%
#
#
# Epoch 169, Iteration 85
# Train Set Loss: 6.87
# Test Set Loss: 7.77
# Train set accuracy for a single minibatch: 90.00%
# Test set accuracy for a single minibatch: 86.00%
#
#
# Epoch 169, Iteration 90
# Train Set Loss: 6.73
# Test Set Loss: 7.47
# Train set accuracy for a single minibatch: 96.00%
# Test set accuracy for a single minibatch: 91.00%

# %%
# Plot Loss
fig = plt.figure(facecolor="w", figsize=(10, 5))
plt.plot(loss_hist)
plt.plot(test_loss_hist)
plt.title("Loss Curves")
plt.legend(["Train Loss", "Test Loss"])
plt.ylabel("Loss")
plt.show()

# %%
fig = plt.figure(facecolor="w", figsize=(10, 5))
plt.plot(test_accuracy_data)
plt.plot(train_accuracy_data)
plt.title("Accuracy Cuve")
plt.legend(["Test accuracy", "Train accuracy"])
plt.ylabel("Accuracy")
plt.show()

# %%
total = 0
correct = 0

# drop_last switched to False to keep all samples
test_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True, drop_last=False)

with torch.no_grad():
  net.eval()
  for data, targets in test_loader:
    data = data.to(device)
    targets = targets.to(device)
    
    # forward pass
    test_spk, _ = net(data.view(data.size(0), -1))

    # calculate total accuracy
    _, predicted = test_spk.sum(dim=0).max(1)
    total += targets.size(0)
    correct += (predicted == targets).sum().item()

print(f"Total correctly classified test set : {correct}/{total}")
print(f"Test Set Accuracy: {100 * correct / total:.2f}%")
# Out:
# Total correctly classified test set : 8955/9500
# Test Set Accuracy: 94.26%

# %%
conf_matrix = confusion_matrix(targets, predicted)

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix*5, annot=True, fmt="d", cmap="Blues", cbar=False)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()

# %%
# Calculating specificity for each class
num_classes = len(conf_matrix)
specificity = np.zeros(num_classes)

for i in range(num_classes):
    # True negatives for the current class
    tn = np.sum(np.delete(np.delete(conf_matrix, i, axis=0), i, axis=1))
    
    # False positives for other classes
    fp = np.sum(np.delete(conf_matrix[i, :], i))
    
    # Specificity for the current class
    specificity[i] = tn / (tn + fp)

print("Confusion Matrix:")
print(conf_matrix)
print(specificity)
# Out:
# Confusion Matrix:
# [[26  0  0  0  0  0  0]
#  [ 0  4  0  0  0  1  0]
#  [ 0  0 27  0  0  0  0]
#  [ 3  0  0  9  0  0  0]
#  [ 0  0  0  0 14  0  0]
#  [ 0  3  0  0  0  7  0]
#  [ 0  0  0  0  0  0  6]]
# [1.         0.98924731 1.         0.96703297 1.         0.9673913
#  1.        ]
